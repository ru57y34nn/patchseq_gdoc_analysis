# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline

# %%
ps = pd.read_csv('patch_seq_log_mouse.csv')

# %%
ps = ps[["Date", "User", "Morph", "Post patch?", "Post patch pipette R", "Nucleus sucked in?", "Notes", "Internal version", "PCR cycles", "SM_QC_PF"]]
ps.dropna(subset = ["Post patch?", "Morph"], inplace = True)
ps["User"] = ps["User"].astype("category")
ps["Post patch?"] = ps["Post patch?"].astype("category")
ps["SM_QC_PF"] = ps["SM_QC_PF"].astype("category")
ps = ps[ps["SM_QC_PF"] != "cnt"]
ps = ps[ps["PCR cycles"] == 21]
ps["Date"] = pd.to_datetime(ps["Date"], format = '%y%m%d')
ps
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Date User Morph      Post patch?  Post patch pipette R  \
# 4968 2017-04-19   P2     n      Outside-Out                   NaN
# 4969 2017-04-19   P2     y      Outside-Out                   NaN
# 4970 2017-04-19   P2     n          No-Seal                   NaN
# 4971 2017-04-19   P2     y        Nucleated                   NaN
# 4972 2017-04-19   P2     y      Outside-Out                   NaN
# 4973 2017-04-19   P2     y        Nucleated                   NaN
# 4974 2017-04-19   P2     n          No-Seal                   NaN
# 4975 2017-04-19   P2     q        Nucleated                   NaN
# 4978 2017-04-19   P6     n          No-Seal                   NaN
# 4979 2017-04-19   P6     n          No-Seal                   NaN
# 4980 2017-04-19   P6     n          No-Seal                   NaN
# 4981 2017-04-19   P6     n          No-Seal                   NaN
# 5016 2017-04-21   P1     n          No-Seal                   NaN
# 5017 2017-04-21   P1     n          No-Seal                   NaN
# 5018 2017-04-21   P1     n          No-Seal                   NaN
# 5019 2017-04-21   P1     n          No-Seal                   NaN
# 5020 2017-04-21   P1     n          No-Seal                   NaN
# 5021 2017-04-21   P1     n  Partial-Nucleus                   NaN
# 5022 2017-04-21   P1     n        Nucleated                   NaN
# 5023 2017-04-21   P1     q          No-Seal                   NaN
# 5026 2017-04-21   P2     n        Nucleated                   NaN
# 5027 2017-04-21   P2     y        Nucleated                   NaN
# 5028 2017-04-21   P2     n          No-Seal                   NaN
# 5029 2017-04-21   P2     n          No-Seal                   NaN
# 5030 2017-04-21   P2     n          No-Seal                   NaN
# 5031 2017-04-21   P2     n          No-Seal                   NaN
# 5032 2017-04-21   P2     n          No-Seal                   NaN
# 5033 2017-04-21   P2     n          No-Seal                   NaN
# 5034 2017-04-21   P2     y          No-Seal                   NaN
# 5035 2017-04-21   P2     n        Nucleated                   NaN
# ...         ...  ...   ...              ...                   ...
# 7539 2017-10-12   P2     n   nucleus_absent                  10.0
# 7540 2017-10-12   P8     n  nucleus_present                  50.0
# 7541 2017-10-12   P8     n  nucleus_present                  50.0
# 7542 2017-10-12   PB     n   nucleus_absent                   0.0
# 7545 2017-10-13   P8     q  nucleus_present                1500.0
# 7546 2017-10-13   P8     y  nucleus_present                 700.0
# 7550 2017-10-13   PB     q  nucleus_present                2000.0
# 7551 2017-10-13   PB     n  nucleus_present                1000.0
# 7552 2017-10-13   PB     n   nucleus_absent                 700.0
# 7553 2017-10-13   PB     n  nucleus_present                1000.0
# 7554 2017-10-16   P2     q   nucleus_absent                1000.0
# 7555 2017-10-16   P2     q  nucleus_present                1000.0
# 7556 2017-10-16   P8     n  nucleus_present                1000.0
# 7557 2017-10-16   P8     n  nucleus_present                  10.0
# 7558 2017-10-16   P8     n   nucleus_absent                  10.0
# 7559 2017-10-16   P8     n  nucleus_present                  30.0
# 7560 2017-10-16   P8     n  nucleus_present                1000.0
# 7561 2017-10-16   P8     n  nucleus_present                1000.0
# 7564 2017-10-16   P9     n  nucleus_present                1000.0
# 7565 2017-10-16   P9     n   nucleus_absent                 200.0
# 7566 2017-10-16   P9     q  nucleus_present                1500.0
# 7567 2017-10-16   P9     n   nucleus_absent                 300.0
# 7569 2017-10-16   PA     n  nucleus_present                   3.6
# 7570 2017-10-16   PA     y   nucleus_absent                   3.5
# 7571 2017-10-16   PA     n  nucleus_present                   6.0
# 7573 2017-10-16   PB     n  nucleus_present                2000.0
# 7574 2017-10-16   PB     q  nucleus_present                2000.0
# 7575 2017-10-16   PB     q  nucleus_present                2000.0
# 7576 2017-10-16   PB     y  nucleus_present                2000.0
# 7577 2017-10-16   PB     q  nucleus_present                1000.0
#
#      Nucleus sucked in?                                              Notes  \
# 4968                NaN                                                NaN
# 4969                NaN                                                NaN
# 4970                NaN                                                NaN
# 4971                NaN                                                NaN
# 4972                NaN                                                NaN
# 4973                NaN                                                NaN
# 4974                NaN                                                NaN
# 4975                NaN                                                NaN
# 4978                NaN                                                NaN
# 4979                NaN                                                NaN
# 4980                NaN                                                NaN
# 4981                NaN                                                NaN
# 5016                NaN                                                NaN
# 5017                NaN                                                NaN
# 5018                NaN                                        Cell Dimmed
# 5019                NaN                            Fluorescence in Pipette
# 5020                NaN          Fluorescence in Pipette,Cell Dimmed   1.0
# 5021                NaN                Fluorescence in Pipette,Cell Dimmed
# 5022                NaN                Fluorescence in Pipette,Cell Dimmed
# 5023                NaN                            Fluorescence in Pipette
# 5026                NaN                            Fluorescence in Pipette
# 5027                NaN                            Fluorescence in Pipette
# 5028                NaN                                                NaN
# 5029                NaN                                                NaN
# 5030                NaN                                                NaN
# 5031                NaN                            Fluorescence in Pipette
# 5032                NaN                                                NaN
# 5033                NaN                                                NaN
# 5034                NaN                            Fluorescence in Pipette
# 5035                NaN                                                NaN
# ...                 ...                                                ...
# 7539                 no  Fluorescence in Pipette Large Bubbles alexa fi...
# 7540  not_intentionally  Cell Dimmed,Cell Swelled No Bubbles Alexa fill...
# 7541  not_intentionally  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7542  not_intentionally                                                NaN
# 7545                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7546                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7550                 no   Medium Bubbles,Solution in Pipette Shank perfect
# 7551                 no                                            perfect
# 7552  not_intentionally                                                NaN
# 7553                 no                                                NaN
# 7554                 no  Fluorescence in Pipette No Bubbles alxa fill v...
# 7555                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7556  not_intentionally  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7557      intentionally  Fluorescence in Pipette No Bubbles Looks like ...
# 7558                 no      Cell Dimmed No Bubbles Alexa fill not visible
# 7559      intentionally  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7560                 no  Fluorescence in Pipette,Cell Dimmed,Cell Swell...
# 7561                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7564                 no  Fluorescence in Pipette No Bubbles Alexa fill ...
# 7565                 no  Fluorescence in Pipette No Bubbles Alexa fill ...
# 7566                 no  Fluorescence in Pipette No Bubbles,Solution in...
# 7567                 no  Fluorescence in Pipette No Bubbles Alexa fill ...
# 7569  not_intentionally  Cell Dimmed No Bubbles,Small Bubbles Partial-n...
# 7570                 no  Cell Dimmed,Cell Swelled,Cell Disappeared Smal...
# 7571  not_intentionally  Cell Dimmed,Cell Shrunk Small Bubbles Partial ...
# 7573                 no                                            perfect
# 7574                 no                                            perfect
# 7575                 no                                            perfect
# 7576                 no                                            perfect
# 7577                 no                                            perfect
#
#          Internal version  PCR cycles SM_QC_PF
# 4968                 AiV2        21.0     fail
# 4969                 AiV2        21.0     pass
# 4970                 AiV2        21.0     fail
# 4971                 AiV2        21.0     pass
# 4972                 AiV2        21.0     pass
# 4973                 AiV2        21.0     pass
# 4974                 AiV2        21.0     pass
# 4975                 AiV2        21.0     pass
# 4978                 AiV2        21.0     fail
# 4979                 AiV2        21.0     pass
# 4980                 AiV2        21.0     pass
# 4981                 AiV2        21.0     pass
# 5016                 AiV2        21.0     pass
# 5017                 AiV2        21.0     pass
# 5018                 AiV2        21.0     fail
# 5019                 AiV2        21.0     pass
# 5020                 AiV2        21.0     pass
# 5021                 AiV2        21.0     pass
# 5022                 AiV2        21.0     pass
# 5023                 AiV2        21.0     pass
# 5026                 AiV2        21.0     pass
# 5027                 AiV2        21.0     pass
# 5028                 AiV2        21.0     pass
# 5029                 AiV2        21.0     pass
# 5030                 AiV2        21.0     pass
# 5031                 AiV2        21.0     pass
# 5032                 AiV2        21.0     pass
# 5033                 AiV2        21.0     pass
# 5034                 AiV2        21.0     fail
# 5035                 AiV2        21.0     pass
# ...                   ...         ...      ...
# 7539  AiV2-50uM alexa 488        21.0     fail
# 7540  AiV2-50uM alexa 488        21.0     fail
# 7541  AiV2-50uM alexa 488        21.0     fail
# 7542  AiV2-50uM alexa 488        21.0     pass
# 7545  AiV2-50uM alexa 488        21.0     pass
# 7546  AiV2-50uM alexa 488        21.0     pass
# 7550  AiV2-50uM alexa 488        21.0     pass
# 7551  AiV2-50uM alexa 488        21.0     pass
# 7552  AiV2-50uM alexa 488        21.0     pass
# 7553  AiV2-50uM alexa 488        21.0     pass
# 7554  AiV2-50uM alexa 488        21.0     fail
# 7555  AiV2-50uM alexa 488        21.0     pass
# 7556  AiV2-50uM alexa 488        21.0     pass
# 7557  AiV2-50uM alexa 488        21.0     pass
# 7558  AiV2-50uM alexa 488        21.0     pass
# 7559  AiV2-50uM alexa 488        21.0     pass
# 7560  AiV2-50uM alexa 488        21.0     pass
# 7561  AiV2-50uM alexa 488        21.0     pass
# 7564  AiV2-50uM alexa 488        21.0     pass
# 7565  AiV2-50uM alexa 488        21.0     pass
# 7566  AiV2-50uM alexa 488        21.0     pass
# 7567  AiV2-50uM alexa 488        21.0     fail
# 7569  AiV2-50uM alexa 488        21.0     pass
# 7570  AiV2-50uM alexa 488        21.0     fail
# 7571  AiV2-50uM alexa 488        21.0     pass
# 7573  AiV2-50uM alexa 488        21.0     pass
# 7574  AiV2-50uM alexa 488        21.0     pass
# 7575  AiV2-50uM alexa 488        21.0     pass
# 7576  AiV2-50uM alexa 488        21.0     pass
# 7577  AiV2-50uM alexa 488        21.0     pass
#
# [1728 rows x 10 columns]

# %% [markdown]
# # Analysis Project: Post Patch vs Cell Depth

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline

# %%
initial = pd.read_csv('C:/users/ramr/documents/github/patchseq_gdoc_analysis/patch_seq_log_mouse.csv')
initial.head()
# Out:
#      Date User Rig #             File Ephys Trans Morph           Pilot  \
# 0  140604  BRL   NaN   WT - 140604_01     x   NaN   NaN  RNAseq - pilot
# 1  140606  BRL   NaN   WT - 140606_01     x   NaN   NaN  RNAseq - pilot
# 2  140606  BRL   NaN   WT - 140606_02     x   NaN   NaN  RNAseq - pilot
# 3  140610  BRL   NaN  WT - 140610_01a     x   NaN   NaN  RNAseq - pilot
# 4  140610  BRL   NaN   WT - 140610_01     x   NaN   NaN  RNAseq - pilot
#
#   Pilot Details cell type     ...     Plate Comments  \
# 0           NaN      tdt-     ...       NaN      NaN
# 1           NaN      tdt-     ...       NaN      NaN
# 2           NaN      tdt-     ...       NaN      NaN
# 3           NaN      tdt-     ...       NaN      NaN
# 4           NaN      tdt-     ...       NaN      NaN
#
#   Stacis call for reconstructions Stacis call for class Confidence Bad dates  \
# 0                             NaN                   NaN        NaN       NaN
# 1                             NaN                   NaN        NaN       NaN
# 2                             NaN                   NaN        NaN       NaN
# 3                             NaN                   NaN        NaN       NaN
# 4                             NaN                   NaN        NaN       NaN
#
#   Notes.1  Unnamed: 76 Unnamed: 77 Unnamed: 78
# 0     NaN          NaN         NaN         NaN
# 1     NaN          NaN         NaN         NaN
# 2     NaN          NaN         NaN         NaN
# 3     NaN          NaN         NaN         NaN
# 4     NaN          NaN         NaN         NaN
#
# [5 rows x 79 columns]

# %%
select = ["Date", "Depth (um)", "Post patch?", "Nucleus sucked in?", "Post patch pipette R", "PCR cycles", "SM_QC_PF", "Bad dates"]
ps = initial[select]

#Changing Date Format
ps["Date"] = pd.to_datetime(ps["Date"], format = "%y%m%d")

#Categories
ps["Post patch?"] = ps["Post patch?"].astype("category")
ps["Nucleus sucked in?"] = ps["Nucleus sucked in?"].astype("category")
ps["SM_QC_PF"] = ps["SM_QC_PF"].astype("category")

#Filtering Columns
ps = ps[ps["PCR cycles"] == 21]      #shows 21 pcr cycles
ps = ps[ps["SM_QC_PF"] != "cnt"]     #shows everything except cnt
ps = ps[ps["Bad dates"] != "x"]      #shows everthing except x

#ps.dropna(subset = ["Post patch?", "Nucleus sucked in?"], returns start date 10/02/17 and data after that date
ps.dropna(subset = ["Post patch?", "SM_QC_PF"], inplace = True)
ps.head()
# Out:
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#            Date Depth (um)  Post patch? Nucleus sucked in?  \
# 4968 2017-04-19       56.3  Outside-Out                NaN
# 4969 2017-04-19       28.5  Outside-Out                NaN
# 4970 2017-04-19       53.8      No-Seal                NaN
# 4971 2017-04-19       24.5    Nucleated                NaN
# 4972 2017-04-19       40.7  Outside-Out                NaN
#
#       Post patch pipette R  PCR cycles SM_QC_PF Bad dates
# 4968                   NaN        21.0     fail       NaN
# 4969                   NaN        21.0     pass       NaN
# 4970                   NaN        21.0     fail       NaN
# 4971                   NaN        21.0     pass       NaN
# 4972                   NaN        21.0     pass       NaN

# %% [markdown]
# All categories for post patch...up till 10/02/2017
# All categories for nucleus sucked in?... starts at 10/02/2017
# For post patch pipette R and nucleus sucked in?... starts at 10/02/2017
# depth = numerical
# post patch? = categorical
# post patch pipette R = numerical
# nucleus sucked in? = categorical

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1861 entries, 4968 to 7596
# Data columns (total 8 columns):
# Date                    1861 non-null datetime64[ns]
# Depth (um)              1589 non-null object
# Post patch?             1861 non-null category
# Nucleus sucked in?      240 non-null category
# Post patch pipette R    240 non-null float64
# PCR cycles              1861 non-null float64
# SM_QC_PF                1861 non-null category
# Bad dates               0 non-null object
# dtypes: category(3), datetime64[ns](1), float64(2), object(2)
# memory usage: 93.8+ KB

# %%
ps.dtypes
# Out:
# Date                    datetime64[ns]
# Depth (um)                      object
# Post patch?                   category
# Nucleus sucked in?            category
# Post patch pipette R           float64
# PCR cycles                     float64
# SM_QC_PF                      category
# Bad dates                       object
# dtype: object

# %% [markdown]
# ## Definitions Sections

# %%
#Clarify if cutoff should be 500 and 501 or 500 and 499
#Defines each post patch category 

def nucleated(x):
    nucleus = x[(x["Post patch?"] == "Nucleated") | (((x["Post patch?"] == "nucleus_visible") | (x["Post patch?"] == "nucleus_present")) & (x["Post patch pipette R"] >= 501))]
    return nucleus

def partial_nucleated(y):
    partial = y[(y["Post patch?"] == 'Partial-Nucleus') | (((y['Post patch?'] == 'nucleus_present') | (y['Post patch?'] == 'nucleus_visible')) & (y["Post patch pipette R"] <= 500))]
    return partial

def outside_out(z):
    outside = z[(z["Post patch?"] == 'Outside-Out') | (((z['Post patch?'] == 'nucleus_absent') | (z['Post patch?'] == 'no_nuclues_visible')) & (z['Post patch pipette R'] >= 501))]
    return outside

def no_seal(w): 
    no = w[(w["Post patch?"] == 'No-Seal') | (((w['Post patch?'] == 'nucleus_absent') | (w['Post patch?'] == 'no_nucleus_visible')) & (w['Post patch pipette R'] <= 500))]
    return no
    
def entire_cell(v):
    entire = v[(v["Post patch?"] == 'Entire-Cell') | (v['Post patch?'] == 'entire_cell')]
    return entire

# %% [markdown]
# ## End of Definitions Section

# %% [markdown]
# Problem: Depth is not displayed after 10/02/2017 so you would have to somehow manually gather data and possibly use an updated csv file with that info

# %% [markdown]
# ## Creating a DataFrame by Post Patch Class

# %%
#Labelling each post patch category
#This creates a column returning the "___" for the defined categories above

nuc = nucleated(ps)
nuc["post patch class"] = "Nucleated"

part_nuc = partial_nucleated(ps)
part_nuc["post patch class"] = "Partial nucleated"

out_out = outside_out(ps)
out_out["post patch class"] = "Outside out"

noSeal = no_seal(ps)
noSeal["post patch class"] = "No seal"

entirecell = entire_cell(ps)
entirecell["post patch class"] = "Entire Cell"

ps.head()
# Out:
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ramr\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Date Depth (um)  Post patch? Nucleus sucked in?  \
# 4968 2017-04-19       56.3  Outside-Out                NaN
# 4969 2017-04-19       28.5  Outside-Out                NaN
# 4970 2017-04-19       53.8      No-Seal                NaN
# 4971 2017-04-19       24.5    Nucleated                NaN
# 4972 2017-04-19       40.7  Outside-Out                NaN
#
#       Post patch pipette R  PCR cycles SM_QC_PF Bad dates
# 4968                   NaN        21.0     fail       NaN
# 4969                   NaN        21.0     pass       NaN
# 4970                   NaN        21.0     fail       NaN
# 4971                   NaN        21.0     pass       NaN
# 4972                   NaN        21.0     pass       NaN

# %%
#This puts data in order the frames list 
#All nucleated data is shown then partial nuc then outside-out...as continues inside brackets

frames = [nuc, part_nuc, out_out, noSeal, entirecell]
ps = pd.concat(frames)
ps.head(10)
# Out:
#            Date Depth (um) Post patch? Nucleus sucked in?  \
# 4971 2017-04-19       24.5   Nucleated                NaN
# 4973 2017-04-19       17.6   Nucleated                NaN
# 4975 2017-04-19       40.2   Nucleated                NaN
# 4988 2017-04-20       56.2   Nucleated                NaN
# 4997 2017-04-20       55.4   Nucleated                NaN
# 5009 2017-04-20       33.8   Nucleated                NaN
# 5022 2017-04-21        NaN   Nucleated                NaN
# 5026 2017-04-21       44.9   Nucleated                NaN
# 5027 2017-04-21       24.2   Nucleated                NaN
# 5035 2017-04-21       31.2   Nucleated                NaN
#
#       Post patch pipette R  PCR cycles SM_QC_PF Bad dates post patch class
# 4971                   NaN        21.0     pass       NaN        Nucleated
# 4973                   NaN        21.0     pass       NaN        Nucleated
# 4975                   NaN        21.0     pass       NaN        Nucleated
# 4988                   NaN        21.0     pass       NaN        Nucleated
# 4997                   NaN        21.0     pass       NaN        Nucleated
# 5009                   NaN        21.0     pass       NaN        Nucleated
# 5022                   NaN        21.0     pass       NaN        Nucleated
# 5026                   NaN        21.0     pass       NaN        Nucleated
# 5027                   NaN        21.0     pass       NaN        Nucleated
# 5035                   NaN        21.0     pass       NaN        Nucleated

# %% [markdown]
# ## Trial & Error Section

# %%
ps["post patch class"].value_counts()
# Out:
# Nucleated            851
# No seal              641
# Partial nucleated    235
# Outside out          110
# Entire Cell           22
# Name: post patch class, dtype: int64

# %%
#Not sure about this just experimenting, refer to Rusty's example of Post patch by cre-line
#Dropping specific columns that are labeled within the brackets
#You don't need to add labels or axis, that is how the method is labeled, press shift+tab to check

ps0 = ps.drop(labels = ["Post patch?", "PCR cycles", "SM_QC_PF", "Bad dates"], axis = 1)
ps0.head()
#Created a new csv with the updated ps0 
#ps0.to_csv("depth_post")
# Out:
#            Date Depth (um) Nucleus sucked in?  Post patch pipette R  \
# 4971 2017-04-19       24.5                NaN                   NaN
# 4973 2017-04-19       17.6                NaN                   NaN
# 4975 2017-04-19       40.2                NaN                   NaN
# 4988 2017-04-20       56.2                NaN                   NaN
# 4997 2017-04-20       55.4                NaN                   NaN
#
#      post patch class
# 4971        Nucleated
# 4973        Nucleated
# 4975        Nucleated
# 4988        Nucleated
# 4997        Nucleated

# %%
#6875 Outlier, Depth = 675
ps.sort_index().tail(600)
# Out:
#            Date Depth (um)      Post patch? Nucleus sucked in?  \
# 6875 2017-08-07        675          No-Seal                NaN
# 6876 2017-08-07       33.8        Nucleated                NaN
# 6877 2017-08-07       39.9          No-Seal                NaN
# 6878 2017-08-07       59.8          No-Seal                NaN
# 6881 2017-08-07        NaN          No-Seal                NaN
# 6882 2017-08-07        NaN        Nucleated                NaN
# 6883 2017-08-07        NaN          No-Seal                NaN
# 6884 2017-08-07         33  Partial-Nucleus                NaN
# 6885 2017-08-07         54        Nucleated                NaN
# 6886 2017-08-07         71  Partial-Nucleus                NaN
# 6893 2017-08-08       36.1      Outside-Out                NaN
# 6894 2017-08-08       32.6        Nucleated                NaN
# 6895 2017-08-08       37.1        Nucleated                NaN
# 6896 2017-08-08       52.4          No-Seal                NaN
# 6897 2017-08-08       53.6        Nucleated                NaN
# 6898 2017-08-08       52.2          No-Seal                NaN
# 6899 2017-08-08       63.3          No-Seal                NaN
# 6902 2017-08-08       39.7          No-Seal                NaN
# 6903 2017-08-08         25          No-Seal                NaN
# 6904 2017-08-08       21.4          No-Seal                NaN
# 6905 2017-08-08       23.7          No-Seal                NaN
# 6906 2017-08-08       81.7        Nucleated                NaN
# 6907 2017-08-08       61.5  Partial-Nucleus                NaN
# 6908 2017-08-08       80.6          No-Seal                NaN
# 6909 2017-08-08       32.1        Nucleated                NaN
# 6910 2017-08-08       21.8          No-Seal                NaN
# 6913 2017-08-08       43.8  Partial-Nucleus                NaN
# 6914 2017-08-08       39.9        Nucleated                NaN
# 6915 2017-08-08       29.4          No-Seal                NaN
# 6916 2017-08-08       33.7          No-Seal                NaN
# ...         ...        ...              ...                ...
# 7567 2017-10-16        NaN   nucleus_absent                 no
# 7568 2017-10-16        NaN  nucleus_present  not_intentionally
# 7569 2017-10-16        NaN  nucleus_present  not_intentionally
# 7570 2017-10-16        NaN   nucleus_absent                 no
# 7571 2017-10-16        NaN  nucleus_present  not_intentionally
# 7572 2017-10-16        NaN  nucleus_present                 no
# 7573 2017-10-16        NaN  nucleus_present                 no
# 7574 2017-10-16        NaN  nucleus_present                 no
# 7575 2017-10-16        NaN  nucleus_present                 no
# 7576 2017-10-16        NaN  nucleus_present                 no
# 7577 2017-10-16        NaN  nucleus_present                 no
# 7578 2017-10-17        NaN   nucleus_absent                 no
# 7579 2017-10-17        NaN   nucleus_absent                 no
# 7580 2017-10-17        NaN  nucleus_present                 no
# 7581 2017-10-17        NaN   nucleus_absent                 no
# 7582 2017-10-17        NaN  nucleus_present                 no
# 7583 2017-10-17        NaN   nucleus_absent                 no
# 7584 2017-10-18        NaN  nucleus_present  not_intentionally
# 7585 2017-10-18        NaN   nucleus_absent                 no
# 7586 2017-10-18        NaN  nucleus_present                 no
# 7587 2017-10-18        NaN      entire_cell                 no
# 7588 2017-10-18        NaN      entire_cell                 no
# 7589 2017-10-18        NaN   nucleus_absent                 no
# 7590 2017-10-18        NaN   nucleus_absent                 no
# 7591 2017-10-18        NaN   nucleus_absent                 no
# 7592 2017-10-18        NaN  nucleus_present      intentionally
# 7593 2017-10-18        NaN  nucleus_present  not_intentionally
# 7594 2017-10-18        NaN   nucleus_absent                 no
# 7595 2017-10-18        NaN  nucleus_present      intentionally
# 7596 2017-10-18        NaN  nucleus_present                 no
#
#       Post patch pipette R  PCR cycles SM_QC_PF Bad dates   post patch class
# 6875                   NaN        21.0     pass       NaN            No seal
# 6876                   NaN        21.0     pass       NaN          Nucleated
# 6877                   NaN        21.0     pass       NaN            No seal
# 6878                   NaN        21.0     pass       NaN            No seal
# 6881                   NaN        21.0     fail       NaN            No seal
# 6882                   NaN        21.0     fail       NaN          Nucleated
# 6883                   NaN        21.0     pass       NaN            No seal
# 6884                   NaN        21.0     pass       NaN  Partial nucleated
# 6885                   NaN        21.0     pass       NaN          Nucleated
# 6886                   NaN        21.0     pass       NaN  Partial nucleated
# 6893                   NaN        21.0     fail       NaN        Outside out
# 6894                   NaN        21.0     pass       NaN          Nucleated
# 6895                   NaN        21.0     pass       NaN          Nucleated
# 6896                   NaN        21.0     fail       NaN            No seal
# 6897                   NaN        21.0     pass       NaN          Nucleated
# 6898                   NaN        21.0     pass       NaN            No seal
# 6899                   NaN        21.0     pass       NaN            No seal
# 6902                   NaN        21.0     pass       NaN            No seal
# 6903                   NaN        21.0     pass       NaN            No seal
# 6904                   NaN        21.0     pass       NaN            No seal
# 6905                   NaN        21.0     pass       NaN            No seal
# 6906                   NaN        21.0     pass       NaN          Nucleated
# 6907                   NaN        21.0     pass       NaN  Partial nucleated
# 6908                   NaN        21.0     pass       NaN            No seal
# 6909                   NaN        21.0     pass       NaN          Nucleated
# 6910                   NaN        21.0     fail       NaN            No seal
# 6913                   NaN        21.0     pass       NaN  Partial nucleated
# 6914                   NaN        21.0     pass       NaN          Nucleated
# 6915                   NaN        21.0     pass       NaN            No seal
# 6916                   NaN        21.0     pass       NaN            No seal
# ...                    ...         ...      ...       ...                ...
# 7567                 300.0        21.0     fail       NaN            No seal
# 7568                   3.0        21.0     fail       NaN  Partial nucleated
# 7569                   3.6        21.0     pass       NaN  Partial nucleated
# 7570                   3.5        21.0     fail       NaN            No seal
# 7571                   6.0        21.0     pass       NaN  Partial nucleated
# 7572                1000.0        21.0     fail       NaN          Nucleated
# 7573                2000.0        21.0     pass       NaN          Nucleated
# 7574                2000.0        21.0     pass       NaN          Nucleated
# 7575                2000.0        21.0     pass       NaN          Nucleated
# 7576                2000.0        21.0     pass       NaN          Nucleated
# 7577                1000.0        21.0     pass       NaN          Nucleated
# 7578                  10.0        21.0     fail       NaN            No seal
# 7579                  15.0        21.0     pass       NaN            No seal
# 7580                1500.0        21.0     pass       NaN          Nucleated
# 7581                  50.0        21.0     fail       NaN            No seal
# 7582                1000.0        21.0     pass       NaN          Nucleated
# 7583                  10.0        21.0     pass       NaN            No seal
# 7584                  10.0        21.0     fail       NaN  Partial nucleated
# 7585                   4.0        21.0     fail       NaN            No seal
# 7586                1000.0        21.0     pass       NaN          Nucleated
# 7587                   7.0        21.0     fail       NaN        Entire Cell
# 7588                  10.0        21.0     pass       NaN        Entire Cell
# 7589                  10.0        21.0     fail       NaN            No seal
# 7590                  10.0        21.0     pass       NaN            No seal
# 7591                   5.0        21.0     fail       NaN            No seal
# 7592                 100.0        21.0     fail       NaN  Partial nucleated
# 7593                  20.0        21.0     pass       NaN  Partial nucleated
# 7594                  10.0        21.0     pass       NaN            No seal
# 7595                1000.0        21.0     pass       NaN          Nucleated
# 7596                1000.0        21.0     pass       NaN          Nucleated
#
# [600 rows x 9 columns]

# %% [markdown]
# ## End of Trial & Error Section

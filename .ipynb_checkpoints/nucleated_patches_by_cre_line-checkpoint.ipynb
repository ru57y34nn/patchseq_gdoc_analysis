# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline
sns.set(style='whitegrid', color_codes = True)

# %%
ps = pd.read_csv('patch_seq_log_mouse.csv')

# %%
ps = ps[['Date', 'Slice (Lims ID?)', 'Post patch?', 'Post patch pipette R' , 'PCR cycles', 'SM_QC_PF', 'Bad dates']]
ps = ps[ps['PCR cycles'] == 21]
ps['Date'] = pd.to_datetime(ps['Date'], format = '%y%m%d')
ps = ps[ps['Bad dates'] != 'x']
ps = ps.drop('Bad dates', 1)
ps = ps[ps['SM_QC_PF'] != 'cnt']
ps.dropna(subset = ['Post patch?', 'SM_QC_PF'], inplace = True)
ps['Post patch?'] = ps['Post patch?'].astype('category')

# %%
ps.head()
# Out:
#            Date                Slice (Lims ID?)  Post patch?  \
# 4968 2017-04-19  Sst-IRES-Cre;Ai14-313562.03.02  Outside-Out
# 4969 2017-04-19  Sst-IRES-Cre;Ai14-313562.03.02  Outside-Out
# 4970 2017-04-19  Sst-IRES-Cre;Ai14-313562.04.02      No-Seal
# 4971 2017-04-19  Sst-IRES-Cre;Ai14-313562.04.02    Nucleated
# 4972 2017-04-19  Sst-IRES-Cre;Ai14-313562.04.02  Outside-Out
#
#       Post patch pipette R  PCR cycles SM_QC_PF
# 4968                   NaN        21.0     fail
# 4969                   NaN        21.0     pass
# 4970                   NaN        21.0     fail
# 4971                   NaN        21.0     pass
# 4972                   NaN        21.0     pass

# %%
def nucleated(x):
    nucleus = x[(x["Post patch?"] == "Nucleated") | (((x["Post patch?"] == "nucleus_visible") | (x["Post patch?"] == "nucleus_present")) & (x["Post patch pipette R"] >= 500))]
    return nucleus

def partial_nucleated(y):
    partial = y[(y["Post patch?"] == 'Partial-Nucleus') | (((y['Post patch?'] == 'nucleus_present') | (y['Post patch?'] == 'nucleus_visible')) & (y["Post patch pipette R"] <= 499))]
    return partial

def outside_out(z):
    outside = z[(z["Post patch?"] == 'Outside-Out') | (((z['Post patch?'] == 'nucleus_absent') | (z['Post patch?'] == 'no_nuclues_visible')) & (z['Post patch pipette R'] >= 500))]
    return outside

def no_seal(w): 
    no = w[(w["Post patch?"] == 'No-Seal') | (((w['Post patch?'] == 'nucleus_absent') | (w['Post patch?'] == 'no_nucleus_visible')) & (w['Post patch pipette R'] <= 499))]
    return no
    
def entire_cell(v):
    entire = v[(v["Post patch?"] == 'Entire-Cell') | (v['Post patch?'] == 'entire_cell')]
    return entire

# %%
nuc = nucleated(ps)
nuc["post patch class"] = "Nucleated"
part_nuc = partial_nucleated(ps)
part_nuc["post patch class"] = "Partial nucleated"
out_out = outside_out(ps)
out_out["post patch class"] = "Outside out"
noSeal = no_seal(ps)
noSeal["post patch class"] = "No seal"
entirecell = entire_cell(ps)
entirecell['post patch class'] = "Entire cell"
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
frames = [nuc, part_nuc, out_out, noSeal, entirecell]
ps = pd.concat(frames)
ps
# Out:
#            Date                                   Slice (Lims ID?)  \
# 4971 2017-04-19                     Sst-IRES-Cre;Ai14-313562.04.02
# 4973 2017-04-19                     Sst-IRES-Cre;Ai14-313562.04.02
# 4975 2017-04-19                     Sst-IRES-Cre;Ai14-313562.02.02
# 4988 2017-04-20                     Vip-IRES-Cre;Ai14-313534.03.01
# 4997 2017-04-20                     Vip-IRES-Cre;Ai14-313534.05.01
# 5009 2017-04-20                     Vip-IRES-Cre;Ai14-313534.04.01
# 5022 2017-04-21                    Gad2-IRES-Cre;Ai14-313294.04.01
# 5026 2017-04-21                    Gad2-IRES-Cre;Ai14-313294.03.02
# 5027 2017-04-21                    Gad2-IRES-Cre;Ai14-313294.03.02
# 5035 2017-04-21                    Gad2-IRES-Cre;Ai14-313294.05.01
# 5045 2017-04-24                   Scnn1a-Tg3-Cre;Ai14-315865.04.01
# 5051 2017-04-24                   Rorb-IRES2-Cre;Ai14-315898.03.01
# 5058 2017-04-24                   Scnn1a-Tg3-Cre;Ai14-315865.04.02
# 5063 2017-04-24                   Rorb-IRES2-Cre;Ai14-315898.04.02
# 5073 2017-04-25                   Rorb-IRES2-Cre;Ai14-315897.04.01
# 5084 2017-04-25                   Rorb-IRES2-Cre;Ai14-315897.04.02
# 5085 2017-04-25                   Rorb-IRES2-Cre;Ai14-315897.04.02
# 5089 2017-04-25                   Rorb-IRES2-Cre;Ai14-315897.05.02
# 5111 2017-04-26                   Scnn1a-Tg3-Cre;Ai14-315863.03.02
# 5114 2017-04-26                   Rorb-IRES2-Cre;Ai14-315895.03.01
# 5117 2017-04-26                   Rorb-IRES2-Cre;Ai14-315895.04.02
# 5134 2017-04-27                   Rorb-IRES2-Cre;Ai14-315894.05.01
# 5146 2017-04-27                   Rorb-IRES2-Cre;Ai14-315894.05.02
# 5154 2017-04-28                   Scnn1a-Tg3-Cre;Ai14-315862.04.01
# 5164 2017-04-28                   Scnn1a-Tg3-Cre;Ai14-315862.04.02
# 5166 2017-04-28                   Scnn1a-Tg3-Cre;Ai14-315862.04.02
# 5184 2017-05-01               Rorb-IRES2-Cre-neo;Ai14-315666.04.02
# 5185 2017-05-01               Rorb-IRES2-Cre-neo;Ai14-315666.04.02
# 5186 2017-05-01               Rorb-IRES2-Cre-neo;Ai14-315666.04.02
# 5189 2017-05-01               Rorb-IRES2-Cre-neo;Ai14-315666.04.01
# ...         ...                                                ...
# 7579 2017-10-17                 Pdyn-T2A-CreERT2;Ai14-353887.04.01
# 7581 2017-10-17                  Chrna2-Cre_OE25;Ai14-355017.05.02
# 7583 2017-10-17                 Pdyn-T2A-CreERT2;Ai14-353887.03.02
# 7585 2017-10-18                        Nr5a1-Cre;Ai14-355060.04.01
# 7589 2017-10-18                        Nr5a1-Cre;Ai14-355060.03.02
# 7590 2017-10-18                        Nr5a1-Cre;Ai14-355060.03.02
# 7591 2017-10-18                        Nr5a1-Cre;Ai14-355060.03.02
# 7594 2017-10-18       Nos1-CreERT2;Sst-IRES-FlpO;Ai65-353543.04.02
# 5002 2017-04-20                     Vip-IRES-Cre;Ai14-313534.03.02
# 5088 2017-04-25                   Rorb-IRES2-Cre;Ai14-315897.05.02
# 5242 2017-05-02               Rorb-IRES2-Cre-neo;Ai14-315667.02.02
# 5269 2017-05-03                   Scnn1a-Tg2-Cre;Ai14-316319.05.02
# 5273 2017-05-03                Chat-IRES-Cre-neo;Ai14-316042.01.02
# 5274 2017-05-03                Chat-IRES-Cre-neo;Ai14-316042.01.02
# 5369 2017-05-10                   Rorb-IRES2-Cre;Ai14-318659.02.01
# 5532 2017-05-18                   Pvalb-IRES-Cre;Ai14-316465.03.01
# 5623 2017-05-24                 Slc32a1-IRES-Cre;Ai14-321267.02.02
# 5687 2017-06-01                     Vip-IRES-Cre;Ai14-322780.05.01
# 5847 2017-06-13                    Gad2-IRES-Cre;Ai14-326032.05.01
# 6814 2017-08-02  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-337417.0...
# 6963 2017-08-09  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-338919.0...
# 7076 2017-08-25                Chat-IRES-Cre-neo;Ai14-341891.05.02
# 7094 2017-08-29                     Vip-IRES-Cre;Ai14-342919.04.02
# 7272 2017-09-22                     Vip-IRES-Cre;Ai14-348725.06.01
# 7308 2017-09-26                 Slc32a1-IRES-Cre;Ai14-347204.05.01
# 7410 2017-10-04                     Oxtr-T2A-Cre;Ai14-351471.03.02
# 7447 2017-10-05                     Oxtr-T2A-Cre;Ai14-351472.04.02
# 7455 2017-10-05                     Oxtr-T2A-Cre;Ai14-351472.04.01
# 7587 2017-10-18                  Chrna2-Cre_OE25;Ai14-355475.04.02
# 7588 2017-10-18                  Chrna2-Cre_OE25;Ai14-355475.04.02
#
#          Post patch?  Post patch pipette R  PCR cycles SM_QC_PF  \
# 4971       Nucleated                   NaN        21.0     pass
# 4973       Nucleated                   NaN        21.0     pass
# 4975       Nucleated                   NaN        21.0     pass
# 4988       Nucleated                   NaN        21.0     pass
# 4997       Nucleated                   NaN        21.0     pass
# 5009       Nucleated                   NaN        21.0     pass
# 5022       Nucleated                   NaN        21.0     pass
# 5026       Nucleated                   NaN        21.0     pass
# 5027       Nucleated                   NaN        21.0     pass
# 5035       Nucleated                   NaN        21.0     pass
# 5045       Nucleated                   NaN        21.0     pass
# 5051       Nucleated                   NaN        21.0     pass
# 5058       Nucleated                   NaN        21.0     pass
# 5063       Nucleated                   NaN        21.0     pass
# 5073       Nucleated                   NaN        21.0     pass
# 5084       Nucleated                   NaN        21.0     pass
# 5085       Nucleated                   NaN        21.0     pass
# 5089       Nucleated                   NaN        21.0     pass
# 5111       Nucleated                   NaN        21.0     pass
# 5114       Nucleated                   NaN        21.0     pass
# 5117       Nucleated                   NaN        21.0     pass
# 5134       Nucleated                   NaN        21.0     pass
# 5146       Nucleated                   NaN        21.0     pass
# 5154       Nucleated                   NaN        21.0     pass
# 5164       Nucleated                   NaN        21.0     pass
# 5166       Nucleated                   NaN        21.0     pass
# 5184       Nucleated                   NaN        21.0     pass
# 5185       Nucleated                   NaN        21.0     pass
# 5186       Nucleated                   NaN        21.0     pass
# 5189       Nucleated                   NaN        21.0     pass
# ...              ...                   ...         ...      ...
# 7579  nucleus_absent                  15.0        21.0     pass
# 7581  nucleus_absent                  50.0        21.0     fail
# 7583  nucleus_absent                  10.0        21.0     pass
# 7585  nucleus_absent                   4.0        21.0     fail
# 7589  nucleus_absent                  10.0        21.0     fail
# 7590  nucleus_absent                  10.0        21.0     pass
# 7591  nucleus_absent                   5.0        21.0     fail
# 7594  nucleus_absent                  10.0        21.0     pass
# 5002     Entire-Cell                   NaN        21.0     pass
# 5088     Entire-Cell                   NaN        21.0     pass
# 5242     Entire-Cell                   NaN        21.0     pass
# 5269     Entire-Cell                   NaN        21.0     fail
# 5273     Entire-Cell                   NaN        21.0     pass
# 5274     Entire-Cell                   NaN        21.0     pass
# 5369     Entire-Cell                   NaN        21.0     pass
# 5532     Entire-Cell                   NaN        21.0     pass
# 5623     Entire-Cell                   NaN        21.0     fail
# 5687     Entire-Cell                   NaN        21.0     pass
# 5847     Entire-Cell                   NaN        21.0     pass
# 6814     Entire-Cell                   NaN        21.0     pass
# 6963     Entire-Cell                   NaN        21.0     pass
# 7076     Entire-Cell                   NaN        21.0     pass
# 7094     Entire-Cell                   NaN        21.0     pass
# 7272     Entire-Cell                   NaN        21.0     pass
# 7308     Entire-Cell                   NaN        21.0     pass
# 7410     entire_cell                  10.0        21.0     fail
# 7447     entire_cell                 100.0        21.0     pass
# 7455     entire_cell                   5.0        21.0     pass
# 7587     entire_cell                   7.0        21.0     fail
# 7588     entire_cell                  10.0        21.0     pass
#
#      post patch class
# 4971        Nucleated
# 4973        Nucleated
# 4975        Nucleated
# 4988        Nucleated
# 4997        Nucleated
# 5009        Nucleated
# 5022        Nucleated
# 5026        Nucleated
# 5027        Nucleated
# 5035        Nucleated
# 5045        Nucleated
# 5051        Nucleated
# 5058        Nucleated
# 5063        Nucleated
# 5073        Nucleated
# 5084        Nucleated
# 5085        Nucleated
# 5089        Nucleated
# 5111        Nucleated
# 5114        Nucleated
# 5117        Nucleated
# 5134        Nucleated
# 5146        Nucleated
# 5154        Nucleated
# 5164        Nucleated
# 5166        Nucleated
# 5184        Nucleated
# 5185        Nucleated
# 5186        Nucleated
# 5189        Nucleated
# ...               ...
# 7579          No seal
# 7581          No seal
# 7583          No seal
# 7585          No seal
# 7589          No seal
# 7590          No seal
# 7591          No seal
# 7594          No seal
# 5002      Entire cell
# 5088      Entire cell
# 5242      Entire cell
# 5269      Entire cell
# 5273      Entire cell
# 5274      Entire cell
# 5369      Entire cell
# 5532      Entire cell
# 5623      Entire cell
# 5687      Entire cell
# 5847      Entire cell
# 6814      Entire cell
# 6963      Entire cell
# 7076      Entire cell
# 7094      Entire cell
# 7272      Entire cell
# 7308      Entire cell
# 7410      Entire cell
# 7447      Entire cell
# 7455      Entire cell
# 7587      Entire cell
# 7588      Entire cell
#
# [1859 rows x 7 columns]

# %%
ps['Cre_line'] = ps['Slice (Lims ID?)'].str[:-18]
ps = ps.drop('Slice (Lims ID?)', 1)
ps
# Out:
#            Date     Post patch?  Post patch pipette R  PCR cycles SM_QC_PF  \
# 4971 2017-04-19       Nucleated                   NaN        21.0     pass
# 4973 2017-04-19       Nucleated                   NaN        21.0     pass
# 4975 2017-04-19       Nucleated                   NaN        21.0     pass
# 4988 2017-04-20       Nucleated                   NaN        21.0     pass
# 4997 2017-04-20       Nucleated                   NaN        21.0     pass
# 5009 2017-04-20       Nucleated                   NaN        21.0     pass
# 5022 2017-04-21       Nucleated                   NaN        21.0     pass
# 5026 2017-04-21       Nucleated                   NaN        21.0     pass
# 5027 2017-04-21       Nucleated                   NaN        21.0     pass
# 5035 2017-04-21       Nucleated                   NaN        21.0     pass
# 5045 2017-04-24       Nucleated                   NaN        21.0     pass
# 5051 2017-04-24       Nucleated                   NaN        21.0     pass
# 5058 2017-04-24       Nucleated                   NaN        21.0     pass
# 5063 2017-04-24       Nucleated                   NaN        21.0     pass
# 5073 2017-04-25       Nucleated                   NaN        21.0     pass
# 5084 2017-04-25       Nucleated                   NaN        21.0     pass
# 5085 2017-04-25       Nucleated                   NaN        21.0     pass
# 5089 2017-04-25       Nucleated                   NaN        21.0     pass
# 5111 2017-04-26       Nucleated                   NaN        21.0     pass
# 5114 2017-04-26       Nucleated                   NaN        21.0     pass
# 5117 2017-04-26       Nucleated                   NaN        21.0     pass
# 5134 2017-04-27       Nucleated                   NaN        21.0     pass
# 5146 2017-04-27       Nucleated                   NaN        21.0     pass
# 5154 2017-04-28       Nucleated                   NaN        21.0     pass
# 5164 2017-04-28       Nucleated                   NaN        21.0     pass
# 5166 2017-04-28       Nucleated                   NaN        21.0     pass
# 5184 2017-05-01       Nucleated                   NaN        21.0     pass
# 5185 2017-05-01       Nucleated                   NaN        21.0     pass
# 5186 2017-05-01       Nucleated                   NaN        21.0     pass
# 5189 2017-05-01       Nucleated                   NaN        21.0     pass
# ...         ...             ...                   ...         ...      ...
# 7579 2017-10-17  nucleus_absent                  15.0        21.0     pass
# 7581 2017-10-17  nucleus_absent                  50.0        21.0     fail
# 7583 2017-10-17  nucleus_absent                  10.0        21.0     pass
# 7585 2017-10-18  nucleus_absent                   4.0        21.0     fail
# 7589 2017-10-18  nucleus_absent                  10.0        21.0     fail
# 7590 2017-10-18  nucleus_absent                  10.0        21.0     pass
# 7591 2017-10-18  nucleus_absent                   5.0        21.0     fail
# 7594 2017-10-18  nucleus_absent                  10.0        21.0     pass
# 5002 2017-04-20     Entire-Cell                   NaN        21.0     pass
# 5088 2017-04-25     Entire-Cell                   NaN        21.0     pass
# 5242 2017-05-02     Entire-Cell                   NaN        21.0     pass
# 5269 2017-05-03     Entire-Cell                   NaN        21.0     fail
# 5273 2017-05-03     Entire-Cell                   NaN        21.0     pass
# 5274 2017-05-03     Entire-Cell                   NaN        21.0     pass
# 5369 2017-05-10     Entire-Cell                   NaN        21.0     pass
# 5532 2017-05-18     Entire-Cell                   NaN        21.0     pass
# 5623 2017-05-24     Entire-Cell                   NaN        21.0     fail
# 5687 2017-06-01     Entire-Cell                   NaN        21.0     pass
# 5847 2017-06-13     Entire-Cell                   NaN        21.0     pass
# 6814 2017-08-02     Entire-Cell                   NaN        21.0     pass
# 6963 2017-08-09     Entire-Cell                   NaN        21.0     pass
# 7076 2017-08-25     Entire-Cell                   NaN        21.0     pass
# 7094 2017-08-29     Entire-Cell                   NaN        21.0     pass
# 7272 2017-09-22     Entire-Cell                   NaN        21.0     pass
# 7308 2017-09-26     Entire-Cell                   NaN        21.0     pass
# 7410 2017-10-04     entire_cell                  10.0        21.0     fail
# 7447 2017-10-05     entire_cell                 100.0        21.0     pass
# 7455 2017-10-05     entire_cell                   5.0        21.0     pass
# 7587 2017-10-18     entire_cell                   7.0        21.0     fail
# 7588 2017-10-18     entire_cell                  10.0        21.0     pass
#
#      post patch class                          Cre_line
# 4971        Nucleated                      Sst-IRES-Cre
# 4973        Nucleated                      Sst-IRES-Cre
# 4975        Nucleated                      Sst-IRES-Cre
# 4988        Nucleated                      Vip-IRES-Cre
# 4997        Nucleated                      Vip-IRES-Cre
# 5009        Nucleated                      Vip-IRES-Cre
# 5022        Nucleated                     Gad2-IRES-Cre
# 5026        Nucleated                     Gad2-IRES-Cre
# 5027        Nucleated                     Gad2-IRES-Cre
# 5035        Nucleated                     Gad2-IRES-Cre
# 5045        Nucleated                    Scnn1a-Tg3-Cre
# 5051        Nucleated                    Rorb-IRES2-Cre
# 5058        Nucleated                    Scnn1a-Tg3-Cre
# 5063        Nucleated                    Rorb-IRES2-Cre
# 5073        Nucleated                    Rorb-IRES2-Cre
# 5084        Nucleated                    Rorb-IRES2-Cre
# 5085        Nucleated                    Rorb-IRES2-Cre
# 5089        Nucleated                    Rorb-IRES2-Cre
# 5111        Nucleated                    Scnn1a-Tg3-Cre
# 5114        Nucleated                    Rorb-IRES2-Cre
# 5117        Nucleated                    Rorb-IRES2-Cre
# 5134        Nucleated                    Rorb-IRES2-Cre
# 5146        Nucleated                    Rorb-IRES2-Cre
# 5154        Nucleated                    Scnn1a-Tg3-Cre
# 5164        Nucleated                    Scnn1a-Tg3-Cre
# 5166        Nucleated                    Scnn1a-Tg3-Cre
# 5184        Nucleated                Rorb-IRES2-Cre-neo
# 5185        Nucleated                Rorb-IRES2-Cre-neo
# 5186        Nucleated                Rorb-IRES2-Cre-neo
# 5189        Nucleated                Rorb-IRES2-Cre-neo
# ...               ...                               ...
# 7579          No seal                  Pdyn-T2A-CreERT2
# 7581          No seal                   Chrna2-Cre_OE25
# 7583          No seal                  Pdyn-T2A-CreERT2
# 7585          No seal                         Nr5a1-Cre
# 7589          No seal                         Nr5a1-Cre
# 7590          No seal                         Nr5a1-Cre
# 7591          No seal                         Nr5a1-Cre
# 7594          No seal        Nos1-CreERT2;Sst-IRES-FlpO
# 5002      Entire cell                      Vip-IRES-Cre
# 5088      Entire cell                    Rorb-IRES2-Cre
# 5242      Entire cell                Rorb-IRES2-Cre-neo
# 5269      Entire cell                    Scnn1a-Tg2-Cre
# 5273      Entire cell                 Chat-IRES-Cre-neo
# 5274      Entire cell                 Chat-IRES-Cre-neo
# 5369      Entire cell                    Rorb-IRES2-Cre
# 5532      Entire cell                    Pvalb-IRES-Cre
# 5623      Entire cell                  Slc32a1-IRES-Cre
# 5687      Entire cell                      Vip-IRES-Cre
# 5847      Entire cell                     Gad2-IRES-Cre
# 6814      Entire cell  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO
# 6963      Entire cell  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO
# 7076      Entire cell                 Chat-IRES-Cre-neo
# 7094      Entire cell                      Vip-IRES-Cre
# 7272      Entire cell                      Vip-IRES-Cre
# 7308      Entire cell                  Slc32a1-IRES-Cre
# 7410      Entire cell                      Oxtr-T2A-Cre
# 7447      Entire cell                      Oxtr-T2A-Cre
# 7455      Entire cell                      Oxtr-T2A-Cre
# 7587      Entire cell                   Chrna2-Cre_OE25
# 7588      Entire cell                   Chrna2-Cre_OE25
#
# [1859 rows x 7 columns]

# %%
ps0 = ps.drop('Post patch?', 1)
ps0 = ps.drop('PCR cycles', 1)
ps0 = ps.drop('SM_QC_PF', 1)

# %%
ps0.to_csv('cre_nuc.csv')

# %%
ps['Cre_line'].value_counts()
#ps['Cre line'].sort_values()
# Out:
# Gad2-IRES-Cre                       255
# Slc32a1-IRES-Cre                    253
# Vip-IRES-Cre                        225
# Rbp4-Cre_KL100                      130
# Rorb-IRES2-Cre                      128
# Pvalb-IRES-Cre                      118
# Sst-IRES-Cre                        100
# Oxtr-T2A-Cre                         71
# Chrna2-Cre_OE25                      67
# Scnn1a-Tg3-Cre                       62
# Cux2-CreERT2                         60
# Nr5a1-Cre                            60
# Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO     59
# Rorb-IRES2-Cre-neo                   51
# Scnn1a-Tg2-Cre                       32
# Ctgf-T2A-dgCre                       30
# Chat-IRES-Cre-neo                    27
# Htr3a-Cre_NO152                      19
# Ndnf-IRES2-dgCre                     19
# Htr3a-Cre_NO152;Pvalb-T2A-Dre        16
# Slc17a8-IRES2-Cre                    15
# Pdyn-T2A-CreERT2                     13
# Glt25d2-Cre_NF107                    12
# Nos1-CreERT2;Sst-IRES-FlpO           10
# Nkx2-1-CreERT2                        9
# Sim1-Cre_KJ18                         9
# Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        6
# Vipr2-IRES2-Cre-neo                   3
# Name: Cre_line, dtype: int64

# %%
ps.groupby(['Cre_line'])['post patch class'].value_counts()
ps
# Out:
#            Date     Post patch?  Post patch pipette R  PCR cycles SM_QC_PF  \
# 4971 2017-04-19       Nucleated                   NaN        21.0     pass
# 4973 2017-04-19       Nucleated                   NaN        21.0     pass
# 4975 2017-04-19       Nucleated                   NaN        21.0     pass
# 4988 2017-04-20       Nucleated                   NaN        21.0     pass
# 4997 2017-04-20       Nucleated                   NaN        21.0     pass
# 5009 2017-04-20       Nucleated                   NaN        21.0     pass
# 5022 2017-04-21       Nucleated                   NaN        21.0     pass
# 5026 2017-04-21       Nucleated                   NaN        21.0     pass
# 5027 2017-04-21       Nucleated                   NaN        21.0     pass
# 5035 2017-04-21       Nucleated                   NaN        21.0     pass
# 5045 2017-04-24       Nucleated                   NaN        21.0     pass
# 5051 2017-04-24       Nucleated                   NaN        21.0     pass
# 5058 2017-04-24       Nucleated                   NaN        21.0     pass
# 5063 2017-04-24       Nucleated                   NaN        21.0     pass
# 5073 2017-04-25       Nucleated                   NaN        21.0     pass
# 5084 2017-04-25       Nucleated                   NaN        21.0     pass
# 5085 2017-04-25       Nucleated                   NaN        21.0     pass
# 5089 2017-04-25       Nucleated                   NaN        21.0     pass
# 5111 2017-04-26       Nucleated                   NaN        21.0     pass
# 5114 2017-04-26       Nucleated                   NaN        21.0     pass
# 5117 2017-04-26       Nucleated                   NaN        21.0     pass
# 5134 2017-04-27       Nucleated                   NaN        21.0     pass
# 5146 2017-04-27       Nucleated                   NaN        21.0     pass
# 5154 2017-04-28       Nucleated                   NaN        21.0     pass
# 5164 2017-04-28       Nucleated                   NaN        21.0     pass
# 5166 2017-04-28       Nucleated                   NaN        21.0     pass
# 5184 2017-05-01       Nucleated                   NaN        21.0     pass
# 5185 2017-05-01       Nucleated                   NaN        21.0     pass
# 5186 2017-05-01       Nucleated                   NaN        21.0     pass
# 5189 2017-05-01       Nucleated                   NaN        21.0     pass
# ...         ...             ...                   ...         ...      ...
# 7579 2017-10-17  nucleus_absent                  15.0        21.0     pass
# 7581 2017-10-17  nucleus_absent                  50.0        21.0     fail
# 7583 2017-10-17  nucleus_absent                  10.0        21.0     pass
# 7585 2017-10-18  nucleus_absent                   4.0        21.0     fail
# 7589 2017-10-18  nucleus_absent                  10.0        21.0     fail
# 7590 2017-10-18  nucleus_absent                  10.0        21.0     pass
# 7591 2017-10-18  nucleus_absent                   5.0        21.0     fail
# 7594 2017-10-18  nucleus_absent                  10.0        21.0     pass
# 5002 2017-04-20     Entire-Cell                   NaN        21.0     pass
# 5088 2017-04-25     Entire-Cell                   NaN        21.0     pass
# 5242 2017-05-02     Entire-Cell                   NaN        21.0     pass
# 5269 2017-05-03     Entire-Cell                   NaN        21.0     fail
# 5273 2017-05-03     Entire-Cell                   NaN        21.0     pass
# 5274 2017-05-03     Entire-Cell                   NaN        21.0     pass
# 5369 2017-05-10     Entire-Cell                   NaN        21.0     pass
# 5532 2017-05-18     Entire-Cell                   NaN        21.0     pass
# 5623 2017-05-24     Entire-Cell                   NaN        21.0     fail
# 5687 2017-06-01     Entire-Cell                   NaN        21.0     pass
# 5847 2017-06-13     Entire-Cell                   NaN        21.0     pass
# 6814 2017-08-02     Entire-Cell                   NaN        21.0     pass
# 6963 2017-08-09     Entire-Cell                   NaN        21.0     pass
# 7076 2017-08-25     Entire-Cell                   NaN        21.0     pass
# 7094 2017-08-29     Entire-Cell                   NaN        21.0     pass
# 7272 2017-09-22     Entire-Cell                   NaN        21.0     pass
# 7308 2017-09-26     Entire-Cell                   NaN        21.0     pass
# 7410 2017-10-04     entire_cell                  10.0        21.0     fail
# 7447 2017-10-05     entire_cell                 100.0        21.0     pass
# 7455 2017-10-05     entire_cell                   5.0        21.0     pass
# 7587 2017-10-18     entire_cell                   7.0        21.0     fail
# 7588 2017-10-18     entire_cell                  10.0        21.0     pass
#
#      post patch class                          Cre_line
# 4971        Nucleated                      Sst-IRES-Cre
# 4973        Nucleated                      Sst-IRES-Cre
# 4975        Nucleated                      Sst-IRES-Cre
# 4988        Nucleated                      Vip-IRES-Cre
# 4997        Nucleated                      Vip-IRES-Cre
# 5009        Nucleated                      Vip-IRES-Cre
# 5022        Nucleated                     Gad2-IRES-Cre
# 5026        Nucleated                     Gad2-IRES-Cre
# 5027        Nucleated                     Gad2-IRES-Cre
# 5035        Nucleated                     Gad2-IRES-Cre
# 5045        Nucleated                    Scnn1a-Tg3-Cre
# 5051        Nucleated                    Rorb-IRES2-Cre
# 5058        Nucleated                    Scnn1a-Tg3-Cre
# 5063        Nucleated                    Rorb-IRES2-Cre
# 5073        Nucleated                    Rorb-IRES2-Cre
# 5084        Nucleated                    Rorb-IRES2-Cre
# 5085        Nucleated                    Rorb-IRES2-Cre
# 5089        Nucleated                    Rorb-IRES2-Cre
# 5111        Nucleated                    Scnn1a-Tg3-Cre
# 5114        Nucleated                    Rorb-IRES2-Cre
# 5117        Nucleated                    Rorb-IRES2-Cre
# 5134        Nucleated                    Rorb-IRES2-Cre
# 5146        Nucleated                    Rorb-IRES2-Cre
# 5154        Nucleated                    Scnn1a-Tg3-Cre
# 5164        Nucleated                    Scnn1a-Tg3-Cre
# 5166        Nucleated                    Scnn1a-Tg3-Cre
# 5184        Nucleated                Rorb-IRES2-Cre-neo
# 5185        Nucleated                Rorb-IRES2-Cre-neo
# 5186        Nucleated                Rorb-IRES2-Cre-neo
# 5189        Nucleated                Rorb-IRES2-Cre-neo
# ...               ...                               ...
# 7579          No seal                  Pdyn-T2A-CreERT2
# 7581          No seal                   Chrna2-Cre_OE25
# 7583          No seal                  Pdyn-T2A-CreERT2
# 7585          No seal                         Nr5a1-Cre
# 7589          No seal                         Nr5a1-Cre
# 7590          No seal                         Nr5a1-Cre
# 7591          No seal                         Nr5a1-Cre
# 7594          No seal        Nos1-CreERT2;Sst-IRES-FlpO
# 5002      Entire cell                      Vip-IRES-Cre
# 5088      Entire cell                    Rorb-IRES2-Cre
# 5242      Entire cell                Rorb-IRES2-Cre-neo
# 5269      Entire cell                    Scnn1a-Tg2-Cre
# 5273      Entire cell                 Chat-IRES-Cre-neo
# 5274      Entire cell                 Chat-IRES-Cre-neo
# 5369      Entire cell                    Rorb-IRES2-Cre
# 5532      Entire cell                    Pvalb-IRES-Cre
# 5623      Entire cell                  Slc32a1-IRES-Cre
# 5687      Entire cell                      Vip-IRES-Cre
# 5847      Entire cell                     Gad2-IRES-Cre
# 6814      Entire cell  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO
# 6963      Entire cell  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO
# 7076      Entire cell                 Chat-IRES-Cre-neo
# 7094      Entire cell                      Vip-IRES-Cre
# 7272      Entire cell                      Vip-IRES-Cre
# 7308      Entire cell                  Slc32a1-IRES-Cre
# 7410      Entire cell                      Oxtr-T2A-Cre
# 7447      Entire cell                      Oxtr-T2A-Cre
# 7455      Entire cell                      Oxtr-T2A-Cre
# 7587      Entire cell                   Chrna2-Cre_OE25
# 7588      Entire cell                   Chrna2-Cre_OE25
#
# [1859 rows x 7 columns]

# %%
ps = ps.drop('Date', 1)
ps = ps.drop('PCR cycles', 1)
ps = ps.drop('Post patch pipette R',1)
ps = ps.drop('Post patch?',1)
ps['post_patch'] = ps['SM_QC_PF']
ps = ps.drop('SM_QC_PF', 1)
#ps['total'] = ps['post_patch']
#ps.tail()

# %%
ps1 = ps.groupby(['Cre_line', 'post patch class']).count()
ps1
# Out:
#                                                     post_patch
# Cre_line                         post patch class
# Chat-IRES-Cre-neo                Entire cell                 3
#                                  No seal                    10
#                                  Nucleated                   5
#                                  Partial nucleated           9
# Chrna2-Cre_OE25                  Entire cell                 2
#                                  No seal                    22
#                                  Nucleated                  37
#                                  Outside out                 3
#                                  Partial nucleated           3
# Ctgf-T2A-dgCre                   No seal                    15
#                                  Nucleated                  13
#                                  Partial nucleated           2
# Cux2-CreERT2                     No seal                    21
#                                  Nucleated                  31
#                                  Outside out                 2
#                                  Partial nucleated           6
# Gad2-IRES-Cre                    Entire cell                 1
#                                  No seal                    98
#                                  Nucleated                 113
#                                  Outside out                13
#                                  Partial nucleated          30
# Glt25d2-Cre_NF107                No seal                     3
#                                  Nucleated                   8
#                                  Partial nucleated           1
# Htr3a-Cre_NO152                  No seal                     4
#                                  Nucleated                  14
#                                  Partial nucleated           1
# Htr3a-Cre_NO152;Pvalb-T2A-Dre    No seal                     5
#                                  Nucleated                   9
#                                  Outside out                 2
# ...                                                        ...
# Sim1-Cre_KJ18                    Nucleated                   4
#                                  Partial nucleated           1
# Slc17a8-IRES2-Cre                No seal                     3
#                                  Nucleated                   9
#                                  Outside out                 1
#                                  Partial nucleated           2
# Slc32a1-IRES-Cre                 Entire cell                 2
#                                  No seal                    78
#                                  Nucleated                 135
#                                  Outside out                 5
#                                  Partial nucleated          33
# Sst-IRES-Cre                     No seal                    35
#                                  Nucleated                  43
#                                  Outside out                11
#                                  Partial nucleated          11
# Vip-IRES-Cre                     Entire cell                 4
#                                  No seal                    83
#                                  Nucleated                 104
#                                  Outside out                14
#                                  Partial nucleated          20
# Vipr2-IRES2-Cre-neo              No seal                     1
#                                  Nucleated                   2
# Vipr2-IRES2-Cre;Pvalb-T2A-FlpO   No seal                     4
#                                  Outside out                 1
#                                  Partial nucleated           1
# Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO Entire cell                 2
#                                  No seal                    23
#                                  Nucleated                  16
#                                  Outside out                 1
#                                  Partial nucleated          17
#
# [108 rows x 1 columns]

# %%
type(ps1)
# Out:
# pandas.core.frame.DataFrame

# %%
ps1 = ps1.add_suffix('_count').reset_index()
ps1
# Out:
#                              Cre_line   post patch class  post_patch_count
# 0                   Chat-IRES-Cre-neo        Entire cell                 3
# 1                   Chat-IRES-Cre-neo            No seal                10
# 2                   Chat-IRES-Cre-neo          Nucleated                 5
# 3                   Chat-IRES-Cre-neo  Partial nucleated                 9
# 4                     Chrna2-Cre_OE25        Entire cell                 2
# 5                     Chrna2-Cre_OE25            No seal                22
# 6                     Chrna2-Cre_OE25          Nucleated                37
# 7                     Chrna2-Cre_OE25        Outside out                 3
# 8                     Chrna2-Cre_OE25  Partial nucleated                 3
# 9                      Ctgf-T2A-dgCre            No seal                15
# 10                     Ctgf-T2A-dgCre          Nucleated                13
# 11                     Ctgf-T2A-dgCre  Partial nucleated                 2
# 12                       Cux2-CreERT2            No seal                21
# 13                       Cux2-CreERT2          Nucleated                31
# 14                       Cux2-CreERT2        Outside out                 2
# 15                       Cux2-CreERT2  Partial nucleated                 6
# 16                      Gad2-IRES-Cre        Entire cell                 1
# 17                      Gad2-IRES-Cre            No seal                98
# 18                      Gad2-IRES-Cre          Nucleated               113
# 19                      Gad2-IRES-Cre        Outside out                13
# 20                      Gad2-IRES-Cre  Partial nucleated                30
# 21                  Glt25d2-Cre_NF107            No seal                 3
# 22                  Glt25d2-Cre_NF107          Nucleated                 8
# 23                  Glt25d2-Cre_NF107  Partial nucleated                 1
# 24                    Htr3a-Cre_NO152            No seal                 4
# 25                    Htr3a-Cre_NO152          Nucleated                14
# 26                    Htr3a-Cre_NO152  Partial nucleated                 1
# 27      Htr3a-Cre_NO152;Pvalb-T2A-Dre            No seal                 5
# 28      Htr3a-Cre_NO152;Pvalb-T2A-Dre          Nucleated                 9
# 29      Htr3a-Cre_NO152;Pvalb-T2A-Dre        Outside out                 2
# ..                                ...                ...               ...
# 78                      Sim1-Cre_KJ18          Nucleated                 4
# 79                      Sim1-Cre_KJ18  Partial nucleated                 1
# 80                  Slc17a8-IRES2-Cre            No seal                 3
# 81                  Slc17a8-IRES2-Cre          Nucleated                 9
# 82                  Slc17a8-IRES2-Cre        Outside out                 1
# 83                  Slc17a8-IRES2-Cre  Partial nucleated                 2
# 84                   Slc32a1-IRES-Cre        Entire cell                 2
# 85                   Slc32a1-IRES-Cre            No seal                78
# 86                   Slc32a1-IRES-Cre          Nucleated               135
# 87                   Slc32a1-IRES-Cre        Outside out                 5
# 88                   Slc32a1-IRES-Cre  Partial nucleated                33
# 89                       Sst-IRES-Cre            No seal                35
# 90                       Sst-IRES-Cre          Nucleated                43
# 91                       Sst-IRES-Cre        Outside out                11
# 92                       Sst-IRES-Cre  Partial nucleated                11
# 93                       Vip-IRES-Cre        Entire cell                 4
# 94                       Vip-IRES-Cre            No seal                83
# 95                       Vip-IRES-Cre          Nucleated               104
# 96                       Vip-IRES-Cre        Outside out                14
# 97                       Vip-IRES-Cre  Partial nucleated                20
# 98                Vipr2-IRES2-Cre-neo            No seal                 1
# 99                Vipr2-IRES2-Cre-neo          Nucleated                 2
# 100    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO            No seal                 4
# 101    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        Outside out                 1
# 102    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO  Partial nucleated                 1
# 103  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Entire cell                 2
# 104  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO            No seal                23
# 105  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          Nucleated                16
# 106  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Outside out                 1
# 107  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  Partial nucleated                17
#
# [108 rows x 3 columns]

# %%
ps1['post_patch_count'] = ps1['post_patch_count'].fillna(0)
#ps1['total_count'] = ps1['total_count'].fillna(0)
ps1
#ps1.groupby(['Cre line', 'Post patch?']).agg({'total_count': 'sum'})
# Out:
#                              Cre_line   post patch class  post_patch_count
# 0                   Chat-IRES-Cre-neo        Entire cell                 3
# 1                   Chat-IRES-Cre-neo            No seal                10
# 2                   Chat-IRES-Cre-neo          Nucleated                 5
# 3                   Chat-IRES-Cre-neo  Partial nucleated                 9
# 4                     Chrna2-Cre_OE25        Entire cell                 2
# 5                     Chrna2-Cre_OE25            No seal                22
# 6                     Chrna2-Cre_OE25          Nucleated                37
# 7                     Chrna2-Cre_OE25        Outside out                 3
# 8                     Chrna2-Cre_OE25  Partial nucleated                 3
# 9                      Ctgf-T2A-dgCre            No seal                15
# 10                     Ctgf-T2A-dgCre          Nucleated                13
# 11                     Ctgf-T2A-dgCre  Partial nucleated                 2
# 12                       Cux2-CreERT2            No seal                21
# 13                       Cux2-CreERT2          Nucleated                31
# 14                       Cux2-CreERT2        Outside out                 2
# 15                       Cux2-CreERT2  Partial nucleated                 6
# 16                      Gad2-IRES-Cre        Entire cell                 1
# 17                      Gad2-IRES-Cre            No seal                98
# 18                      Gad2-IRES-Cre          Nucleated               113
# 19                      Gad2-IRES-Cre        Outside out                13
# 20                      Gad2-IRES-Cre  Partial nucleated                30
# 21                  Glt25d2-Cre_NF107            No seal                 3
# 22                  Glt25d2-Cre_NF107          Nucleated                 8
# 23                  Glt25d2-Cre_NF107  Partial nucleated                 1
# 24                    Htr3a-Cre_NO152            No seal                 4
# 25                    Htr3a-Cre_NO152          Nucleated                14
# 26                    Htr3a-Cre_NO152  Partial nucleated                 1
# 27      Htr3a-Cre_NO152;Pvalb-T2A-Dre            No seal                 5
# 28      Htr3a-Cre_NO152;Pvalb-T2A-Dre          Nucleated                 9
# 29      Htr3a-Cre_NO152;Pvalb-T2A-Dre        Outside out                 2
# ..                                ...                ...               ...
# 78                      Sim1-Cre_KJ18          Nucleated                 4
# 79                      Sim1-Cre_KJ18  Partial nucleated                 1
# 80                  Slc17a8-IRES2-Cre            No seal                 3
# 81                  Slc17a8-IRES2-Cre          Nucleated                 9
# 82                  Slc17a8-IRES2-Cre        Outside out                 1
# 83                  Slc17a8-IRES2-Cre  Partial nucleated                 2
# 84                   Slc32a1-IRES-Cre        Entire cell                 2
# 85                   Slc32a1-IRES-Cre            No seal                78
# 86                   Slc32a1-IRES-Cre          Nucleated               135
# 87                   Slc32a1-IRES-Cre        Outside out                 5
# 88                   Slc32a1-IRES-Cre  Partial nucleated                33
# 89                       Sst-IRES-Cre            No seal                35
# 90                       Sst-IRES-Cre          Nucleated                43
# 91                       Sst-IRES-Cre        Outside out                11
# 92                       Sst-IRES-Cre  Partial nucleated                11
# 93                       Vip-IRES-Cre        Entire cell                 4
# 94                       Vip-IRES-Cre            No seal                83
# 95                       Vip-IRES-Cre          Nucleated               104
# 96                       Vip-IRES-Cre        Outside out                14
# 97                       Vip-IRES-Cre  Partial nucleated                20
# 98                Vipr2-IRES2-Cre-neo            No seal                 1
# 99                Vipr2-IRES2-Cre-neo          Nucleated                 2
# 100    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO            No seal                 4
# 101    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        Outside out                 1
# 102    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO  Partial nucleated                 1
# 103  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Entire cell                 2
# 104  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO            No seal                23
# 105  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          Nucleated                16
# 106  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Outside out                 1
# 107  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  Partial nucleated                17
#
# [108 rows x 3 columns]

# %%
type(ps1)
# Out:
# pandas.core.frame.DataFrame

# %%
ps_totals = ps1.groupby(['Cre_line', 'post patch class']).agg({'post_patch_count': 'sum'})
ps2 = ps1.groupby(['Cre_line']).agg({'post_patch_count': 'sum'})
ps_final = ps_totals.div(ps2, level = 'Cre_line') * 100

# %%
ps_final = ps_final.reset_index()

# %%
ps_final
# Out:
#                              Cre_line   post patch class  post_patch_count
# 0                   Chat-IRES-Cre-neo        Entire cell         11.111111
# 1                   Chat-IRES-Cre-neo            No seal         37.037037
# 2                   Chat-IRES-Cre-neo          Nucleated         18.518519
# 3                   Chat-IRES-Cre-neo  Partial nucleated         33.333333
# 4                     Chrna2-Cre_OE25        Entire cell          2.985075
# 5                     Chrna2-Cre_OE25            No seal         32.835821
# 6                     Chrna2-Cre_OE25          Nucleated         55.223881
# 7                     Chrna2-Cre_OE25        Outside out          4.477612
# 8                     Chrna2-Cre_OE25  Partial nucleated          4.477612
# 9                      Ctgf-T2A-dgCre            No seal         50.000000
# 10                     Ctgf-T2A-dgCre          Nucleated         43.333333
# 11                     Ctgf-T2A-dgCre  Partial nucleated          6.666667
# 12                       Cux2-CreERT2            No seal         35.000000
# 13                       Cux2-CreERT2          Nucleated         51.666667
# 14                       Cux2-CreERT2        Outside out          3.333333
# 15                       Cux2-CreERT2  Partial nucleated         10.000000
# 16                      Gad2-IRES-Cre        Entire cell          0.392157
# 17                      Gad2-IRES-Cre            No seal         38.431373
# 18                      Gad2-IRES-Cre          Nucleated         44.313725
# 19                      Gad2-IRES-Cre        Outside out          5.098039
# 20                      Gad2-IRES-Cre  Partial nucleated         11.764706
# 21                  Glt25d2-Cre_NF107            No seal         25.000000
# 22                  Glt25d2-Cre_NF107          Nucleated         66.666667
# 23                  Glt25d2-Cre_NF107  Partial nucleated          8.333333
# 24                    Htr3a-Cre_NO152            No seal         21.052632
# 25                    Htr3a-Cre_NO152          Nucleated         73.684211
# 26                    Htr3a-Cre_NO152  Partial nucleated          5.263158
# 27      Htr3a-Cre_NO152;Pvalb-T2A-Dre            No seal         31.250000
# 28      Htr3a-Cre_NO152;Pvalb-T2A-Dre          Nucleated         56.250000
# 29      Htr3a-Cre_NO152;Pvalb-T2A-Dre        Outside out         12.500000
# ..                                ...                ...               ...
# 78                      Sim1-Cre_KJ18          Nucleated         44.444444
# 79                      Sim1-Cre_KJ18  Partial nucleated         11.111111
# 80                  Slc17a8-IRES2-Cre            No seal         20.000000
# 81                  Slc17a8-IRES2-Cre          Nucleated         60.000000
# 82                  Slc17a8-IRES2-Cre        Outside out          6.666667
# 83                  Slc17a8-IRES2-Cre  Partial nucleated         13.333333
# 84                   Slc32a1-IRES-Cre        Entire cell          0.790514
# 85                   Slc32a1-IRES-Cre            No seal         30.830040
# 86                   Slc32a1-IRES-Cre          Nucleated         53.359684
# 87                   Slc32a1-IRES-Cre        Outside out          1.976285
# 88                   Slc32a1-IRES-Cre  Partial nucleated         13.043478
# 89                       Sst-IRES-Cre            No seal         35.000000
# 90                       Sst-IRES-Cre          Nucleated         43.000000
# 91                       Sst-IRES-Cre        Outside out         11.000000
# 92                       Sst-IRES-Cre  Partial nucleated         11.000000
# 93                       Vip-IRES-Cre        Entire cell          1.777778
# 94                       Vip-IRES-Cre            No seal         36.888889
# 95                       Vip-IRES-Cre          Nucleated         46.222222
# 96                       Vip-IRES-Cre        Outside out          6.222222
# 97                       Vip-IRES-Cre  Partial nucleated          8.888889
# 98                Vipr2-IRES2-Cre-neo            No seal         33.333333
# 99                Vipr2-IRES2-Cre-neo          Nucleated         66.666667
# 100    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO            No seal         66.666667
# 101    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        Outside out         16.666667
# 102    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO  Partial nucleated         16.666667
# 103  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Entire cell          3.389831
# 104  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO            No seal         38.983051
# 105  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          Nucleated         27.118644
# 106  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Outside out          1.694915
# 107  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  Partial nucleated         28.813559
#
# [108 rows x 3 columns]

# %%
ps_nuc = ps_final[ps_final['post patch class'] == 'Nucleated']
ps_nuc['pct_nuc'] = ps_nuc['post_patch_count']
ps_nuc = ps_nuc.drop('post_patch_count', 1)
ps_nuc = ps_nuc.drop('post patch class', 1)
ps_nuc = ps_nuc.reset_index()
#ps_nuc.set_index('Cre_line', inplace=True)
ps_nuc = ps_nuc.drop('index', 1)
ps_nuc
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                             Cre_line    pct_nuc
# 0                  Chat-IRES-Cre-neo  18.518519
# 1                    Chrna2-Cre_OE25  55.223881
# 2                     Ctgf-T2A-dgCre  43.333333
# 3                       Cux2-CreERT2  51.666667
# 4                      Gad2-IRES-Cre  44.313725
# 5                  Glt25d2-Cre_NF107  66.666667
# 6                    Htr3a-Cre_NO152  73.684211
# 7      Htr3a-Cre_NO152;Pvalb-T2A-Dre  56.250000
# 8                   Ndnf-IRES2-dgCre  42.105263
# 9                     Nkx2-1-CreERT2  44.444444
# 10        Nos1-CreERT2;Sst-IRES-FlpO  80.000000
# 11                         Nr5a1-Cre  35.000000
# 12                      Oxtr-T2A-Cre  60.563380
# 13                  Pdyn-T2A-CreERT2  23.076923
# 14                    Pvalb-IRES-Cre  37.288136
# 15                    Rbp4-Cre_KL100  64.615385
# 16                    Rorb-IRES2-Cre  26.562500
# 17                Rorb-IRES2-Cre-neo  43.137255
# 18                    Scnn1a-Tg2-Cre  50.000000
# 19                    Scnn1a-Tg3-Cre  35.483871
# 20                     Sim1-Cre_KJ18  44.444444
# 21                 Slc17a8-IRES2-Cre  60.000000
# 22                  Slc32a1-IRES-Cre  53.359684
# 23                      Sst-IRES-Cre  43.000000
# 24                      Vip-IRES-Cre  46.222222
# 25               Vipr2-IRES2-Cre-neo  66.666667
# 26  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  27.118644

# %%
cre_nuc = sns.barplot(x = 'Cre_line', y = 'pct_nuc', data = ps_nuc)
for item in cre_nuc.get_xticklabels():
    item.set_rotation(90)
#plt.setp(cre_nuc.get_xticklabels(), rotation=90)
#plt.tight_layout()
#plt.subplots_adjust(bottom=0.15)
plt.savefig('cre_line_vs_pct_nuc',dpi=100)

# %%
#ps2 = ps2.reset_index()
ps2
#ps2.to_csv('cre_line_totals.csv')
# Out:
#                             Cre_line  post_patch_count
# 0                  Chat-IRES-Cre-neo                27
# 1                    Chrna2-Cre_OE25                67
# 2                     Ctgf-T2A-dgCre                30
# 3                       Cux2-CreERT2                60
# 4                      Gad2-IRES-Cre               255
# 5                  Glt25d2-Cre_NF107                12
# 6                    Htr3a-Cre_NO152                19
# 7      Htr3a-Cre_NO152;Pvalb-T2A-Dre                16
# 8                   Ndnf-IRES2-dgCre                19
# 9                     Nkx2-1-CreERT2                 9
# 10        Nos1-CreERT2;Sst-IRES-FlpO                10
# 11                         Nr5a1-Cre                60
# 12                      Oxtr-T2A-Cre                71
# 13                  Pdyn-T2A-CreERT2                13
# 14                    Pvalb-IRES-Cre               118
# 15                    Rbp4-Cre_KL100               130
# 16                    Rorb-IRES2-Cre               128
# 17                Rorb-IRES2-Cre-neo                51
# 18                    Scnn1a-Tg2-Cre                32
# 19                    Scnn1a-Tg3-Cre                62
# 20                     Sim1-Cre_KJ18                 9
# 21                 Slc17a8-IRES2-Cre                15
# 22                  Slc32a1-IRES-Cre               253
# 23                      Sst-IRES-Cre               100
# 24                      Vip-IRES-Cre               225
# 25               Vipr2-IRES2-Cre-neo                 3
# 26    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO                 6
# 27  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO                59

# %%
#ps2 = ps2.set_index('Cre_line', inplace=True)
ps2 = ps2.reset_index()
#ps2.to_csv('cre_line_totals.csv')

# %%
ps2
# Out:
#                             Cre_line  post_patch_count
# 0                  Chat-IRES-Cre-neo                27
# 1                    Chrna2-Cre_OE25                67
# 2                     Ctgf-T2A-dgCre                30
# 3                       Cux2-CreERT2                60
# 4                      Gad2-IRES-Cre               255
# 5                  Glt25d2-Cre_NF107                12
# 6                    Htr3a-Cre_NO152                19
# 7      Htr3a-Cre_NO152;Pvalb-T2A-Dre                16
# 8                   Ndnf-IRES2-dgCre                19
# 9                     Nkx2-1-CreERT2                 9
# 10        Nos1-CreERT2;Sst-IRES-FlpO                10
# 11                         Nr5a1-Cre                60
# 12                      Oxtr-T2A-Cre                71
# 13                  Pdyn-T2A-CreERT2                13
# 14                    Pvalb-IRES-Cre               118
# 15                    Rbp4-Cre_KL100               130
# 16                    Rorb-IRES2-Cre               128
# 17                Rorb-IRES2-Cre-neo                51
# 18                    Scnn1a-Tg2-Cre                32
# 19                    Scnn1a-Tg3-Cre                62
# 20                     Sim1-Cre_KJ18                 9
# 21                 Slc17a8-IRES2-Cre                15
# 22                  Slc32a1-IRES-Cre               253
# 23                      Sst-IRES-Cre               100
# 24                      Vip-IRES-Cre               225
# 25               Vipr2-IRES2-Cre-neo                 3
# 26    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO                 6
# 27  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO                59

# %%
ps2 = ps2.drop('Cre_line', 1)

# %%
ps2
# Out:
#     post_patch_count
# 0                 27
# 1                 67
# 2                 30
# 3                 60
# 4                255
# 5                 12
# 6                 19
# 7                 16
# 8                 19
# 9                  9
# 10                10
# 11                60
# 12                71
# 13                13
# 14               118
# 15               130
# 16               128
# 17                51
# 18                32
# 19                62
# 20                 9
# 21                15
# 22               253
# 23               100
# 24               225
# 25                 3
# 26                 6
# 27                59

# %%
result = pd.concat([ps_nuc, ps2], axis=1, join='inner')
result
# Out:
#                             Cre_line    pct_nuc  post_patch_count
# 0                  Chat-IRES-Cre-neo  18.518519                27
# 1                    Chrna2-Cre_OE25  55.223881                67
# 2                     Ctgf-T2A-dgCre  43.333333                30
# 3                       Cux2-CreERT2  51.666667                60
# 4                      Gad2-IRES-Cre  44.313725               255
# 5                  Glt25d2-Cre_NF107  66.666667                12
# 6                    Htr3a-Cre_NO152  73.684211                19
# 7      Htr3a-Cre_NO152;Pvalb-T2A-Dre  56.250000                16
# 8                   Ndnf-IRES2-dgCre  42.105263                19
# 9                     Nkx2-1-CreERT2  44.444444                 9
# 10        Nos1-CreERT2;Sst-IRES-FlpO  80.000000                10
# 11                         Nr5a1-Cre  35.000000                60
# 12                      Oxtr-T2A-Cre  60.563380                71
# 13                  Pdyn-T2A-CreERT2  23.076923                13
# 14                    Pvalb-IRES-Cre  37.288136               118
# 15                    Rbp4-Cre_KL100  64.615385               130
# 16                    Rorb-IRES2-Cre  26.562500               128
# 17                Rorb-IRES2-Cre-neo  43.137255                51
# 18                    Scnn1a-Tg2-Cre  50.000000                32
# 19                    Scnn1a-Tg3-Cre  35.483871                62
# 20                     Sim1-Cre_KJ18  44.444444                 9
# 21                 Slc17a8-IRES2-Cre  60.000000                15
# 22                  Slc32a1-IRES-Cre  53.359684               253
# 23                      Sst-IRES-Cre  43.000000               100
# 24                      Vip-IRES-Cre  46.222222               225
# 25               Vipr2-IRES2-Cre-neo  66.666667                 3
# 26  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  27.118644                 6

# %%
#cre_nuc = sns.barplot(x = 'Cre_line', y = 'pct_nuc', data = result)
#for item in cre_nuc.get_xticklabels():
    #item.set_rotation(90)
nuc_pct = list(result['pct_nuc'])
counts = list(result['post_patch_count'])
names = list(result['Cre_line'])
n_groups = 27
index = np.arange(n_groups)
bar_width = 0.5
plt.xlabel('Cre_line')
plt.ylabel('percent_nucleated')
plt.xticks(index, names, rotation=90)
rects = plt.bar(index, nuc_pct, bar_width)
for i, rect in enumerate(rects):
    height = rect.get_height()
    plt.text(rect.get_x()+rect.get_width()/2, 1.01*height, counts[i], ha='center')

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline
sns.set(style='whitegrid', color_codes = True)

# %%
ps = pd.read_csv('patch_seq_log_mouse.csv')

# %%
ps = ps[['Date', 'Slice (Lims ID?)', 'Post patch?', 'PCR cycles', 'SM_QC_PF', 'Bad dates']]
ps = ps[ps['PCR cycles'] == 21]
ps['Date'] = pd.to_datetime(ps['Date'], format = '%y%m%d')
ps = ps[ps['Bad dates'] != 'x']
ps = ps.drop('Bad dates', 1)
ps = ps[ps['SM_QC_PF'] != 'cnt']
ps.dropna(subset = ['Post patch?', 'SM_QC_PF'], inplace = True)
ps['Post patch?'] = ps['Post patch?'].astype('category')

# %%
ps.head()
# Out:
#            Date                Slice (Lims ID?)  Post patch?  PCR cycles  \
# 4717 2017-04-19  Sst-IRES-Cre;Ai14-313562.03.02  Outside-Out        21.0
# 4718 2017-04-19  Sst-IRES-Cre;Ai14-313562.03.02  Outside-Out        21.0
# 4719 2017-04-19  Sst-IRES-Cre;Ai14-313562.04.02      No-Seal        21.0
# 4720 2017-04-19  Sst-IRES-Cre;Ai14-313562.04.02    Nucleated        21.0
# 4721 2017-04-19  Sst-IRES-Cre;Ai14-313562.04.02  Outside-Out        21.0
#
#      SM_QC_PF
# 4717     fail
# 4718     pass
# 4719     fail
# 4720     pass
# 4721     pass

# %%
ps['Cre_line'] = ps['Slice (Lims ID?)'].str[:-18]
ps = ps.drop('Slice (Lims ID?)', 1)
ps
# Out:
#            Date      Post patch?  PCR cycles SM_QC_PF           Cre_line
# 4717 2017-04-19      Outside-Out        21.0     fail       Sst-IRES-Cre
# 4718 2017-04-19      Outside-Out        21.0     pass       Sst-IRES-Cre
# 4719 2017-04-19          No-Seal        21.0     fail       Sst-IRES-Cre
# 4720 2017-04-19        Nucleated        21.0     pass       Sst-IRES-Cre
# 4721 2017-04-19      Outside-Out        21.0     pass       Sst-IRES-Cre
# 4722 2017-04-19        Nucleated        21.0     pass       Sst-IRES-Cre
# 4723 2017-04-19          No-Seal        21.0     pass       Sst-IRES-Cre
# 4724 2017-04-19        Nucleated        21.0     pass       Sst-IRES-Cre
# 4727 2017-04-19          No-Seal        21.0     fail       Sst-IRES-Cre
# 4728 2017-04-19          No-Seal        21.0     pass       Sst-IRES-Cre
# 4729 2017-04-19          No-Seal        21.0     pass       Sst-IRES-Cre
# 4730 2017-04-19          No-Seal        21.0     pass       Sst-IRES-Cre
# 4737 2017-04-20        Nucleated        21.0     pass       Vip-IRES-Cre
# 4738 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4739 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4740 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4741 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4742 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4743 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4744 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4745 2017-04-20  Partial-Nucleus        21.0     pass       Vip-IRES-Cre
# 4746 2017-04-20        Nucleated        21.0     pass       Vip-IRES-Cre
# 4749 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4750 2017-04-20      Outside-Out        21.0     pass       Vip-IRES-Cre
# 4751 2017-04-20      Entire-Cell        21.0     pass       Vip-IRES-Cre
# 4752 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4753 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4754 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4755 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# 4756 2017-04-20          No-Seal        21.0     pass       Vip-IRES-Cre
# ...         ...              ...         ...      ...                ...
# 6784 2017-08-21        Nucleated        21.0     pass       Vip-IRES-Cre
# 6785 2017-08-21        Nucleated        21.0     pass       Vip-IRES-Cre
# 6786 2017-08-21          No-Seal        21.0     pass       Vip-IRES-Cre
# 6787 2017-08-21          No-Seal        21.0     pass       Vip-IRES-Cre
# 6788 2017-08-21  Partial-Nucleus        21.0     pass       Vip-IRES-Cre
# 6789 2017-08-23          No-Seal        21.0     pass  Chat-IRES-Cre-neo
# 6790 2017-08-23          No-Seal        21.0     pass  Chat-IRES-Cre-neo
# 6791 2017-08-23  Partial-Nucleus        21.0     pass  Chat-IRES-Cre-neo
# 6792 2017-08-23  Partial-Nucleus        21.0     pass  Chat-IRES-Cre-neo
# 6793 2017-08-23        Nucleated        21.0     pass     Scnn1a-Tg3-Cre
# 6794 2017-08-23        Nucleated        21.0     pass     Scnn1a-Tg3-Cre
# 6795 2017-08-23  Partial-Nucleus        21.0     pass     Scnn1a-Tg3-Cre
# 6796 2017-08-23          No-Seal        21.0     pass     Scnn1a-Tg3-Cre
# 6803 2017-08-24          No-Seal        21.0     pass    Chrna2-Cre_OE25
# 6804 2017-08-24        Nucleated        21.0     pass    Chrna2-Cre_OE25
# 6805 2017-08-24        Nucleated        21.0     fail    Chrna2-Cre_OE25
# 6806 2017-08-24          No-Seal        21.0     pass  Chat-IRES-Cre-neo
# 6807 2017-08-24        Nucleated        21.0     pass  Chat-IRES-Cre-neo
# 6810 2017-08-24  Partial-Nucleus        21.0     fail    Chrna2-Cre_OE25
# 6811 2017-08-24        Nucleated        21.0     pass    Chrna2-Cre_OE25
# 6812 2017-08-24        Nucleated        21.0     pass    Chrna2-Cre_OE25
# 6813 2017-08-24        Nucleated        21.0     pass  Chat-IRES-Cre-neo
# 6814 2017-08-24        Nucleated        21.0     pass  Chat-IRES-Cre-neo
# 6815 2017-08-24  Partial-Nucleus        21.0     pass  Chat-IRES-Cre-neo
# 6822 2017-08-25        Nucleated        21.0     pass    Chrna2-Cre_OE25
# 6823 2017-08-25          No-Seal        21.0     pass    Chrna2-Cre_OE25
# 6824 2017-08-25        Nucleated        21.0     pass    Chrna2-Cre_OE25
# 6825 2017-08-25      Entire-Cell        21.0     pass  Chat-IRES-Cre-neo
# 6826 2017-08-25  Partial-Nucleus        21.0     pass  Chat-IRES-Cre-neo
# 6827 2017-08-25          No-Seal        21.0     pass  Chat-IRES-Cre-neo
#
# [1385 rows x 5 columns]

# %%
ps0 = ps.drop('Post patch?', 1)
ps0 = ps.drop('PCR cycles', 1)
ps0 = ps.drop('SM_QC_PF', 1)

# %%
ps0.to_csv('cre_nuc.csv')

# %%
ps['Cre_line'].value_counts()
#ps['Cre line'].sort_values()
# Out:
# Slc32a1-IRES-Cre                    229
# Gad2-IRES-Cre                       195
# Vip-IRES-Cre                        168
# Rbp4-Cre_KL100                      117
# Rorb-IRES2-Cre                      112
# Pvalb-IRES-Cre                       93
# Sst-IRES-Cre                         70
# Cux2-CreERT2                         60
# Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO     57
# Rorb-IRES2-Cre-neo                   51
# Chrna2-Cre_OE25                      30
# Ctgf-T2A-dgCre                       30
# Scnn1a-Tg3-Cre                       29
# Chat-IRES-Cre-neo                    27
# Nr5a1-Cre                            23
# Scnn1a-Tg2-Cre                       22
# Htr3a-Cre_NO152;Pvalb-T2A-Dre        16
# Slc17a8-IRES2-Cre                    15
# Glt25d2-Cre_NF107                    12
# Ndnf-IRES2-dgCre                      9
# Nkx2-1-CreERT2                        9
# Oxtr-T2A-Cre                          6
# Vipr2-IRES2-Cre-neo                   3
# Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        2
# Name: Cre_line, dtype: int64

# %%
ps.groupby(['Cre_line'])['Post patch?'].value_counts()
# Out:
# Cre_line                          Post patch?
# Chat-IRES-Cre-neo                 No-Seal             10
#                                   Partial-Nucleus      9
#                                   Nucleated            5
#                                   Entire-Cell          3
# Chrna2-Cre_OE25                   Nucleated           17
#                                   No-Seal             10
#                                   Outside-Out          2
#                                   Partial-Nucleus      1
# Ctgf-T2A-dgCre                    No-Seal             15
#                                   Nucleated           13
#                                   Partial-Nucleus      2
# Cux2-CreERT2                      Nucleated           31
#                                   No-Seal             21
#                                   Partial-Nucleus      6
#                                   Outside-Out          2
# Gad2-IRES-Cre                     Nucleated           85
#                                   No-Seal             79
#                                   Partial-Nucleus     23
#                                   Outside-Out          6
#                                   Entire-Cell          1
#                                   missing              1
# Glt25d2-Cre_NF107                 Nucleated            8
#                                   No-Seal              3
#                                   Partial-Nucleus      1
# Htr3a-Cre_NO152;Pvalb-T2A-Dre     Nucleated            9
#                                   No-Seal              5
#                                   Outside-Out          2
# Ndnf-IRES2-dgCre                  Nucleated            5
#                                   No-Seal              4
# Nkx2-1-CreERT2                    No-Seal              5
#                                                     ...
# Scnn1a-Tg3-Cre                    No-Seal              9
#                                   Nucleated            8
#                                   Partial-Nucleus      1
# Slc17a8-IRES2-Cre                 Nucleated            9
#                                   No-Seal              3
#                                   Partial-Nucleus      2
#                                   Outside-Out          1
# Slc32a1-IRES-Cre                  Nucleated          123
#                                   No-Seal             71
#                                   Partial-Nucleus     32
#                                   Outside-Out          2
#                                   Entire-Cell          1
# Sst-IRES-Cre                      No-Seal             27
#                                   Nucleated           26
#                                   Outside-Out         11
#                                   Partial-Nucleus      6
# Vip-IRES-Cre                      Nucleated           76
#                                   No-Seal             63
#                                   Partial-Nucleus     14
#                                   Outside-Out         13
#                                   Entire-Cell          2
# Vipr2-IRES2-Cre-neo               Nucleated            2
#                                   No-Seal              1
# Vipr2-IRES2-Cre;Pvalb-T2A-FlpO    No-Seal              1
#                                   Partial-Nucleus      1
# Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  No-Seal             23
#                                   Nucleated           16
#                                   Partial-Nucleus     15
#                                   Entire-Cell          2
#                                   Outside-Out          1
# Name: Post patch?, dtype: int64

# %%
ps = ps.drop('Date', 1)
ps = ps.drop('PCR cycles', 1)
ps['post_patch'] = ps['SM_QC_PF']
ps = ps.drop('SM_QC_PF', 1)
#ps['total'] = ps['post_patch']
#ps.tail()

# %%
ps1 = ps.groupby(['Cre_line', 'Post patch?']).count()
ps1
# Out:
#                                                   post_patch
# Cre_line                         Post patch?
# Chat-IRES-Cre-neo                Entire-Cell             3.0
#                                  No-Seal                10.0
#                                  Nucleated               5.0
#                                  Outside-Out             NaN
#                                  Partial-Nucleus         9.0
#                                  missing                 NaN
# Chrna2-Cre_OE25                  Entire-Cell             NaN
#                                  No-Seal                10.0
#                                  Nucleated              17.0
#                                  Outside-Out             2.0
#                                  Partial-Nucleus         1.0
#                                  missing                 NaN
# Ctgf-T2A-dgCre                   Entire-Cell             NaN
#                                  No-Seal                15.0
#                                  Nucleated              13.0
#                                  Outside-Out             NaN
#                                  Partial-Nucleus         2.0
#                                  missing                 NaN
# Cux2-CreERT2                     Entire-Cell             NaN
#                                  No-Seal                21.0
#                                  Nucleated              31.0
#                                  Outside-Out             2.0
#                                  Partial-Nucleus         6.0
#                                  missing                 NaN
# Gad2-IRES-Cre                    Entire-Cell             1.0
#                                  No-Seal                79.0
#                                  Nucleated              85.0
#                                  Outside-Out             6.0
#                                  Partial-Nucleus        23.0
#                                  missing                 1.0
# ...                                                      ...
# Sst-IRES-Cre                     Entire-Cell             NaN
#                                  No-Seal                27.0
#                                  Nucleated              26.0
#                                  Outside-Out            11.0
#                                  Partial-Nucleus         6.0
#                                  missing                 NaN
# Vip-IRES-Cre                     Entire-Cell             2.0
#                                  No-Seal                63.0
#                                  Nucleated              76.0
#                                  Outside-Out            13.0
#                                  Partial-Nucleus        14.0
#                                  missing                 NaN
# Vipr2-IRES2-Cre-neo              Entire-Cell             NaN
#                                  No-Seal                 1.0
#                                  Nucleated               2.0
#                                  Outside-Out             NaN
#                                  Partial-Nucleus         NaN
#                                  missing                 NaN
# Vipr2-IRES2-Cre;Pvalb-T2A-FlpO   Entire-Cell             NaN
#                                  No-Seal                 1.0
#                                  Nucleated               NaN
#                                  Outside-Out             NaN
#                                  Partial-Nucleus         1.0
#                                  missing                 NaN
# Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO Entire-Cell             2.0
#                                  No-Seal                23.0
#                                  Nucleated              16.0
#                                  Outside-Out             1.0
#                                  Partial-Nucleus        15.0
#                                  missing                 NaN
#
# [144 rows x 1 columns]

# %%
type(ps1)
# Out:
# pandas.core.frame.DataFrame

# %%
ps1 = ps1.add_suffix('_count').reset_index()
ps1
# Out:
#                              Cre_line      Post patch?  post_patch_count
# 0                   Chat-IRES-Cre-neo      Entire-Cell               3.0
# 1                   Chat-IRES-Cre-neo          No-Seal              10.0
# 2                   Chat-IRES-Cre-neo        Nucleated               5.0
# 3                   Chat-IRES-Cre-neo      Outside-Out               NaN
# 4                   Chat-IRES-Cre-neo  Partial-Nucleus               9.0
# 5                   Chat-IRES-Cre-neo          missing               NaN
# 6                     Chrna2-Cre_OE25      Entire-Cell               NaN
# 7                     Chrna2-Cre_OE25          No-Seal              10.0
# 8                     Chrna2-Cre_OE25        Nucleated              17.0
# 9                     Chrna2-Cre_OE25      Outside-Out               2.0
# 10                    Chrna2-Cre_OE25  Partial-Nucleus               1.0
# 11                    Chrna2-Cre_OE25          missing               NaN
# 12                     Ctgf-T2A-dgCre      Entire-Cell               NaN
# 13                     Ctgf-T2A-dgCre          No-Seal              15.0
# 14                     Ctgf-T2A-dgCre        Nucleated              13.0
# 15                     Ctgf-T2A-dgCre      Outside-Out               NaN
# 16                     Ctgf-T2A-dgCre  Partial-Nucleus               2.0
# 17                     Ctgf-T2A-dgCre          missing               NaN
# 18                       Cux2-CreERT2      Entire-Cell               NaN
# 19                       Cux2-CreERT2          No-Seal              21.0
# 20                       Cux2-CreERT2        Nucleated              31.0
# 21                       Cux2-CreERT2      Outside-Out               2.0
# 22                       Cux2-CreERT2  Partial-Nucleus               6.0
# 23                       Cux2-CreERT2          missing               NaN
# 24                      Gad2-IRES-Cre      Entire-Cell               1.0
# 25                      Gad2-IRES-Cre          No-Seal              79.0
# 26                      Gad2-IRES-Cre        Nucleated              85.0
# 27                      Gad2-IRES-Cre      Outside-Out               6.0
# 28                      Gad2-IRES-Cre  Partial-Nucleus              23.0
# 29                      Gad2-IRES-Cre          missing               1.0
# ..                                ...              ...               ...
# 114                      Sst-IRES-Cre      Entire-Cell               NaN
# 115                      Sst-IRES-Cre          No-Seal              27.0
# 116                      Sst-IRES-Cre        Nucleated              26.0
# 117                      Sst-IRES-Cre      Outside-Out              11.0
# 118                      Sst-IRES-Cre  Partial-Nucleus               6.0
# 119                      Sst-IRES-Cre          missing               NaN
# 120                      Vip-IRES-Cre      Entire-Cell               2.0
# 121                      Vip-IRES-Cre          No-Seal              63.0
# 122                      Vip-IRES-Cre        Nucleated              76.0
# 123                      Vip-IRES-Cre      Outside-Out              13.0
# 124                      Vip-IRES-Cre  Partial-Nucleus              14.0
# 125                      Vip-IRES-Cre          missing               NaN
# 126               Vipr2-IRES2-Cre-neo      Entire-Cell               NaN
# 127               Vipr2-IRES2-Cre-neo          No-Seal               1.0
# 128               Vipr2-IRES2-Cre-neo        Nucleated               2.0
# 129               Vipr2-IRES2-Cre-neo      Outside-Out               NaN
# 130               Vipr2-IRES2-Cre-neo  Partial-Nucleus               NaN
# 131               Vipr2-IRES2-Cre-neo          missing               NaN
# 132    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO      Entire-Cell               NaN
# 133    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO          No-Seal               1.0
# 134    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        Nucleated               NaN
# 135    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO      Outside-Out               NaN
# 136    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO  Partial-Nucleus               1.0
# 137    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO          missing               NaN
# 138  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO      Entire-Cell               2.0
# 139  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          No-Seal              23.0
# 140  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Nucleated              16.0
# 141  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO      Outside-Out               1.0
# 142  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  Partial-Nucleus              15.0
# 143  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          missing               NaN
#
# [144 rows x 3 columns]

# %%
ps1['post_patch_count'] = ps1['post_patch_count'].fillna(0)
#ps1['total_count'] = ps1['total_count'].fillna(0)
ps1
#ps1.groupby(['Cre line', 'Post patch?']).agg({'total_count': 'sum'})
# Out:
#                              Cre_line      Post patch?  post_patch_count
# 0                   Chat-IRES-Cre-neo      Entire-Cell               3.0
# 1                   Chat-IRES-Cre-neo          No-Seal              10.0
# 2                   Chat-IRES-Cre-neo        Nucleated               5.0
# 3                   Chat-IRES-Cre-neo      Outside-Out               0.0
# 4                   Chat-IRES-Cre-neo  Partial-Nucleus               9.0
# 5                   Chat-IRES-Cre-neo          missing               0.0
# 6                     Chrna2-Cre_OE25      Entire-Cell               0.0
# 7                     Chrna2-Cre_OE25          No-Seal              10.0
# 8                     Chrna2-Cre_OE25        Nucleated              17.0
# 9                     Chrna2-Cre_OE25      Outside-Out               2.0
# 10                    Chrna2-Cre_OE25  Partial-Nucleus               1.0
# 11                    Chrna2-Cre_OE25          missing               0.0
# 12                     Ctgf-T2A-dgCre      Entire-Cell               0.0
# 13                     Ctgf-T2A-dgCre          No-Seal              15.0
# 14                     Ctgf-T2A-dgCre        Nucleated              13.0
# 15                     Ctgf-T2A-dgCre      Outside-Out               0.0
# 16                     Ctgf-T2A-dgCre  Partial-Nucleus               2.0
# 17                     Ctgf-T2A-dgCre          missing               0.0
# 18                       Cux2-CreERT2      Entire-Cell               0.0
# 19                       Cux2-CreERT2          No-Seal              21.0
# 20                       Cux2-CreERT2        Nucleated              31.0
# 21                       Cux2-CreERT2      Outside-Out               2.0
# 22                       Cux2-CreERT2  Partial-Nucleus               6.0
# 23                       Cux2-CreERT2          missing               0.0
# 24                      Gad2-IRES-Cre      Entire-Cell               1.0
# 25                      Gad2-IRES-Cre          No-Seal              79.0
# 26                      Gad2-IRES-Cre        Nucleated              85.0
# 27                      Gad2-IRES-Cre      Outside-Out               6.0
# 28                      Gad2-IRES-Cre  Partial-Nucleus              23.0
# 29                      Gad2-IRES-Cre          missing               1.0
# ..                                ...              ...               ...
# 114                      Sst-IRES-Cre      Entire-Cell               0.0
# 115                      Sst-IRES-Cre          No-Seal              27.0
# 116                      Sst-IRES-Cre        Nucleated              26.0
# 117                      Sst-IRES-Cre      Outside-Out              11.0
# 118                      Sst-IRES-Cre  Partial-Nucleus               6.0
# 119                      Sst-IRES-Cre          missing               0.0
# 120                      Vip-IRES-Cre      Entire-Cell               2.0
# 121                      Vip-IRES-Cre          No-Seal              63.0
# 122                      Vip-IRES-Cre        Nucleated              76.0
# 123                      Vip-IRES-Cre      Outside-Out              13.0
# 124                      Vip-IRES-Cre  Partial-Nucleus              14.0
# 125                      Vip-IRES-Cre          missing               0.0
# 126               Vipr2-IRES2-Cre-neo      Entire-Cell               0.0
# 127               Vipr2-IRES2-Cre-neo          No-Seal               1.0
# 128               Vipr2-IRES2-Cre-neo        Nucleated               2.0
# 129               Vipr2-IRES2-Cre-neo      Outside-Out               0.0
# 130               Vipr2-IRES2-Cre-neo  Partial-Nucleus               0.0
# 131               Vipr2-IRES2-Cre-neo          missing               0.0
# 132    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO      Entire-Cell               0.0
# 133    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO          No-Seal               1.0
# 134    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        Nucleated               0.0
# 135    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO      Outside-Out               0.0
# 136    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO  Partial-Nucleus               1.0
# 137    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO          missing               0.0
# 138  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO      Entire-Cell               2.0
# 139  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          No-Seal              23.0
# 140  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Nucleated              16.0
# 141  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO      Outside-Out               1.0
# 142  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  Partial-Nucleus              15.0
# 143  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          missing               0.0
#
# [144 rows x 3 columns]

# %%
type(ps1)
# Out:
# pandas.core.frame.DataFrame

# %%
ps_totals = ps1.groupby(['Cre_line', 'Post patch?']).agg({'post_patch_count': 'sum'})
ps2 = ps1.groupby(['Cre_line']).agg({'post_patch_count': 'sum'})
ps_final = ps_totals.div(ps2, level = 'Cre_line') * 100

# %%
ps_final = ps_final.reset_index()

# %%
ps_final
# Out:
#                              Cre_line      Post patch?  post_patch_count
# 0                   Chat-IRES-Cre-neo      Entire-Cell         11.111111
# 1                   Chat-IRES-Cre-neo          No-Seal         37.037037
# 2                   Chat-IRES-Cre-neo        Nucleated         18.518519
# 3                   Chat-IRES-Cre-neo      Outside-Out          0.000000
# 4                   Chat-IRES-Cre-neo  Partial-Nucleus         33.333333
# 5                   Chat-IRES-Cre-neo          missing          0.000000
# 6                     Chrna2-Cre_OE25      Entire-Cell          0.000000
# 7                     Chrna2-Cre_OE25          No-Seal         33.333333
# 8                     Chrna2-Cre_OE25        Nucleated         56.666667
# 9                     Chrna2-Cre_OE25      Outside-Out          6.666667
# 10                    Chrna2-Cre_OE25  Partial-Nucleus          3.333333
# 11                    Chrna2-Cre_OE25          missing          0.000000
# 12                     Ctgf-T2A-dgCre      Entire-Cell          0.000000
# 13                     Ctgf-T2A-dgCre          No-Seal         50.000000
# 14                     Ctgf-T2A-dgCre        Nucleated         43.333333
# 15                     Ctgf-T2A-dgCre      Outside-Out          0.000000
# 16                     Ctgf-T2A-dgCre  Partial-Nucleus          6.666667
# 17                     Ctgf-T2A-dgCre          missing          0.000000
# 18                       Cux2-CreERT2      Entire-Cell          0.000000
# 19                       Cux2-CreERT2          No-Seal         35.000000
# 20                       Cux2-CreERT2        Nucleated         51.666667
# 21                       Cux2-CreERT2      Outside-Out          3.333333
# 22                       Cux2-CreERT2  Partial-Nucleus         10.000000
# 23                       Cux2-CreERT2          missing          0.000000
# 24                      Gad2-IRES-Cre      Entire-Cell          0.512821
# 25                      Gad2-IRES-Cre          No-Seal         40.512821
# 26                      Gad2-IRES-Cre        Nucleated         43.589744
# 27                      Gad2-IRES-Cre      Outside-Out          3.076923
# 28                      Gad2-IRES-Cre  Partial-Nucleus         11.794872
# 29                      Gad2-IRES-Cre          missing          0.512821
# ..                                ...              ...               ...
# 114                      Sst-IRES-Cre      Entire-Cell          0.000000
# 115                      Sst-IRES-Cre          No-Seal         38.571429
# 116                      Sst-IRES-Cre        Nucleated         37.142857
# 117                      Sst-IRES-Cre      Outside-Out         15.714286
# 118                      Sst-IRES-Cre  Partial-Nucleus          8.571429
# 119                      Sst-IRES-Cre          missing          0.000000
# 120                      Vip-IRES-Cre      Entire-Cell          1.190476
# 121                      Vip-IRES-Cre          No-Seal         37.500000
# 122                      Vip-IRES-Cre        Nucleated         45.238095
# 123                      Vip-IRES-Cre      Outside-Out          7.738095
# 124                      Vip-IRES-Cre  Partial-Nucleus          8.333333
# 125                      Vip-IRES-Cre          missing          0.000000
# 126               Vipr2-IRES2-Cre-neo      Entire-Cell          0.000000
# 127               Vipr2-IRES2-Cre-neo          No-Seal         33.333333
# 128               Vipr2-IRES2-Cre-neo        Nucleated         66.666667
# 129               Vipr2-IRES2-Cre-neo      Outside-Out          0.000000
# 130               Vipr2-IRES2-Cre-neo  Partial-Nucleus          0.000000
# 131               Vipr2-IRES2-Cre-neo          missing          0.000000
# 132    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO      Entire-Cell          0.000000
# 133    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO          No-Seal         50.000000
# 134    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO        Nucleated          0.000000
# 135    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO      Outside-Out          0.000000
# 136    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO  Partial-Nucleus         50.000000
# 137    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO          missing          0.000000
# 138  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO      Entire-Cell          3.508772
# 139  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          No-Seal         40.350877
# 140  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO        Nucleated         28.070175
# 141  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO      Outside-Out          1.754386
# 142  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  Partial-Nucleus         26.315789
# 143  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO          missing          0.000000
#
# [144 rows x 3 columns]

# %%
ps_nuc = ps_final[ps_final['Post patch?'] == 'Nucleated']
ps_nuc['pct_nuc'] = ps_nuc['post_patch_count']
ps_nuc = ps_nuc.drop('post_patch_count', 1)
ps_nuc = ps_nuc.drop('Post patch?', 1)
ps_nuc = ps_nuc.reset_index()
#ps_nuc.set_index('Cre_line', inplace=True)
ps_nuc = ps_nuc.drop('index', 1)
ps_nuc
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                             Cre_line    pct_nuc
# 0                  Chat-IRES-Cre-neo  18.518519
# 1                    Chrna2-Cre_OE25  56.666667
# 2                     Ctgf-T2A-dgCre  43.333333
# 3                       Cux2-CreERT2  51.666667
# 4                      Gad2-IRES-Cre  43.589744
# 5                  Glt25d2-Cre_NF107  66.666667
# 6      Htr3a-Cre_NO152;Pvalb-T2A-Dre  56.250000
# 7                   Ndnf-IRES2-dgCre  55.555556
# 8                     Nkx2-1-CreERT2  44.444444
# 9                          Nr5a1-Cre  39.130435
# 10                      Oxtr-T2A-Cre  66.666667
# 11                    Pvalb-IRES-Cre  31.182796
# 12                    Rbp4-Cre_KL100  60.683761
# 13                    Rorb-IRES2-Cre  23.214286
# 14                Rorb-IRES2-Cre-neo  43.137255
# 15                    Scnn1a-Tg2-Cre  40.909091
# 16                    Scnn1a-Tg3-Cre  27.586207
# 17                 Slc17a8-IRES2-Cre  60.000000
# 18                  Slc32a1-IRES-Cre  53.711790
# 19                      Sst-IRES-Cre  37.142857
# 20                      Vip-IRES-Cre  45.238095
# 21               Vipr2-IRES2-Cre-neo  66.666667
# 22    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO   0.000000
# 23  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  28.070175

# %%
cre_nuc = sns.barplot(x = 'Cre_line', y = 'pct_nuc', data = ps_nuc)
for item in cre_nuc.get_xticklabels():
    item.set_rotation(90)
#plt.setp(cre_nuc.get_xticklabels(), rotation=90)
#plt.tight_layout()
#plt.subplots_adjust(bottom=0.15)
plt.savefig('cre_line_vs_pct_nuc',dpi=100)

# %%
#ps2 = ps2.reset_index()
ps2
#ps2.to_csv('cre_line_totals.csv')
# Out:
#                                   post_patch_count
# Cre_line
# Chat-IRES-Cre-neo                             27.0
# Chrna2-Cre_OE25                               30.0
# Ctgf-T2A-dgCre                                30.0
# Cux2-CreERT2                                  60.0
# Gad2-IRES-Cre                                195.0
# Glt25d2-Cre_NF107                             12.0
# Htr3a-Cre_NO152;Pvalb-T2A-Dre                 16.0
# Ndnf-IRES2-dgCre                               9.0
# Nkx2-1-CreERT2                                 9.0
# Nr5a1-Cre                                     23.0
# Oxtr-T2A-Cre                                   6.0
# Pvalb-IRES-Cre                                93.0
# Rbp4-Cre_KL100                               117.0
# Rorb-IRES2-Cre                               112.0
# Rorb-IRES2-Cre-neo                            51.0
# Scnn1a-Tg2-Cre                                22.0
# Scnn1a-Tg3-Cre                                29.0
# Slc17a8-IRES2-Cre                             15.0
# Slc32a1-IRES-Cre                             229.0
# Sst-IRES-Cre                                  70.0
# Vip-IRES-Cre                                 168.0
# Vipr2-IRES2-Cre-neo                            3.0
# Vipr2-IRES2-Cre;Pvalb-T2A-FlpO                 2.0
# Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO              57.0

# %%
#ps2 = ps2.set_index('Cre_line', inplace=True)
ps2 = ps2.reset_index()
#ps2.to_csv('cre_line_totals.csv')

# %%
ps2
# Out:
#                             Cre_line  post_patch_count
# 0                  Chat-IRES-Cre-neo              27.0
# 1                    Chrna2-Cre_OE25              30.0
# 2                     Ctgf-T2A-dgCre              30.0
# 3                       Cux2-CreERT2              60.0
# 4                      Gad2-IRES-Cre             195.0
# 5                  Glt25d2-Cre_NF107              12.0
# 6      Htr3a-Cre_NO152;Pvalb-T2A-Dre              16.0
# 7                   Ndnf-IRES2-dgCre               9.0
# 8                     Nkx2-1-CreERT2               9.0
# 9                          Nr5a1-Cre              23.0
# 10                      Oxtr-T2A-Cre               6.0
# 11                    Pvalb-IRES-Cre              93.0
# 12                    Rbp4-Cre_KL100             117.0
# 13                    Rorb-IRES2-Cre             112.0
# 14                Rorb-IRES2-Cre-neo              51.0
# 15                    Scnn1a-Tg2-Cre              22.0
# 16                    Scnn1a-Tg3-Cre              29.0
# 17                 Slc17a8-IRES2-Cre              15.0
# 18                  Slc32a1-IRES-Cre             229.0
# 19                      Sst-IRES-Cre              70.0
# 20                      Vip-IRES-Cre             168.0
# 21               Vipr2-IRES2-Cre-neo               3.0
# 22    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO               2.0
# 23  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO              57.0

# %%
ps2 = ps2.drop('Cre_line', 1)

# %%
result =

# %%
result = pd.concat([ps_nuc, ps2], axis=1, join='inner')
result
# Out:
#     index                          Cre_line    pct_nuc  \
# 0       2                 Chat-IRES-Cre-neo  18.518519
# 1       8                   Chrna2-Cre_OE25  56.666667
# 2      14                    Ctgf-T2A-dgCre  43.333333
# 3      20                      Cux2-CreERT2  51.666667
# 4      26                     Gad2-IRES-Cre  43.589744
# 5      32                 Glt25d2-Cre_NF107  66.666667
# 6      38     Htr3a-Cre_NO152;Pvalb-T2A-Dre  56.250000
# 7      44                  Ndnf-IRES2-dgCre  55.555556
# 8      50                    Nkx2-1-CreERT2  44.444444
# 9      56                         Nr5a1-Cre  39.130435
# 10     62                      Oxtr-T2A-Cre  66.666667
# 11     68                    Pvalb-IRES-Cre  31.182796
# 12     74                    Rbp4-Cre_KL100  60.683761
# 13     80                    Rorb-IRES2-Cre  23.214286
# 14     86                Rorb-IRES2-Cre-neo  43.137255
# 15     92                    Scnn1a-Tg2-Cre  40.909091
# 16     98                    Scnn1a-Tg3-Cre  27.586207
# 17    104                 Slc17a8-IRES2-Cre  60.000000
# 18    110                  Slc32a1-IRES-Cre  53.711790
# 19    116                      Sst-IRES-Cre  37.142857
# 20    122                      Vip-IRES-Cre  45.238095
# 21    128               Vipr2-IRES2-Cre-neo  66.666667
# 22    134    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO   0.000000
# 23    140  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO  28.070175
#
#                             Cre_line  post_patch_count
# 0                  Chat-IRES-Cre-neo              27.0
# 1                    Chrna2-Cre_OE25              30.0
# 2                     Ctgf-T2A-dgCre              30.0
# 3                       Cux2-CreERT2              60.0
# 4                      Gad2-IRES-Cre             195.0
# 5                  Glt25d2-Cre_NF107              12.0
# 6      Htr3a-Cre_NO152;Pvalb-T2A-Dre              16.0
# 7                   Ndnf-IRES2-dgCre               9.0
# 8                     Nkx2-1-CreERT2               9.0
# 9                          Nr5a1-Cre              23.0
# 10                      Oxtr-T2A-Cre               6.0
# 11                    Pvalb-IRES-Cre              93.0
# 12                    Rbp4-Cre_KL100             117.0
# 13                    Rorb-IRES2-Cre             112.0
# 14                Rorb-IRES2-Cre-neo              51.0
# 15                    Scnn1a-Tg2-Cre              22.0
# 16                    Scnn1a-Tg3-Cre              29.0
# 17                 Slc17a8-IRES2-Cre              15.0
# 18                  Slc32a1-IRES-Cre             229.0
# 19                      Sst-IRES-Cre              70.0
# 20                      Vip-IRES-Cre             168.0
# 21               Vipr2-IRES2-Cre-neo               3.0
# 22    Vipr2-IRES2-Cre;Pvalb-T2A-FlpO               2.0
# 23  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO              57.0

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
import math

# %% [markdown]
# # Import Sheet as csv

# %%
ps = pd.read_csv('patch_seq_log_mouse.csv')

# %% [markdown]
# # Format sheet

# %%
ps = ps[["Date", "User", "File", "Post patch?", "Notes", "Picogreen", "Conc.", ">400", "Ratio", "SM_QC_PF", "Bad dates"]]
#ps.dropna(subset = ["SM_QC_PF", "Post patch?"], inplace = True)
ps.dropna(subset = ["Notes", "Picogreen"], inplace = True)
ps["User"] = ps["User"].astype("category")
ps["SM_QC_PF"] = ps["SM_QC_PF"].astype("category")
ps["Post patch?"] = ps["Post patch?"].astype("category")
ps["Picogreen"] = pd.to_numeric(ps["Picogreen"].str.replace(' ',''), errors='force')
ps["Conc."] = pd.to_numeric(ps["Conc."].str.replace(' ',''), errors ='force')
ps[">400"] = pd.to_numeric(ps[">400"].str.replace(' ',''), errors ='force')
ps["Date"] = pd.to_datetime(ps["Date"], format = '%y%m%d')
ps = ps[ps["SM_QC_PF"] != "cnt"]
ps = ps[ps["Bad dates"] != "x"]
ps
# Out:
#            Date User                                   File      Post patch?  \
# 5005 2017-04-20   P2      Vip-IRES-Cre;Ai14-313534.04.01.02          No-Seal
# 5006 2017-04-20   P2      Vip-IRES-Cre;Ai14-313534.04.01.03          No-Seal
# 5008 2017-04-20   P2      Vip-IRES-Cre;Ai14-313534.04.01.05      Outside-Out
# 5018 2017-04-21   P1     Gad2-IRES-Cre;Ai14-313294.03.01.03          No-Seal
# 5019 2017-04-21   P1     Gad2-IRES-Cre;Ai14-313294.03.01.04          No-Seal
# 5020 2017-04-21   P1     Gad2-IRES-Cre;Ai14-313294.04.01.01          No-Seal
# 5021 2017-04-21   P1     Gad2-IRES-Cre;Ai14-313294.04.01.02  Partial-Nucleus
# 5022 2017-04-21   P1     Gad2-IRES-Cre;Ai14-313294.04.01.03        Nucleated
# 5023 2017-04-21   P1     Gad2-IRES-Cre;Ai14-313294.04.01.04          No-Seal
# 5026 2017-04-21   P2     Gad2-IRES-Cre;Ai14-313294.03.02.01        Nucleated
# 5027 2017-04-21   P2     Gad2-IRES-Cre;Ai14-313294.03.02.02        Nucleated
# 5031 2017-04-21   P2     Gad2-IRES-Cre;Ai14-313294.04.02.03          No-Seal
# 5034 2017-04-21   P2     Gad2-IRES-Cre;Ai14-313294.05.01.02          No-Seal
# 5042 2017-04-24   P1    Scnn1a-Tg3-Cre;Ai14-315865.04.01.01          No-Seal
# 5043 2017-04-24   P1    Scnn1a-Tg3-Cre;Ai14-315865.04.01.02              NaN
# 5044 2017-04-24   P1    Scnn1a-Tg3-Cre;Ai14-315865.04.01.03          No-Seal
# 5045 2017-04-24   P1    Scnn1a-Tg3-Cre;Ai14-315865.04.01.04        Nucleated
# 5046 2017-04-24   P1    Scnn1a-Tg3-Cre;Ai14-315865.04.01.05          No-Seal
# 5047 2017-04-24   P1    Rorb-IRES2-Cre;Ai14-315898.03.01.01  Partial-Nucleus
# 5048 2017-04-24   P1    Rorb-IRES2-Cre;Ai14-315898.03.01.02          No-Seal
# 5049 2017-04-24   P1    Rorb-IRES2-Cre;Ai14-315898.03.01.03          No-Seal
# 7531 2017-10-11   P8     Sim1-Cre_KJ18;Ai14-350522.03.02.03   nucleus_absent
# 7532 2017-10-11   P8      Vip-IRES-Cre;Ai14-355068.05.02.01  nucleus_present
# 7533 2017-10-11   P8      Vip-IRES-Cre;Ai14-355068.05.02.02   nucleus_absent
# 7534 2017-10-11   PA     Sim1-Cre_KJ18;Ai14-350522.05.01.01  nucleus_present
# 7535 2017-10-11   PA     Sim1-Cre_KJ18;Ai14-350522.04.01.01   nucleus_absent
# 7536 2017-10-11   PB  Ndnf-IRES2-dgCre;Ai14-353742.03.01.01   nucleus_absent
# 7537 2017-10-11   PB     Sim1-Cre_KJ18;Ai14-350522.04.02.01  nucleus_present
# 7538 2017-10-11   PB     Sim1-Cre_KJ18;Ai14-350522.04.02.02  nucleus_present
#
#                                                   Notes  Picogreen   Conc.  \
# 5005              approached angle same as tissue angle     1012.0   978.8
# 5006                 approach angle same as slice angle      940.0  1166.6
# 5008                lost seal on cell during extraction     1671.0  2624.2
# 5018                                        Cell Dimmed      517.0   538.4
# 5019                            Fluorescence in Pipette     1425.0  2274.5
# 5020          Fluorescence in Pipette,Cell Dimmed   1.0      386.0   583.2
# 5021                Fluorescence in Pipette,Cell Dimmed      842.0  1157.7
# 5022                Fluorescence in Pipette,Cell Dimmed     1211.0  1403.9
# 5023                            Fluorescence in Pipette      683.0  1120.8
# 5026                            Fluorescence in Pipette     1272.0  1827.1
# 5027                            Fluorescence in Pipette      775.0   996.6
# 5031                            Fluorescence in Pipette      664.0   991.8
# 5034                            Fluorescence in Pipette      343.0   496.8
# 5042                            Fluorescence in Pipette      344.0   567.0
# 5043                            Fluorescence in Pipette      344.0   431.2
# 5044                Fluorescence in Pipette,Cell Dimmed      404.0   526.6
# 5045                            Fluorescence in Pipette     1419.0  1579.8
# 5046                Fluorescence in Pipette,Cell Dimmed      723.0  1245.2
# 5047                Cell Dimmed   lots of small bubbles      384.0   423.5
# 5048                                         no bubbles      360.0   492.2
# 5049                                   one large bubble      590.0   792.0
# 5050                     Cell Dimmed   one large bubble      766.0  1411.6
# 5051      Fluorescence in Pipette   a few small bubbles      942.0  1657.5
# 5056                            Fluorescence in Pipette      654.0  1150.5
# 5059                   One big bubble during expulsion.     1062.0  1085.8
# 5060                       No bubbles during expulsion.     1228.0  2992.0
# 5061                 a few small bubbles upon expulsion      375.0   566.5
# 5062  Fluorescence in Pipette Lots of little bubble ...      385.0   623.6
# 5063  Fluorescence in Pipette One big bubble formed ...      751.0  1189.6
# 5070                  Cell Dimmed   a few small bubbles      355.0   657.8
# ...                                                 ...        ...     ...
# 7504                  not 100% sure nucleus was present     1231.0  1046.2
# 7505                                     Medium Bubbles      194.0   107.8
# 7506                          Cell Dimmed Small Bubbles      629.0   391.7
# 7507                                        Cell Dimmed     1395.0   955.8
# 7508  Fluorescence in Pipette No Bubbles alexa fill ...     3876.0  2844.8
# 7509  Fluorescence in Pipette No Bubbles alexa fill ...     1054.0   331.1
# 7510  Fluorescence in Pipette No Bubbles alexa fill ...      904.0   518.6
# 7511     No Bubbles alexa fill visible post experiment.     3000.0  1025.9
# 7512  Fluorescence in Pipette No Bubbles alexa fill ...      715.0   432.5
# 7513  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1048.0   194.0
# 7514  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1093.0   234.2
# 7515  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1968.0  1093.2
# 7516  Fluorescence in Pipette,Cell Dimmed,Cell Swell...      358.0   193.2
# 7517  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     2195.0   910.2
# 7518  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...      716.0   213.8
# 7519  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1605.0   651.2
# 7520  Cell Disappeared No Bubbles In wave of death w...      916.0   602.2
# 7526  Fluorescence in Pipette No Bubbles alexa fill ...     2026.0  1244.2
# 7527  Fluorescence in Pipette No Bubbles alexa fill ...      930.0   381.2
# 7528  Fluorescence in Pipette Medium Bubbles alexa f...     1656.0  1157.8
# 7529  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1656.0   487.9
# 7530  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     3051.0  1551.8
# 7531  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1619.0   496.4
# 7532  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1604.0  1293.5
# 7533  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...      405.0   242.6
# 7534  Fluorescence in Pipette No Bubbles Nucleated p...      617.0   425.8
# 7535  Cell Disappeared No Bubbles Had nucleus attach...     1634.0  1189.6
# 7536                            Fluorescence in Pipette      430.0   228.7
# 7537                             Medium Bubbles perfect     2251.0  1352.6
# 7538                                            perfect     2125.0  1142.3
#
#           >400 Ratio SM_QC_PF Bad dates
# 5005   558.000  0.57     pass       NaN
# 5006   506.000  0.43     pass       NaN
# 5008  1770.000  0.67     pass       NaN
# 5018   309.000  0.57     fail       NaN
# 5019  1264.000  0.56     pass       NaN
# 5020   425.000  0.73     pass       NaN
# 5021   933.000  0.81     pass       NaN
# 5022  1136.000  0.81     pass       NaN
# 5023   649.000  0.58     pass       NaN
# 5026  1111.000  0.61     pass       NaN
# 5027   746.000  0.75     pass       NaN
# 5031   789.000   0.8     pass       NaN
# 5034   375.000  0.76     fail       NaN
# 5042   398.000   0.7     pass       NaN
# 5043   262.000  0.61     pass       NaN
# 5044   307.000  0.58     fail       NaN
# 5045  1055.000  0.67     pass       NaN
# 5046   651.000  0.52     pass       NaN
# 5047   298.000   0.7     fail       NaN
# 5048   276.000  0.56     fail       NaN
# 5049   377.000  0.48     fail       NaN
# 5050   689.000  0.49     pass       NaN
# 5051  1091.000  0.66     pass       NaN
# 5056   534.000  0.46     pass       NaN
# 5059   416.000  0.38     pass       NaN
# 5060   881.000  0.29     pass       NaN
# 5061   346.000  0.61     fail       NaN
# 5062   305.000  0.49     fail       NaN
# 5063   748.000  0.63     pass       NaN
# 5070   338.000  0.51     pass       NaN
# ...        ...   ...      ...       ...
# 7504   659.106   63%     pass       NaN
# 7505    26.950   25%     fail       NaN
# 7506   180.182   46%     pass       NaN
# 7507   506.574   53%     pass       NaN
# 7508  1906.016   67%     pass       NaN
# 7509    82.775   25%     fail       NaN
# 7510   259.300   50%     pass       NaN
# 7511   297.511   29%     fail       NaN
# 7512   229.225   53%     pass       NaN
# 7513    23.280   12%     fail       NaN
# 7514    35.130   15%     fail       NaN
# 7515   557.532   51%     pass       NaN
# 7516    63.756   33%     fail       NaN
# 7517   254.856   28%     pass       NaN
# 7518    49.174   23%     fail       NaN
# 7519   214.896   33%     pass       NaN
# 7520   337.232   56%     pass       NaN
# 7526   684.310   55%     pass       NaN
# 7527   121.984   32%     fail       NaN
# 7528   683.102   59%     pass       NaN
# 7529   102.459   21%     fail       NaN
# 7530   682.792   44%     pass       NaN
# 7531   124.100   25%     pass       NaN
# 7532   776.100   60%     pass       NaN
# 7533    92.188   38%     fail       NaN
# 7534   217.158   51%     fail       NaN
# 7535   749.448   63%     pass       NaN
# 7536    82.332   36%     fail       NaN
# 7537   730.404   54%     pass       NaN
# 7538   536.881   47%     pass       NaN
#
# [1681 rows x 11 columns]

# %%
bubble_data = ps["Notes"].str.contains("No Bubbles") | ps["Notes"].str.contains("Solution in Pipette Shank")
bubble_data = ps[bubble_data]
up_shank = '((?<=Solution).*?(?=Shank))'
bubble_data["Bubble_data"] = bubble_data["Notes"].str.extract(up_shank).fillna("No Bubbles")
bubble_data["Bubble_data"] = bubble_data["Bubble_data"].str.replace('in Pipette', 'Solution up Pipette Shank')
#bubble_data["Bubble_data"].value_counts()
bubble_data
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Date User                                   File      Post patch?  \
# 5461 2017-05-16   P1     Gad2-IRES-Cre;Ai14-318382.04.01.02          No-Seal
# 5467 2017-05-16   P2     Gad2-IRES-Cre;Ai14-318382.03.02.02        Nucleated
# 5468 2017-05-16   P2     Gad2-IRES-Cre;Ai14-318382.03.02.03        Nucleated
# 5483 2017-05-17   P1     Gad2-IRES-Cre;Ai14-318381.05.01.01          No-Seal
# 5484 2017-05-17   P1     Gad2-IRES-Cre;Ai14-318381.05.01.02          No-Seal
# 5491 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.03.02.01  Partial-Nucleus
# 5493 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.03.02.03      Outside-Out
# 5494 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.04.02.01        Nucleated
# 5495 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.04.02.02        Nucleated
# 5496 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.04.02.03          No-Seal
# 5497 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.04.02.04        Nucleated
# 5498 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.04.02.05        Nucleated
# 5499 2017-05-17   P2     Gad2-IRES-Cre;Ai14-318381.04.02.06        Nucleated
# 5503 2017-05-17   P6     Gad2-IRES-Cre;Ai14-318381.04.01.02  Partial-Nucleus
# 5520 2017-05-18   P2    Pvalb-IRES-Cre;Ai14-316465.03.02.01  Partial-Nucleus
# 5521 2017-05-18   P2    Pvalb-IRES-Cre;Ai14-316465.03.02.02          No-Seal
# 5522 2017-05-18   P2    Pvalb-IRES-Cre;Ai14-316465.03.02.03          No-Seal
# 5524 2017-05-18   P2    Pvalb-IRES-Cre;Ai14-316465.04.02.01        Nucleated
# 5525 2017-05-18   P2    Pvalb-IRES-Cre;Ai14-316465.04.02.02        Nucleated
# 5529 2017-05-18   P2    Pvalb-IRES-Cre;Ai14-316465.06.01.02          No-Seal
# 5532 2017-05-18   P6    Pvalb-IRES-Cre;Ai14-316465.03.01.01      Entire-Cell
# 5533 2017-05-18   P6    Pvalb-IRES-Cre;Ai14-316465.03.01.02        Nucleated
# 7529 2017-10-11   P8     Sim1-Cre_KJ18;Ai14-350522.03.02.01   nucleus_absent
# 7530 2017-10-11   P8     Sim1-Cre_KJ18;Ai14-350522.03.02.02  nucleus_present
# 7531 2017-10-11   P8     Sim1-Cre_KJ18;Ai14-350522.03.02.03   nucleus_absent
# 7532 2017-10-11   P8      Vip-IRES-Cre;Ai14-355068.05.02.01  nucleus_present
# 7533 2017-10-11   P8      Vip-IRES-Cre;Ai14-355068.05.02.02   nucleus_absent
# 7534 2017-10-11   PA     Sim1-Cre_KJ18;Ai14-350522.05.01.01  nucleus_present
# 7535 2017-10-11   PA     Sim1-Cre_KJ18;Ai14-350522.04.01.01   nucleus_absent
#
#                                                   Notes  Picogreen   Conc.  \
# 5461  Small Bubbles,Large Bubbles,Solution in Pipett...      423.0   335.6
# 5467                                         No Bubbles     1026.0   904.0
# 5468                                         No Bubbles      816.0   760.2
# 5483  Medium Bubbles,Large Bubbles,Solution in Pipet...      410.0   281.6
# 5484            Large Bubbles,Solution in Pipette Shank      423.0   241.9
# 5491  No Bubbles got nucleus and gigaohm seal but th...     3039.0  2569.0
# 5493  No Bubbles lost seal on cell during extraction...     1122.0   758.6
# 5494            Large Bubbles,Solution in Pipette Shank     1170.0   988.1
# 5495                                         No Bubbles      961.0   644.3
# 5496                                         No Bubbles      485.0   325.1
# 5497                                         No Bubbles     1095.0   783.0
# 5498                                         No Bubbles     1072.0   742.8
# 5499                                         No Bubbles     1134.0  1027.3
# 5503                                         No Bubbles      570.0   376.6
# 5520                 Fluorescence in Pipette No Bubbles     1481.0  1333.8
# 5521  Fluorescence in Pipette Large Bubbles,Solution...      504.0   333.9
# 5522                 Fluorescence in Pipette No Bubbles      872.0   787.8
# 5524                 Fluorescence in Pipette No Bubbles      828.0   685.0
# 5525                 Fluorescence in Pipette No Bubbles     1338.0   926.0
# 5529                 Fluorescence in Pipette No Bubbles     1380.0  1496.9
# 5532                                         No Bubbles     1034.0   815.3
# 5533                 Fluorescence in Pipette No Bubbles     1510.0  1172.4
# 5534                                         No Bubbles      661.0   607.7
# 5535               No Bubbles,Solution in Pipette Shank      658.0   636.1
# 5536                                         No Bubbles      266.0   205.3
# 5537                                         No Bubbles     1217.0   978.9
# 5539                                         No Bubbles     1314.0  1487.3
# 5547  Fluorescence in Pipette,Cell Dimmed   Small Bu...      261.0   241.4
# 5556                 Fluorescence in Pipette No Bubbles     1314.0  3020.7
# 5558                 Fluorescence in Pipette No Bubbles     1124.0  2245.1
# ...                                                 ...        ...     ...
# 7493  Fluorescence in Pipette No Bubbles Alexa fill ...     1799.0   707.1
# 7494  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1346.0  1188.5
# 7495  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...      602.0   281.3
# 7496  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1309.0   554.5
# 7497  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...      847.0   469.7
# 7498  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     2655.0  1633.1
# 7500  Cell Dimmed No Bubbles The cell was in the wav...      916.0   556.8
# 7503                                         No Bubbles     1062.0   768.2
# 7508  Fluorescence in Pipette No Bubbles alexa fill ...     3876.0  2844.8
# 7509  Fluorescence in Pipette No Bubbles alexa fill ...     1054.0   331.1
# 7510  Fluorescence in Pipette No Bubbles alexa fill ...      904.0   518.6
# 7511     No Bubbles alexa fill visible post experiment.     3000.0  1025.9
# 7512  Fluorescence in Pipette No Bubbles alexa fill ...      715.0   432.5
# 7513  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1048.0   194.0
# 7514  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1093.0   234.2
# 7515  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1968.0  1093.2
# 7516  Fluorescence in Pipette,Cell Dimmed,Cell Swell...      358.0   193.2
# 7517  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     2195.0   910.2
# 7518  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...      716.0   213.8
# 7519  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1605.0   651.2
# 7520  Cell Disappeared No Bubbles In wave of death w...      916.0   602.2
# 7526  Fluorescence in Pipette No Bubbles alexa fill ...     2026.0  1244.2
# 7527  Fluorescence in Pipette No Bubbles alexa fill ...      930.0   381.2
# 7529  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1656.0   487.9
# 7530  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     3051.0  1551.8
# 7531  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1619.0   496.4
# 7532  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...     1604.0  1293.5
# 7533  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...      405.0   242.6
# 7534  Fluorescence in Pipette No Bubbles Nucleated p...      617.0   425.8
# 7535  Cell Disappeared No Bubbles Had nucleus attach...     1634.0  1189.6
#
#           >400 Ratio SM_QC_PF Bad dates                  Bubble_data
# 5461   169.000   0.5     fail       NaN   Solution up Pipette Shank
# 5467   644.000  0.71     pass       NaN                   No Bubbles
# 5468   570.000  0.75     pass       NaN                   No Bubbles
# 5483   116.000  0.41     fail       NaN   Solution up Pipette Shank
# 5484   125.000  0.52     fail       NaN   Solution up Pipette Shank
# 5491   750.000  0.29     pass       NaN                   No Bubbles
# 5493   608.000   0.8     pass       NaN                   No Bubbles
# 5494   494.000   0.5     pass       NaN   Solution up Pipette Shank
# 5495   423.000  0.66     pass       NaN                   No Bubbles
# 5496   125.000  0.38     fail       NaN                   No Bubbles
# 5497   614.000  0.78     pass       NaN                   No Bubbles
# 5498   606.000  0.82     pass       NaN                   No Bubbles
# 5499   512.000   0.5     pass       NaN                   No Bubbles
# 5503   163.000  0.43     fail       NaN                   No Bubbles
# 5520   580.000  0.43     pass       NaN                   No Bubbles
# 5521   172.000  0.51     fail       NaN   Solution up Pipette Shank
# 5522   666.000  0.85     pass       NaN                   No Bubbles
# 5524   216.000  0.31     pass       NaN                   No Bubbles
# 5525   679.000  0.73     pass       NaN                   No Bubbles
# 5529   850.000  0.57     pass       NaN                   No Bubbles
# 5532   613.000  0.75     pass       NaN                   No Bubbles
# 5533   807.000  0.69     pass       NaN                   No Bubbles
# 5534   337.000  0.55     pass       NaN                   No Bubbles
# 5535   316.000   0.5     pass       NaN   Solution up Pipette Shank
# 5536    82.000   0.4     fail       NaN                   No Bubbles
# 5537   493.000   0.5     pass       NaN                   No Bubbles
# 5539   915.000  0.62     pass       NaN                   No Bubbles
# 5547    73.000   0.3     fail       NaN   Solution up Pipette Shank
# 5556  2090.000  0.69     pass       NaN                   No Bubbles
# 5558  1757.000  0.78     pass       NaN                   No Bubbles
# ...        ...   ...      ...       ...                          ...
# 7493   247.485   35%     pass       NaN                   No Bubbles
# 7494   867.605   73%     pass       NaN                   No Bubbles
# 7495    81.577   29%     fail       NaN                   No Bubbles
# 7496   182.985   33%     fail       NaN                   No Bubbles
# 7497   169.092   36%     pass       NaN                   No Bubbles
# 7498   849.212   52%     pass       NaN                   No Bubbles
# 7500   239.424   43%     pass       NaN                   No Bubbles
# 7503   437.874   57%     pass       NaN                   No Bubbles
# 7508  1906.016   67%     pass       NaN                   No Bubbles
# 7509    82.775   25%     fail       NaN                   No Bubbles
# 7510   259.300   50%     pass       NaN                   No Bubbles
# 7511   297.511   29%     fail       NaN                   No Bubbles
# 7512   229.225   53%     pass       NaN                   No Bubbles
# 7513    23.280   12%     fail       NaN                   No Bubbles
# 7514    35.130   15%     fail       NaN                   No Bubbles
# 7515   557.532   51%     pass       NaN                   No Bubbles
# 7516    63.756   33%     fail       NaN                   No Bubbles
# 7517   254.856   28%     pass       NaN                   No Bubbles
# 7518    49.174   23%     fail       NaN                   No Bubbles
# 7519   214.896   33%     pass       NaN                   No Bubbles
# 7520   337.232   56%     pass       NaN                   No Bubbles
# 7526   684.310   55%     pass       NaN                   No Bubbles
# 7527   121.984   32%     fail       NaN                   No Bubbles
# 7529   102.459   21%     fail       NaN                   No Bubbles
# 7530   682.792   44%     pass       NaN                   No Bubbles
# 7531   124.100   25%     pass       NaN                   No Bubbles
# 7532   776.100   60%     pass       NaN                   No Bubbles
# 7533    92.188   38%     fail       NaN                   No Bubbles
# 7534   217.158   51%     fail       NaN                   No Bubbles
# 7535   749.448   63%     pass       NaN                   No Bubbles
#
# [712 rows x 12 columns]

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1681 entries, 5005 to 7538
# Data columns (total 11 columns):
# Date           1681 non-null datetime64[ns]
# User           1681 non-null category
# File           1681 non-null object
# Post patch?    1675 non-null category
# Notes          1681 non-null object
# Picogreen      1679 non-null float64
# Conc.          1676 non-null float64
# >400           1651 non-null float64
# Ratio          1678 non-null object
# SM_QC_PF       1679 non-null category
# Bad dates      0 non-null object
# dtypes: category(3), datetime64[ns](1), float64(3), object(4)
# memory usage: 123.3+ KB

# %% [markdown]
# # Percentage of nucleated patches passing SM_QC

# %%
mask = ps["Post patch?"] == "Nucleated"
mask
nuc = ps[mask]
nuc.head()
nuc_count = nuc["Post patch?"].count()
nuc_count
# Out:
# 1055

# %%
ps["Post patch?"].value_counts()
# Out:
# Nucleated             1055
# No-Seal                969
# Outside-Out            907
# Partial-Nucleus        411
# nr                     178
# Entire-Cell             38
# nucleus_present         32
# nucleus_absent          14
# no-seal                  5
# no_nucleus_visible       4
# nucleus_visible          3
# Outside-Out?             1
# outside-out              1
# entire_cell              1
# missing                  1
# nucelated                1
# no -seal                 1
# Name: Post patch?, dtype: int64

# %%
pas = ps["SM_QC_PF"] == "pass"
pas.head()
# Out:
# 251    False
# 252    False
# 253    False
# 254     True
# 255    False
# Name: SM_QC_PF, dtype: bool

# %%
np = ps[mask & pas]
np
# Out:
#            Date User                                             File  \
# 268  2016-04-06   P5                             Ndnf - brl_160406_04
# 280  2016-04-07   P1                             Ndnf - kjh_160407_03
# 303  2016-04-11   P5                             Rorb - brl_160411_02
# 320  2016-04-12   P5                             Rorb - brl_160412_01
# 360  2016-04-18   P5                             Chat - brl_160418_02
# 363  2016-04-18   P5                             Chat - brl_160418_05
# 376  2016-04-19   P1                             Chat - kjh_160419_03
# 395  2016-04-20   P1                              Vip - kjh_160420_10
Nucleated  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  1097.60
# 7329   Nucleated  Cell Dimmed No Bubbles seems like nucleus suck...   274.20
# 7331   Nucleated      Cell Dimmed No Bubbles Retention Time = 3 min   690.70
# 7332   Nucleated                        Cell Swelled Medium Bubbles  1152.60
# 7333   Nucleated                                      Small Bubbles   555.10
# 7334   Nucleated                                                NaN  1450.60
# 7335   Nucleated                                                NaN   758.50
# 7339   Nucleated  Fluorescence in Pipette Medium Bubbles 2.83 mi...   628.80
# 7342   Nucleated  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...   935.80
# 7343   Nucleated  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  1409.80
# 7344   Nucleated  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...   716.70
# 7345   Nucleated  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...   528.10
# 7349   Nucleated  Cell Dimmed,Cell Swelled No Bubbles Retraction...   524.90
# 7350   Nucleated     Cell Dimmed No Bubbles Retraction Time = 2 min   732.40
# 7351   Nucleated                Small Bubbles 2 min retraction time   369.50
# 7352   Nucleated               Medium Bubbles 2 min retraction time  1019.70
# 7357   Nucleated  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...   392.50
# 7364   Nucleated                Cell Dimmed 3 min retraction period   895.40
#
#        >400 Ratio SM_QC_PF                                          Bad dates
# 268   167.0  0.69     pass                                                NaN
# 280    96.0  0.73     pass                                                NaN
# 303    92.0  0.63     pass                                                NaN
# 320   183.0  0.87     pass                                   no slide in LIMS
# 360   116.0  0.85     pass                                                NaN
# 363   113.0  0.62     pass                                                NaN
# 376   203.0  0.48     pass                                                NaN
# 395   338.0  0.64     pass                                                NaN
# 439   282.0  0.73     pass  cell is between 01 and 02 (different than cell...
# 441   332.0  0.72     pass                                                NaN
# 447   163.0  0.73     pass  no axon, boarder of layer 1/2, can't say type,...
# 449   210.0  0.61     pass  blebby dendrites, layer 2/3, d takes 90 degree...
# 468   154.0  0.48     pass                                                NaN
# 469   286.0  0.63     pass                                                NaN
# 474   168.0  0.26     pass                                                NaN
# 478   170.0  0.29     pass                                                NaN
# 479   292.0  0.57     pass                                                NaN
# 499    71.0   0.4     pass                                                NaN
# 505   196.0  0.72     pass                                                NaN
# 509   183.0  0.58     pass                                                NaN
# 523   162.0  0.41     pass                                                NaN
# 524   323.0  0.71     pass                                                NaN
# 528   201.0  0.52     pass                                                NaN
# 537   235.0  0.68     pass                                                NaN
# 541   176.0  0.82     pass                                                NaN
# 601   386.0  0.48     pass                                                NaN
# 644   217.0  0.54     pass                                                NaN
# 657    32.0  0.26     pass                                                NaN
# 687    76.0  0.78     pass                                                NaN
# 691    52.0  0.57     pass                                                NaN
# ...     ...   ...      ...                                                ...
# 7310    NaN   62%     pass                                                NaN
# 7311    NaN   81%     pass                                                NaN
# 7314    NaN   55%     pass                                                NaN
# 7315    NaN   53%     pass                                                NaN
# 7316    NaN   51%     pass                                                NaN
# 7317    NaN   47%     pass                                                NaN
# 7318    NaN   58%     pass                                                NaN
# 7319    NaN   57%     pass                                                NaN
# 7323    NaN   54%     pass                                                NaN
# 7324    NaN   55%     pass                                                NaN
# 7325    NaN   73%     pass                                                NaN
# 7326    NaN   59%     pass                                                NaN
# 7328    NaN   81%     pass                                                NaN
# 7329    NaN   41%     pass                                                NaN
# 7331    NaN   66%     pass                                                NaN
# 7332    NaN   49%     pass                                                NaN
# 7333    NaN   43%     pass                                                NaN
# 7334    NaN   48%     pass                                                NaN
# 7335    NaN   67%     pass                                                NaN
# 7339    NaN   60%     pass                                                NaN
# 7342    NaN   52%     pass                                                NaN
# 7343    NaN   73%     pass                                                NaN
# 7344    NaN   53%     pass                                                NaN
# 7345    NaN   49%     pass                                                NaN
# 7349    NaN   67%     pass                                                NaN
# 7350    NaN   56%     pass                                                NaN
# 7351    NaN   42%     pass                                                NaN
# 7352    NaN   70%     pass                                                NaN
# 7357    NaN   31%     pass                                                NaN
# 7364    NaN   62%     pass                                                NaN
#
# [896 rows x 10 columns]

# %%
nuc_pass = np["Post patch?"].count()
nuc_pass
#np["Post patch?"].count()
# Out:
# 896

# %%
float(nuc_pass)/nuc_count
# Out:
# 0.8492890995260663

# %% [markdown]
# # Bubbles Analysis

# %%
bubbles = ps.dropna(subset = ["Notes"])
bubbles
# Out:
#            Date User                                             File  \
# 252  2016-03-18   P5                             Ndnf - brl_160318_02
# 254  2016-03-18   P5                             Ndnf - brl_160318_04
# 256  2016-03-18   P5                             Ndnf - brl_160318_06
# 258  2016-03-18   P5                              Ndnf - brl_160318_x
# 259  2016-03-18   P5                             Ndnf - brl_160318_08
# 267  2016-04-06   P5                             Ndnf - brl_160406_03
# 269  2016-04-06   P5                             Ndnf - brl_160406_05
# 270  2016-04-06   P5                             Ndnf - brl_160406_06
# 279  2016-04-07   P1                             Ndnf - kjh_160407_02
# 280  2016-04-07   P1                             Ndnf - kjh_160407_03
# 281  2016-04-07   P1                             Ndnf - kjh_160407_04
# 282  2016-04-07   P1                             Ndnf - kjh_160407_05
# 283  2016-04-07   P1                             Ndnf - kjh_160407_06
# 284  2016-04-07   P1                             Ndnf - kjh_160407_07
# 291  2016-04-08   P5                              Vip - brl_160408_01
# 292  2016-04-08   P5                              Vip - brl_160408_02
# 293  2016-04-08   P5                              Vip - brl_160408_03
# 295  2016-04-08   P5                              Vip - brl_160408_05
# 297  2016-04-08   P1                              Vip - kjh_160408_01
# 299  2016-04-08   P1                              Vip - kjh_160408_03
# 300  2016-04-08   P1                              Vip - kjh_160408_04
# 301  2016-04-08   P1                              Vip - kjh_160408_05
# 302  2016-04-11   P5                             Rorb - brl_160411_01
# 304  2016-04-11   P5                             Rorb - brl_160411_03
# 305  2016-04-11   P5                             Rorb - brl_160411_04
# 310  2016-04-11   P1                             Rorb - kjh_160411_01
# 311  2016-04-11   P1                             Rorb - kjh_160411_02
# 312  2016-04-11   P1                             Rorb - kjh_160411_03
# 313  2016-04-11   P1                             Rorb - kjh_160411_04
# 314  2016-04-11   P1                             Rorb - kjh_160411_05
# ...         ...  ...                                              ...
# 7381 2017-10-03   P2                   Nr5a1-Cre;Ai14-350880.03.02.01
# 7382 2017-10-03   P2                   Nr5a1-Cre;Ai14-350880.03.02.02
# 7383 2017-10-03   P8               Gad2-IRES-Cre;Ai14-350674.04.02.01
# 7384 2017-10-03   P8               Gad2-IRES-Cre;Ai14-350674.04.02.02
# 7385 2017-10-03   P8             Chrna2-Cre_OE25;Ai14-351070.04.02.01
# 7389 2017-10-03   P8                Oxtr-T2A-Cre;Ai14-351470.05.01.01
# 300                   nr  saw material in pipette, cell disappeared sudd...
# 301      Partial-Nucleus   saw fluorescence in pipette, cell visibly shrunk
# 302                   nr  dislosdged nucleus and extracted or another mi...
# 304          Outside-Out                        good Outside-Out with image
# 305                   nr                                           swelling
# 310                   nr  saw fluorescence in pipette, cell almost disap...
# 311          Outside-Out            cell shrunk, didn't see much in pipette
# 312      Partial-Nucleus     cell swelled, fluorescence disappeared quickly
# 313      Partial-Nucleus     cell swelled, fluorescence disappeared quickly
# 314                   nr      saw some fluorescence in pipette, cell dimmed
# ...                  ...                                                ...
# 7381     nucleus_present  Fluorescence in Pipette Small Bubbles,Medium B...
# 7382     nucleus_present  Fluorescence in Pipette Small Bubbles alexa fi...
# 7383     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Swell...
# 7384      nucleus_absent  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7385     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7389     nucleus_present  Fluorescence in Pipette No Bubbles Alexa fill ...
# 7390     nucleus_present                 Fluorescence in Pipette No Bubbles
# 7391      nucleus_absent  Fluorescence in Pipette No Bubbles Outside-Out...
# 7392     nucleus_present                             Cell Dimmed No Bubbles
# 7393     nucleus_present                             Cell Dimmed No Bubbles
# 7394     nucleus_present  Cell Dimmed Small Bubbles Partial-Nucleated: I...
# 7395      nucleus_absent  Cell Dimmed No Bubbles nucleus came off of pip...
# 7402     nucleus_present                             Cell Dimmed No Bubbles
# 7403     nucleus_present                          Cell Dimmed Small Bubbles
# 7404  no_nucleus_visible  Cell Dimmed Medium Bubbles cell elongated and ...
# 7405     nucleus_visible                          Cell Dimmed Large Bubbles
# 7406  no_nucleus_visible  Fluorescence in Pipette,Cell Dimmed nucleus ma...
# 7407     nucleus_present                                      Small Bubbles
# 7408     nucleus_present                                     Medium Bubbles
# 7409     nucleus_present                                      Large Bubbles
# 7410         entire_cell  Fluorescence in Pipette Medium Bubbles cell de...
# 7418     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7419     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7420     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7421     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7422      nucleus_absent  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7423      nucleus_absent  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7424     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7425     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7426     nucleus_present  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
#
#         Conc.    >400 Ratio SM_QC_PF Bad dates
# 252   3649.03     NaN   NaN     fail       NaN
# 254    320.83  278.00  0.81     pass       NaN
# 256    188.27     NaN   NaN     fail       NaN
# 258    211.35  200.00  0.84     pass       NaN
# 259      4.69    4.00   NaN     fail       NaN
# 267    100.61   37.65   NaN     fail       NaN
# 269    125.58   92.00  0.61     pass       NaN
# 270     92.49   78.00  0.75     pass       NaN
# 279     40.19   33.54   NaN     fail       NaN
# 280    114.09   96.00  0.73     pass       NaN
# 281    129.23  111.00  0.79     pass       NaN
# 282     32.87   27.30   NaN     fail       NaN
# 283     22.02   18.76   NaN     fail       NaN
# 284    117.47  100.00  0.75     pass       NaN
# 291    292.21  232.00  0.71     pass       NaN
# 292     54.43     NaN   NaN     fail       NaN
# 293    308.89  249.00  0.73     pass       NaN
# 295     98.20     NaN   NaN     fail       NaN
# 297    102.99  110.00  0.75     pass       NaN
# 299    187.99   23.00  0.12     fail       NaN
# 300    226.92  178.00  0.65     pass       NaN
# 301    110.66   77.00  0.49     pass       NaN
# 302     73.96   30.36   NaN     fail       NaN
# 304    104.80   40.57   NaN     fail       NaN
# 305    181.67   62.22   NaN     fail       NaN
# 310     24.58   17.83   NaN     fail       NaN
# 311    280.68   88.07   NaN     fail       NaN
# 312    220.12  135.00  0.58     pass       NaN
# 313    231.75  118.61   NaN     fail       NaN
# 314    133.42   73.55   NaN     fail       NaN
# ...       ...     ...   ...      ...       ...
# 7381   585.70     NaN   44%     pass       NaN
# 7382   386.90     NaN   45%     pass       NaN
# 7383   997.60     NaN   75%     pass       NaN
# 7384   293.10     NaN   43%     fail       NaN
# 7385   935.60     NaN   50%     pass       NaN
# 7389   807.60     NaN   73%     pass       NaN
# 7390  1882.80     NaN   70%     pass       NaN
# 7391   266.30     NaN   50%     fail       NaN
# 7392   554.30     NaN   50%     pass       NaN
# 7393  1034.50     NaN   49%     pass       NaN
# 7394   840.90     NaN   52%     pass       NaN
# 7395   445.70     NaN   59%     pass       NaN
# 7402   662.30     NaN   53%     pass       NaN
# 7403   547.70     NaN   57%     pass       NaN
# 7404   340.50     NaN   36%     fail       NaN
# 7405   802.80     NaN   67%     pass       NaN
# 7406   475.70     NaN   34%     pass       NaN
# 7407   702.20     NaN   45%     pass       NaN
# 7408   422.40     NaN   27%     pass       NaN
# 7409  1048.40     NaN   74%     pass       NaN
# 7410   604.00     NaN   21%     fail       NaN
# 7418   583.00     NaN   57%     pass       NaN
# 7419   864.70     NaN   52%     pass       NaN
# 7420   733.30     NaN   62%     pass       NaN
# 7421   339.10     NaN   49%     pass       NaN
# 7422   316.50     NaN   30%     fail       NaN
# 7423   324.10     NaN   54%     pass       NaN
# 7424   665.40     NaN   57%     pass       NaN
# 7425   691.30     NaN   49%     pass       NaN
# 7426   899.60     NaN   60%     pass       NaN
#
# [2487 rows x 10 columns]

# %%
def make_mask(v,x):
    mask = v["Notes"].str.contains(x)
    df = v[mask]
    return df

def pass_only(y):
    mask = y["SM_QC_PF"] == "pass"
    df2 = y[mask]
    return df2

#Should also define a function to calculate pass percentages

# %%
def get_count(x):    
    count = x[">400"].count()
    return count

def get_sqrtct(x):
    sqrt_ct = math.sqrt(get_count(x))
    return sqrt_ct

def calc_mean(x):
    mean = x[">400"].mean()
    return mean

def calc_std(x):
    std_dev = x[">400"].std()
    return std_dev

def calc_stderr(x):
    std_err = calc_std(x) / get_sqrtct(x)
    return std_err

def calc_pp(passing,total):
    pp = float(get_count(passing)) / get_count(total)
    return pp

# %% [markdown]
# # No Bubbles Stats - All Samples

# %%
nb = make_mask(bubbles,"No Bubbles")

nb_mean = calc_mean(nb)
print "mean", nb_mean

nb_stderr = calc_stderr(nb)
print "standard error of the mean", nb_stderr
# Out:
# mean 1366.6611236
# standard error of the mean 47.6815409343

# %% [markdown]
# # No Bubbles Stats - SMQC Pass Only

# %%
nb_p = pass_only(make_mask(bubbles,"No Bubbles"))

nb_mean = calc_mean(nb_p)
print "mean =", nb_mean

nb_stderr = calc_stderr(nb_p)
print "standard error of the mean =", nb_stderr

nb_pp = calc_pp(nb_p,nb)
print "pass percentage =", nb_pp
# Out:
# mean = 1578.02451791
# standard error of the mean = 50.7005797402
# pass percentage = 0.815730337079

# %% [markdown]
# # Small Bubbles Stats - All Samples

# %%
sb = make_mask(bubbles,"Small Bubbles")

sb_mean = calc_mean(sb)
print "mean", sb_mean

sb_stderr = calc_stderr(sb)
print "standard error of the mean", sb_stderr
# Out:
# mean 1369.29014085
# standard error of the mean 86.5840364432

# %% [markdown]
# # Small Bubbles Stats - SMQC Pass Only

# %%
sb_p = pass_only(make_mask(bubbles,"Small Bubbles"))

sb_mean = calc_mean(sb_p)
print "mean", sb_mean

sb_stderr = calc_stderr(sb_p)
print "standard error of the mean", sb_stderr

sb_pp = calc_pp(sb_p,sb)
print "pass percentage =", sb_pp
# Out:
# mean 1672.03350785
# standard error of the mean 107.5958286
# pass percentage = 0.76861167002

# %% [markdown]
# # Medium bubbles Stats - All Samples

# %%
mb = make_mask(bubbles,"Medium Bubbles")

mb_mean = calc_mean(mb)
print "mean =", mb_mean

mb_stderr = calc_stderr(mb)
print "standard error of the mean =", mb_stderr
# Out:
# mean = 1334.71764706
# standard error of the mean = 106.315505511

# %% [markdown]
# # Medium Bubbles Stats - SMQC Pass Only

# %%
mb_p = pass_only(make_mask(bubbles, "Medium Bubbles"))

mb_mean = calc_mean(mb_p)
print "mean =", mb_mean

mb_stderr = calc_stderr(mb_p)
print "standard error of the mean =", calc_stderr(mb_p)

mb_pp = calc_pp(mb_p,mb)
print "pass percentage =", mb_pp

print get_count(mb)
print get_count(mb_p)
# Out:
# mean = 1594.10487805
# standard error of the mean = 115.048434532
# pass percentage = 0.803921568627
# 102
# 82

# %% [markdown]
# # Large Bubbles Stats - All Samples

# %%
lb = make_mask(bubbles,"Large Bubbles")

lb_mean = calc_mean(lb)
print "mean =", lb_mean

lb_stderr = calc_stderr(lb)
print "standard error of the mean", lb_stderr
# Out:
# mean = 1349.54736842
# standard error of the mean 188.811785898

# %% [markdown]
# # Large Bubbles Stats - SMQC Pass Only

# %%
lb_p = pass_only(make_mask(bubbles,"Large Bubbles"))

lb_mean = calc_mean(lb_p)
print "mean =", lb_mean

lb_stderr = calc_stderr(lb_p)
print "standard error of the mean =", lb_stderr

lb_pp = calc_pp(lb_p,lb)
print "pass percentage =", lb_pp
# Out:
# mean = 1653.30333333
# standard error of the mean = 205.483099872
# pass percentage = 0.789473684211

# %% [markdown]
# # Solution up Pipette - All Samples

# %%
sp = make_mask(bubbles,"Solution in Pipette Shank")

sp_mean = calc_mean(sp)
print "mean =", sp_mean

sp_stderr = calc_stderr(sp)
print "standard error of the mean =", sp_stderr
# Out:
# mean = 914.647368421
# standard error of the mean = 295.180430139

# %% [markdown]
# # Solution up Pipette - SMQC Pass Only

# %%
sp_p = pass_only(make_mask(bubbles, "Solution in Pipette Shank"))

sp_mean = calc_mean(sp_p)
print "mean =", sp_mean

sp_stderr = calc_stderr(sp_p)
print "standard error of the mean =", sp_stderr

sp_pp = calc_pp(sp_p,sp)
print "pass percentage =", sp_pp

print get_count(sp)
print get_count(sp_p)
# Out:
# mean = 1410.75454545
# standard error of the mean = 458.825817884
# pass percentage = 0.578947368421
# 19
# 11

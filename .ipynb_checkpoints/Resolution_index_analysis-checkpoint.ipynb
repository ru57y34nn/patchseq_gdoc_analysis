# %% [markdown]
# # Defining the dataframe

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline
sns.set(style='whitegrid', color_codes = True)

# %%
ps = pd.read_csv('patch_seq_log_mouse.csv')

# %%
ps = ps[["Date", "User","Ephys", "Morph", "Post patch?", "Post patch pipette R", "Nucleus sucked in?", "Notes", "Internal version", "PCR cycles", "SM_QC_PF", "Resolution index", "Res index pctl.", "Bad dates"]]
#ps.dropna(subset = ["SM_QC_PF", "Post patch?"], inplace = True)
ps.dropna(subset = ["Post patch?"], inplace = True)
ps["User"] = ps["User"].astype("category")
ps["Post patch?"] = ps["Post patch?"].astype("category")
ps["SM_QC_PF"] = ps["SM_QC_PF"].astype("category")
ps = ps[ps["Bad dates"] != 'x']
ps = ps[ps["SM_QC_PF"] != "cnt"]
ps = ps[ps["PCR cycles"] == 21]
ps = ps.drop('Bad dates', 1)
ps["Date"] = pd.to_datetime(ps["Date"], format = '%y%m%d')
ps.dropna(subset = ["Resolution index"], inplace=True)
#ps["PCR cycles"].value_counts()
ps
# Out:
#            Date User Ephys Morph      Post patch?  Post patch pipette R  \
# 4969 2017-04-19   P2     x     y      Outside-Out                   NaN
# 4971 2017-04-19   P2     x     y        Nucleated                   NaN
# 4972 2017-04-19   P2     x     y      Outside-Out                   NaN
# 4973 2017-04-19   P2     x     y        Nucleated                   NaN
# 4974 2017-04-19   P2     x     n          No-Seal                   NaN
# 4979 2017-04-19   P6     x     n          No-Seal                   NaN
# 4988 2017-04-20   P1     x   NaN        Nucleated                   NaN
# 4989 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4990 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4991 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4992 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4993 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4994 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4995 2017-04-20   P1     x   NaN          No-Seal                   NaN
# 4996 2017-04-20   P1     x   NaN  Partial-Nucleus                   NaN
# 5000 2017-04-20   P2     x   NaN          No-Seal                   NaN
# 5001 2017-04-20   P2     x   NaN      Outside-Out                   NaN
# 5002 2017-04-20   P2     x   NaN      Entire-Cell                   NaN
# 5003 2017-04-20   P2     x   NaN          No-Seal                   NaN
# 5004 2017-04-20   P2     x   NaN          No-Seal                   NaN
# 5005 2017-04-20   P2     x   NaN          No-Seal                   NaN
# 5006 2017-04-20   P2     x   NaN          No-Seal                   NaN
# 5007 2017-04-20   P2     x   NaN          No-Seal                   NaN
# 5008 2017-04-20   P2     x   NaN      Outside-Out                   NaN
# 5009 2017-04-20   P2     x   NaN        Nucleated                   NaN
# 5016 2017-04-21   P1     x     n          No-Seal                   NaN
# 5017 2017-04-21   P1     ?     n          No-Seal                   NaN
# 5019 2017-04-21   P1     ?     n          No-Seal                   NaN
# 5020 2017-04-21   P1     x     n          No-Seal                   NaN
# 5021 2017-04-21   P1     x     n  Partial-Nucleus                   NaN
# ...         ...  ...   ...   ...              ...                   ...
# 7219 2017-09-20   P8     x     y        Nucleated                   NaN
# 7220 2017-09-20   P8     x     y        Nucleated                   NaN
# 7221 2017-09-20   P8     x     y        Nucleated                   NaN
# 7222 2017-09-20   P8     x     y        Nucleated                   NaN
# 7223 2017-09-20   P8     x     n        Nucleated                   NaN
# 7224 2017-09-20   P8     x     y        Nucleated                   NaN
# 7225 2017-09-20   P9     x    na        Nucleated                   NaN
# 7226 2017-09-20   P9     x    na        Nucleated                   NaN
# 7227 2017-09-20   P9     x    na        Nucleated                   NaN
# 7228 2017-09-20   P9     x    na        Nucleated                   NaN
# 7229 2017-09-20   P9     x    na        Nucleated                   NaN
# 7230 2017-09-20   P9     x    na        Nucleated                   NaN
# 7231 2017-09-20   P9     x    na        Nucleated                   NaN
# 7232 2017-09-20   P9     x    na        Nucleated                   NaN
# 7233 2017-09-20   P9     x    na        Nucleated                   NaN
# 7234 2017-09-20   P9     x    na        Nucleated                   NaN
# 7235 2017-09-20   P9     x    na        Nucleated                   NaN
# 7236 2017-09-20   P9     x    na        Nucleated                   NaN
# 7237 2017-09-21   P2     x     n          No-Seal                   NaN
# 7238 2017-09-21   P2     x     y        Nucleated                   NaN
# 7239 2017-09-21   P2     x     y        Nucleated                   NaN
# 7240 2017-09-21   P2     x     q        Nucleated                   NaN
# 7241 2017-09-21   P2     x     n          No-Seal                   NaN
# 7242 2017-09-21   P8     x     n          No-Seal                   NaN
# 7243 2017-09-21   P8     ?     n  Partial-Nucleus                   NaN
# 7244 2017-09-21   P8     x     n        Nucleated                   NaN
# 7245 2017-09-21   P8     x     n        Nucleated                   NaN
# 7246 2017-09-21   P9     x     y        Nucleated                   NaN
# 7247 2017-09-21   P9     x     n        Nucleated                   NaN
# 7252 2017-09-21   PA     ?     n        Nucleated                   NaN
#
#      Nucleus sucked in?                                              Notes  \
# 4969                NaN                                                NaN
# 4971                NaN                                                NaN
# 4972                NaN                                                NaN
# 4973                NaN                                                NaN
# 4974                NaN                                                NaN
# 4979                NaN                                                NaN
# 4988                NaN                                                NaN
# 4989                NaN                                                NaN
# 4990                NaN                                                NaN
# 4991                NaN                                                NaN
# 4992                NaN                                                NaN
# 4993                NaN                                                NaN
# 4994                NaN                                                NaN
# 4995                NaN                                                NaN
# 4996                NaN                                                NaN
# 5000                NaN                                                NaN
# 5001                NaN                                                NaN
# 5002                NaN                                                NaN
# 5003                NaN                                                NaN
# 5004                NaN                                                NaN
# 5005                NaN              approached angle same as tissue angle
# 5006                NaN                 approach angle same as slice angle
# 5007                NaN                                                NaN
# 5008                NaN                lost seal on cell during extraction
# 5009                NaN                                                NaN
# 5016                NaN                                                NaN
# 5017                NaN                                                NaN
# 5019                NaN                            Fluorescence in Pipette
# 5020                NaN          Fluorescence in Pipette,Cell Dimmed   1.0
# 5021                NaN                Fluorescence in Pipette,Cell Dimmed
# ...                 ...                                                ...
# 7219                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7220                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7221                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7222                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7223                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7224                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7225                NaN                                                NaN
# 7226                NaN                                                NaN
# 7227                NaN                                                NaN
# 7228                NaN                     ~2 min retraction (11:05:56AM)
# 7229                NaN                     ~2 min retraction (11:28:39AM)
# 7230                NaN                     ~3 min retraction (11:44:11AM)
# 7231                NaN                            2 min retraction period
# 7232                NaN  Small Bubbles,Medium Bubbles nucleus sucked up...
# 7233                NaN                          2.2 min retraction period
# 7234                NaN                          2.3 min retraction period
# 7235                NaN                          2.5 min retraction period
# 7236                NaN                          2.5 min retraction period
# 7237                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
# 7238                NaN  Fluorescence in Pipette Small Bubbles 1.33 min...
# 7239                NaN  Fluorescence in Pipette No Bubbles 3 min retra...
# 7240                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 7241                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 7242                NaN  Fluorescence in Pipette,Cell Shrunk   No Bubbl...
# 7243                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7244                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7245                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7246                NaN                            2 min retraction period
# 7247                NaN                            3 min retraction period
# 7252                NaN  Fluorescence in Pipette,Too Deep Small Bubbles...
#
#          Internal version  PCR cycles SM_QC_PF  Resolution index  \
# 4969                 AiV2        21.0     pass          0.923406
# 4971                 AiV2        21.0     pass          0.000000
# 4972                 AiV2        21.0     pass          0.322631
# 4973                 AiV2        21.0     pass          0.322631
# 4974                 AiV2        21.0     pass          0.000000
# 4979                 AiV2        21.0     pass          0.000000
# 4988                 AiV2        21.0     pass          0.601033
# 4989                 AiV2        21.0     pass          0.000000
# 4990                 AiV2        21.0     pass          0.000000
# 4991                 AiV2        21.0     pass          0.000000
# 4992                 AiV2        21.0     pass          0.000000
# 4993                 AiV2        21.0     pass          0.000000
# 4994                 AiV2        21.0     pass          0.469928
# 4995                 AiV2        21.0     pass          0.000000
# 4996                 AiV2        21.0     pass          0.678447
# 5000                 AiV2        21.0     pass          0.719078
# 5001                 AiV2        21.0     pass          0.000000
# 5002                 AiV2        21.0     pass          0.719078
# 5003                 AiV2        21.0     pass          0.601033
# 5004                 AiV2        21.0     pass          0.000000
# 5005                 AiV2        21.0     pass          0.702701
# 5006                 AiV2        21.0     pass          0.601033
# 5007                 AiV2        21.0     pass          0.678447
# 5008                 AiV2        21.0     pass          0.695597
# 5009                 AiV2        21.0     pass          0.678447
# 5016                 AiV2        21.0     pass          0.702701
# 5017                 AiV2        21.0     pass          0.469928
# 5019                 AiV2        21.0     pass          0.556320
# 5020                 AiV2        21.0     pass          0.000000
# 5021                 AiV2        21.0     pass          1.000000
# ...                   ...         ...      ...               ...
# 7219  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7220  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7221  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7222  AiV2-50uM alexa 488        21.0     pass          0.719078
# 7223  AiV2-50uM alexa 488        21.0     pass          0.678447
# 7224  AiV2-50uM alexa 488        21.0     pass          0.678447
# 7225  AiV2-50uM alexa 488        21.0     pass          0.879669
# 7226  AiV2-50uM alexa 488        21.0     pass          0.879669
# 7227  AiV2-50uM alexa 488        21.0     pass          0.860881
# 7228  AiV2-50uM alexa 488        21.0     pass          0.864362
# 7229  AiV2-50uM alexa 488        21.0     pass          0.884634
# 7230  AiV2-50uM alexa 488        21.0     pass          0.795757
# 7231  AiV2-50uM alexa 488        21.0     pass          0.678447
# 7232  AiV2-50uM alexa 488        21.0     fail          0.000000
# 7233  AiV2-50uM alexa 488        21.0     pass          0.678447
# 7234  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7235  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7236  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7237  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7238  AiV2-50uM alexa 488        21.0     pass          0.877682
# 7239  AiV2-50uM alexa 488        21.0     pass          0.831825
# 7240  AiV2-50uM alexa 488        21.0     pass          0.879669
# 7241  AiV2-50uM alexa 488        21.0     pass          0.556320
# 7242  AiV2-50uM alexa 488        21.0     fail          0.556320
# 7243  AiV2-50uM alexa 488        21.0     pass          0.556320
# 7244  AiV2-50uM alexa 488        21.0     pass          0.322631
# 7245  AiV2-50uM alexa 488        21.0     pass          0.322631
# 7246  AiV2-50uM alexa 488        21.0     pass          0.556320
# 7247  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7252  AiV2-50uM alexa 488        21.0     pass          0.877682
#
#       Res index pctl.
# 4969             65.0
# 4971              7.0
# 4972             20.0
# 4973             20.0
# 4974              7.0
# 4979              7.0
# 4988             41.0
# 4989              7.0
# 4990              7.0
# 4991              7.0
# 4992              7.0
# 4993              7.0
# 4994             27.0
# 4995              7.0
# 4996             48.0
# 5000             51.0
# 5001              7.0
# 5002             51.0
# 5003             41.0
# 5004              7.0
# 5005             50.0
# 5006             41.0
# 5007             48.0
# 5008             49.0
# 5009             48.0
# 5016             50.0
# 5017             27.0
# 5019             36.0
# 5020              7.0
# 5021            100.0
# ...               ...
# 7219            100.0
# 7220            100.0
# 7221            100.0
# 7222             51.0
# 7223             48.0
# 7224             48.0
# 7225             65.0
# 7226             65.0
# 7227             60.0
# 7228             62.0
# 7229             66.0
# 7230             56.0
# 7231             48.0
# 7232              7.0
# 7233             48.0
# 7234            100.0
# 7235            100.0
# 7236            100.0
# 7237            100.0
# 7238             64.0
# 7239             58.0
# 7240             65.0
# 7241             36.0
# 7242             36.0
# 7243             36.0
# 7244             20.0
# 7245             20.0
# 7246             36.0
# 7247            100.0
# 7252             64.0
#
# [1171 rows x 13 columns]

# %% [markdown]
# # Defining Functions

# %% [markdown]
# #### defining counting functions

# %%
def get_count(x):    
    count = x["Post patch?"].count()
    return count

def calc_pct(part,total):
    pct = float(get_count(part)) / get_count(total)
    return pct

# %% [markdown]
# #### defining filtering functions

# %%
#input is a dataframe

def nucleated(x):
    nucleus = x[(x["Post patch?"] == "Nucleated") | (((x["Post patch?"] == "nucleus_visible") | (x["Post patch?"] == "nucleus_present")) & (x["Post patch pipette R"] >= 501))]
    return nucleus

def partial_nucleated(y):
    partial = y[(y["Post patch?"] == 'Partial-Nucleus') | (((y['Post patch?'] == 'nucleus_present') | (y['Post patch?'] == 'nucleus_visible')) & (y["Post patch pipette R"] <= 500))]
    return partial

def outside_out(z):
    outside = z[(z["Post patch?"] == 'Outside-Out') | (((z['Post patch?'] == 'nucleus_absent') | (z['Post patch?'] == 'no_nuclues_visible')) & (z['Post patch pipette R'] >= 501))]
    return outside

def no_seal(w): 
    no = w[(w["Post patch?"] == 'No-Seal') | (((w['Post patch?'] == 'nucleus_absent') | (w['Post patch?'] == 'no_nucleus_visible')) & (w['Post patch pipette R'] <= 500))]
    return no
    
def pass_only(df):
    pas = df[df["SM_QC_PF"] == "pass"]
    return pas

def gen_filter(df, col, cond):
    filtr = df[df[col] == cond]
    return filtr

def hi_res(df):
    hi = df[df["Resolution index"] >= 0.8]
    return hi

# %% [markdown]
# # Creating a dataframe by post patch class

# %%
nuc = nucleated(ps)
nuc["post patch class"] = "Nucleated"

part_nuc = partial_nucleated(ps)
part_nuc["post patch class"] = "Partial nucleated"

out_out = outside_out(ps)
out_out["post patch class"] = "Outside out"

noSeal = no_seal(ps)
noSeal["post patch class"] = "No seal"

entirecell = ps[ps["Post patch?"] == "Entire-Cell"]
entirecell["post patch class"] = "Entire cell"

frames = [nuc, part_nuc, out_out, noSeal, entirecell]
ps2 = pd.concat(frames)
ps2
# Out:
# C:\Users\lindsayn\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lindsayn\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\lindsayn\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lindsayn\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\lindsayn\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Date User Ephys Morph  Post patch?  Post patch pipette R  \
# 4971 2017-04-19   P2     x     y    Nucleated                   NaN
# 4973 2017-04-19   P2     x     y    Nucleated                   NaN
# 4988 2017-04-20   P1     x   NaN    Nucleated                   NaN
# 5009 2017-04-20   P2     x   NaN    Nucleated                   NaN
# 5022 2017-04-21   P1     ?     n    Nucleated                   NaN
# 5026 2017-04-21   P2     x     n    Nucleated                   NaN
# 5027 2017-04-21   P2     x     y    Nucleated                   NaN
# 5035 2017-04-21   P2     x     n    Nucleated                   NaN
# 5045 2017-04-24   P1     x   NaN    Nucleated                   NaN
# 5051 2017-04-24   P1     x     y    Nucleated                   NaN
# 5058 2017-04-24   P2     x   NaN    Nucleated                   NaN
# 5063 2017-04-24   P2     x     n    Nucleated                   NaN
# 5073 2017-04-25   P1     x     n    Nucleated                   NaN
# 5084 2017-04-25   P2     x     n    Nucleated                   NaN
# 5085 2017-04-25   P2     x     n    Nucleated                   NaN
# 5089 2017-04-25   P2     x     q    Nucleated                   NaN
# 5111 2017-04-26   P2     x     y    Nucleated                   NaN
# 5114 2017-04-26   P2     ?     n    Nucleated                   NaN
# 5117 2017-04-26   P2     x     q    Nucleated                   NaN
# 5134 2017-04-27   P1     x     n    Nucleated                   NaN
# 5146 2017-04-27   P2     x     q    Nucleated                   NaN
# 5154 2017-04-28   P1     ?   NaN    Nucleated                   NaN
# 5164 2017-04-28   P2     x     q    Nucleated                   NaN
# 5166 2017-04-28   P2     x     y    Nucleated                   NaN
# 5192 2017-05-01   P2     x     q    Nucleated                   NaN
# 5198 2017-05-01   P6     x     q    Nucleated                   NaN
# 5199 2017-05-01   P6     x     q    Nucleated                   NaN
# 5200 2017-05-01   P6     x     n    Nucleated                   NaN
# 5204 2017-05-01   P6     x     n    Nucleated                   NaN
# 5212 2017-05-02   P1     x     y    Nucleated                   NaN
# ...         ...  ...   ...   ...          ...                   ...
# 7136 2017-09-01   P8     x     y      No-Seal                   NaN
# 7151 2017-09-11   P2     x     n      No-Seal                   NaN
# 7153 2017-09-12   P2     x     y      No-Seal                   NaN
# 7157 2017-09-13   P8     x     n      No-Seal                   NaN
# 7160 2017-09-13   P8     x     n      No-Seal                   NaN
# 7163 2017-09-13   P8     x     q      No-Seal                   NaN
# 7164 2017-09-13   P8     x   NaN      No-Seal                   NaN
# 7165 2017-09-13   P8     x   NaN      No-Seal                   NaN
# 7171 2017-09-14   P8     x     n      No-Seal                   NaN
# 7174 2017-09-15   P2     x     n      No-Seal                   NaN
# 7178 2017-09-15   P8     x     n      No-Seal                   NaN
# 7180 2017-09-15   P8     x     n      No-Seal                   NaN
# 7203 2017-09-19   P8     ?     n      No-Seal                   NaN
# 7210 2017-09-20   P2     x     n      No-Seal                   NaN
# 7237 2017-09-21   P2     x     n      No-Seal                   NaN
# 7241 2017-09-21   P2     x     n      No-Seal                   NaN
# 7242 2017-09-21   P8     x     n      No-Seal                   NaN
# 5002 2017-04-20   P2     x   NaN  Entire-Cell                   NaN
# 5088 2017-04-25   P2     x     n  Entire-Cell                   NaN
# 5242 2017-05-02   P6     x     q  Entire-Cell                   NaN
# 5273 2017-05-03   P5   NaN     z  Entire-Cell                   NaN
# 5274 2017-05-03   P5   NaN     z  Entire-Cell                   NaN
# 5369 2017-05-10   P6     x     n  Entire-Cell                   NaN
# 5532 2017-05-18   P6     x   NaN  Entire-Cell                   NaN
# 5687 2017-06-01   P1     x     q  Entire-Cell                   NaN
# 5847 2017-06-13   P1     x     q  Entire-Cell                   NaN
# 6814 2017-08-02   P8     x     n  Entire-Cell                   NaN
# 6963 2017-08-09   P8     x     n  Entire-Cell                   NaN
# 7076 2017-08-25   P8     x     n  Entire-Cell                   NaN
# 7094 2017-08-29   P8     x     n  Entire-Cell                   NaN
#
#      Nucleus sucked in?                                              Notes  \
# 4971                NaN                                                NaN
# 4973                NaN                                                NaN
# 4988                NaN                                                NaN
# 5009                NaN                                                NaN
# 5022                NaN                Fluorescence in Pipette,Cell Dimmed
# 5026                NaN                            Fluorescence in Pipette
# 5027                NaN                            Fluorescence in Pipette
# 5035                NaN                                                NaN
# 5045                NaN                            Fluorescence in Pipette
# 5051                NaN      Fluorescence in Pipette   a few small bubbles
# 5058                NaN                                                NaN
# 5063                NaN  Fluorescence in Pipette One big bubble formed ...
# 5073                NaN                              lots of small bubbles
# 5084                NaN                                                NaN
# 5085                NaN                            Fluorescence in Pipette
# 5089                NaN                       no bubbles during expulsion.
# 5111                NaN                                                NaN
# 5114                NaN  Fluorescence in Pipette a few small bubbles fo...
# 5117                NaN  Fluorescence in Pipette large bubble formed du...
# 5134                NaN                              lots of small bubbles
# 5146                NaN                few small bubbles during expulsion.
# 5154                NaN               Fluorescence in Pipette   no bubbles
# 5164                NaN          one small bubble formed during expulsion.
# 5166                NaN  One medium bubble formed during expulsion, sol...
# 5192                NaN  Fluorescence in Pipette one big bubble formed ...
# 5198                NaN                                                NaN
# 5199                NaN                                                NaN
# 5200                NaN                                                NaN
# 5204                NaN                                                NaN
# 5212                NaN                  Cell Dimmed   a few small bubbles
# ...                 ...                                                ...
# 7136                NaN  Fluorescence in Pipette,Cell Dimmed No Bubbles...
# 7151                NaN      No Bubbles 0.1 units of pressure on expulsion
# 7153                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
# 7157                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7160                NaN  Fluorescence in Pipette,Cell Disappeared No Bu...
# 7163                NaN                 Fluorescence in Pipette No Bubbles
# 7164                NaN  No Bubbles sat for a long time while waiting f...
# 7165                NaN  Cell Dimmed,Cell Shrunk Small Bubbles sat for ...
# 7171                NaN  Fluorescence in Pipette,Cell Disappeared No Bu...
# 7174                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 7178                NaN                        Cell Disappeared No Bubbles
# 7180                NaN     Fluorescence in Pipette,Cell Shrunk No Bubbles
# 7203                NaN  Fluorescence in Pipette,Cell Swelled   No Bubbles
# 7210                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
# 7237                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
# 7241                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 7242                NaN  Fluorescence in Pipette,Cell Shrunk   No Bubbl...
# 5002                NaN                                                NaN
# 5088                NaN                    small bubbles during expulsion.
# 5242                NaN                                                NaN
# 5273                NaN  cuoldnt get gigaseal but pulled Entire-Cell ou...
# 5274                NaN  cuoldnt get gigaseal but pulled Entire-Cell ou...
# 5369                NaN                                                NaN
# 5532                NaN                                         No Bubbles
# 5687                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 5847                NaN                        Cell Dimmed   Small Bubbles
# 6814                NaN  Fluorescence in Pipette,Cell Swelled No Bubble...
# 6963                NaN  Fluorescence in Pipette,Cell Disappeared No Bu...
# 7076                NaN     Fluorescence in Pipette,Cell Shrunk No Bubbles
# 7094                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
#
#          Internal version  PCR cycles SM_QC_PF  Resolution index  \
# 4971                 AiV2        21.0     pass          0.000000
# 4973                 AiV2        21.0     pass          0.322631
# 4988                 AiV2        21.0     pass          0.601033
# 5009                 AiV2        21.0     pass          0.678447
# 5022                 AiV2        21.0     pass          0.795757
# 5026                 AiV2        21.0     pass          1.000000
# 5027                 AiV2        21.0     pass          0.877682
# 5035                 AiV2        21.0     pass          0.556320
# 5045                 AiV2        21.0     pass          0.601033
# 5051                 AiV2        21.0     pass          1.000000
# 5058                 AiV2        21.0     pass          0.678447
# 5063                 AiV2        21.0     pass          0.678447
# 5073                 AiV2        21.0     pass          0.678447
# 5084                 AiV2        21.0     pass          1.000000
# 5085                 AiV2        21.0     pass          1.000000
# 5089                 AiV2        21.0     pass          1.000000
# 5111                 AiV2        21.0     pass          0.678447
# 5114                 AiV2        21.0     pass          0.678447
# 5117                 AiV2        21.0     pass          1.000000
# 5134                 AiV2        21.0     pass          0.678447
# 5146                 AiV2        21.0     pass          0.678447
# 5154                 AiV2        21.0     pass          0.000000
# 5164                 AiV2        21.0     pass          1.000000
# 5166                 AiV2        21.0     pass          0.678447
# 5192                 AiV2        21.0     pass          1.000000
# 5198                 AiV2        21.0     pass          0.678447
# 5199                 AiV2        21.0     pass          0.805486
# 5200                 AiV2        21.0     pass          0.678447
# 5204                 AiV2        21.0     pass          0.678447
# 5212                 AiV2        21.0     pass          0.678447
# ...                   ...         ...      ...               ...
# 7136  AiV2-50uM alexa 488        21.0     pass          0.322631
# 7151  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7153  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7157  AiV2-50uM alexa 488        21.0     fail          0.322631
# 7160  AiV2-50uM alexa 488        21.0     pass          0.601033
# 7163  AiV2-50uM alexa 488        21.0     pass          0.322631
# 7164  AiV2-50uM alexa 488        21.0     fail          0.000000
# 7165  AiV2-50uM alexa 488        21.0     fail          0.322631
# 7171  AiV2-50uM alexa 488        21.0     pass          0.469928
# 7174  AiV2-50uM alexa 488        21.0     pass          0.469928
# 7178  AiV2-50uM alexa 488        21.0     fail          0.469928
# 7180  AiV2-50uM alexa 488        21.0     pass          0.469928
# 7203  AiV2-50uM alexa 488        21.0     fail          0.000000
# 7210  AiV2-50uM alexa 488        21.0     pass          0.556320
# 7237  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7241  AiV2-50uM alexa 488        21.0     pass          0.556320
# 7242  AiV2-50uM alexa 488        21.0     fail          0.556320
# 5002                 AiV2        21.0     pass          0.719078
# 5088                 AiV2        21.0     pass          1.000000
# 5242                 AiV2        21.0     pass          0.601033
# 5273                  NaN        21.0     pass          0.678447
# 5274                  NaN        21.0     pass          0.678447
# 5369                 AiV2        21.0     pass          1.000000
# 5532                 AiV2        21.0     pass          1.000000
# 5687                 AiV2        21.0     pass          1.000000
# 5847                 AiV2        21.0     pass          1.000000
# 6814                 AiV2        21.0     pass          1.000000
# 6963                 AiV2        21.0     pass          1.000000
# 7076                 AiV2        21.0     pass          0.556320
# 7094  AiV2-50uM alexa 488        21.0     pass          0.322631
#
#       Res index pctl. post patch class
# 4971              7.0        Nucleated
# 4973             20.0        Nucleated
# 4988             41.0        Nucleated
# 5009             48.0        Nucleated
# 5022             55.0        Nucleated
# 5026            100.0        Nucleated
# 5027             64.0        Nucleated
# 5035             36.0        Nucleated
# 5045             41.0        Nucleated
# 5051            100.0        Nucleated
# 5058             48.0        Nucleated
# 5063             48.0        Nucleated
# 5073             48.0        Nucleated
# 5084            100.0        Nucleated
# 5085            100.0        Nucleated
# 5089            100.0        Nucleated
# 5111             48.0        Nucleated
# 5114             48.0        Nucleated
# 5117            100.0        Nucleated
# 5134             48.0        Nucleated
# 5146             48.0        Nucleated
# 5154              7.0        Nucleated
# 5164            100.0        Nucleated
# 5166             48.0        Nucleated
# 5192            100.0        Nucleated
# 5198             48.0        Nucleated
# 5199             56.0        Nucleated
# 5200             48.0        Nucleated
# 5204             48.0        Nucleated
# 5212             48.0        Nucleated
# ...               ...              ...
# 7136             20.0          No seal
# 7151            100.0          No seal
# 7153            100.0          No seal
# 7157             20.0          No seal
# 7160             40.0          No seal
# 7163             20.0          No seal
# 7164              7.0          No seal
# 7165             20.0          No seal
# 7171             26.0          No seal
# 7174             26.0          No seal
# 7178             26.0          No seal
# 7180             26.0          No seal
# 7203              7.0          No seal
# 7210             36.0          No seal
# 7237            100.0          No seal
# 7241             36.0          No seal
# 7242             36.0          No seal
# 5002             51.0      Entire cell
# 5088            100.0      Entire cell
# 5242             41.0      Entire cell
# 5273             48.0      Entire cell
# 5274             48.0      Entire cell
# 5369            100.0      Entire cell
# 5532            100.0      Entire cell
# 5687            100.0      Entire cell
# 5847            100.0      Entire cell
# 6814            100.0      Entire cell
# 6963            100.0      Entire cell
# 7076             36.0      Entire cell
# 7094             20.0      Entire cell
#
# [1170 rows x 14 columns]

# %% [markdown]
# # Resolution Index vs post patch condition for pre and post alexa experiments

# %% [markdown]
# #### comparing standard to alexa internal

# %%
sns.swarmplot(x = "post patch class", y ="Resolution index", hue = "Internal version", data=ps2)
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)

# %%
pre_alexa = gen_filter(ps2, "Internal version", "AiV2")
post_alexa = gen_filter(ps2, "Internal version", "AiV2-50uM alexa 488" )

# %% [markdown]
# #### alexa internal only

# %%
sns.swarmplot(x = "post patch class", y = "Resolution index", data=post_alexa)

# %% [markdown]
# #### standard internal only

# %%
sns.swarmplot(x = "post patch class", y = "Resolution index", data = pre_alexa)

# %% [markdown]
# # Calculating occurance of resolution index > 0.8 (high resolution)

# %% [markdown]
# ### First attempts:

# %%
for frame in frames:
    hi_res_occurance = calc_pct(hi_res(frame), frame)
    print "high resolution occurance:" , hi_res_occurance
# Out:
# high resolution occurance: 0.601286173633
# high resolution occurance: 0.503225806452
# high resolution occurance: 0.209302325581
# high resolution occurance: 0.311572700297
# high resolution occurance: 0.538461538462

# %%
def hi_res_occur(frame, postpatch):
    hi_res_occurance = calc_pct(hi_res(frame), frame)
    print postpatch,":", hi_res_occurance
    
hi_res_occur(nuc, "Nucleated")
hi_res_occur(part_nuc, "Partial Nucleated")
hi_res_occur(out_out, "Outside out")
hi_res_occur(noSeal, "No Seal")
hi_res_occur(entirecell, "Entire cell")
# Out:
# Nucleated : 0.601286173633
# Partial Nucleated : 0.503225806452
# Outside out : 0.209302325581
# No Seal : 0.311572700297
# Entire cell : 0.538461538462

# %% [markdown]
# ### Use this one:

# %%
# calculates the occurance of high resolution index for each post patch condition

def hi_res_occ(frame, postpatch):
    total = gen_filter(frame, "post patch class", postpatch)
    hi_reso = hi_res(total)
    hi_res_oc = calc_pct(hi_reso, total)
    print postpatch, ":" , hi_res_oc

hi_res_occ(ps2, "Nucleated")
hi_res_occ(ps2, "Partial nucleated")
hi_res_occ(ps2,"Outside out")
hi_res_occ(ps2,"No seal")
hi_res_occ(ps2,"Entire cell")
# Out:
# Nucleated : 0.601286173633
# Partial nucleated : 0.503225806452
# Outside out : 0.209302325581
# No seal : 0.311572700297
# Entire cell : 0.538461538462

# %% [markdown]
# # Calculating occurance of resolution index > 0.8 (high resolution) by internal version

# %% [markdown]
# #### Occurance of high resolution index in pre alexa expreiments

# %%
hi_res_occ(pre_alexa, "Nucleated")
hi_res_occ(pre_alexa, "Partial nucleated")
hi_res_occ(pre_alexa,"Outside out")
hi_res_occ(pre_alexa,"No seal")
hi_res_occ(pre_alexa,"Entire cell")
# Out:
# Nucleated : 0.607476635514
# Partial nucleated : 0.510948905109
# Outside out : 0.209302325581
# No seal : 0.325878594249
# Entire cell : 0.7

# %% [markdown]
# #### Occurance of high resolution index in post alexa expreiments

# %%
#currently throws error because each post patch condition has not occured in this sample yet

hi_res_occ(post_alexa, "Nucleated")
hi_res_occ(post_alexa, "Partial nucleated")
hi_res_occ(post_alexa,"Outside out")
hi_res_occ(post_alexa,"No seal")
hi_res_occ(post_alexa,"Entire cell")
# Out:
# Nucleated : 0.56976744186
# Partial nucleated : 0.4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-6050298a5a3a> in <module>()
#       3 hi_res_occ(post_alexa, "Nucleated")
#       4 hi_res_occ(post_alexa, "Partial nucleated")
# ----> 5 hi_res_occ(post_alexa,"Outside out")
#       6 hi_res_occ(post_alexa,"No seal")
#       7 hi_res_occ(post_alexa,"Entire cell")
#
# <ipython-input-13-75a3f6510fc3> in hi_res_occ(frame, postpatch)
#       4     total = gen_filter(frame, "post patch class", postpatch)
#       5     hi_reso = hi_res(total)
# ----> 6     hi_res_oc = calc_pct(hi_reso, total)
#       7     print postpatch, ":" , hi_res_oc
#       8
#
# <ipython-input-4-66a638347a1b> in calc_pct(part, total)
#       4
#       5 def calc_pct(part,total):
# ----> 6     pct = float(get_count(part)) / get_count(total)
#       7     return pct
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# # Resolution Index Percentile vs post patch condition for pre and post alexa experiments

# %% [markdown]
# #### comparing standard to alexa internal

# %%
sns.swarmplot(x = "post patch class", y ="Res index pctl.", hue = "Internal version", data=ps2)
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Calculating occurance of Triple Modality experiments (Ephys pass, Morpho pass, High RI)

# %%
Ephys_pass = gen_filter(ps2, "Ephys", "x")
#Ephys_pass

# %%
Ephys_and_morpho_pass = gen_filter(Ephys_pass, "Morph", "y")
#Ephys_and_morpho_pass

# %%
Triple_mod = hi_res(Ephys_and_morpho_pass)
Triple_mod
# Out:
#            Date User Ephys Morph      Post patch?  Post patch pipette R  \
# 5027 2017-04-21   P2     x     y        Nucleated                   NaN
# 5051 2017-04-24   P1     x     y        Nucleated                   NaN
# 5215 2017-05-02   P1     x     y        Nucleated                   NaN
# 5225 2017-05-02   P2     x     y        Nucleated                   NaN
# 5226 2017-05-02   P2     x     y        Nucleated                   NaN
# 5234 2017-05-02   P2     x     y        Nucleated                   NaN
# 5250 2017-05-03   P1     x     y        Nucleated                   NaN
# 5251 2017-05-03   P1     x     y        Nucleated                   NaN
# 5261 2017-05-03   P2     x     y        Nucleated                   NaN
# 5262 2017-05-03   P2     x     y        Nucleated                   NaN
# 5295 2017-05-04   P2     x     y        Nucleated                   NaN
# 5298 2017-05-04   P2     x     y        Nucleated                   NaN
# 5309 2017-05-04   P5     x     y        Nucleated                   NaN
# 5319 2017-05-05   P1     x     y        Nucleated                   NaN
# 5320 2017-05-05   P1     x     y        Nucleated                   NaN
# 5333 2017-05-05   P2     x     y        Nucleated                   NaN
# 5334 2017-05-05   P2     x     y        Nucleated                   NaN
# 5363 2017-05-10   P2     x     y        Nucleated                   NaN
# 5417 2017-05-12   P2     x     y        Nucleated                   NaN
# 5479 2017-05-17   P1     x     y        Nucleated                   NaN
# 5481 2017-05-17   P1     x     y        Nucleated                   NaN
# 5485 2017-05-17   P1     x     y        Nucleated                   NaN
# 5486 2017-05-17   P1     x     y        Nucleated                   NaN
# 5487 2017-05-17   P1     x     y        Nucleated                   NaN
# 5716 2017-06-02   P2     x     y        Nucleated                   NaN
# 5719 2017-06-02   P2     x     y        Nucleated                   NaN
# 5737 2017-06-05   P1     x     y        Nucleated                   NaN
# 6083 2017-06-27   P8     x     y        Nucleated                   NaN
# 6102 2017-06-28   P1     x     y        Nucleated                   NaN
# 6117 2017-06-28   P8     x     y        Nucleated                   NaN
# ...         ...  ...   ...   ...              ...                   ...
# 7219 2017-09-20   P8     x     y        Nucleated                   NaN
# 7220 2017-09-20   P8     x     y        Nucleated                   NaN
# 7221 2017-09-20   P8     x     y        Nucleated                   NaN
# 7238 2017-09-21   P2     x     y        Nucleated                   NaN
# 7239 2017-09-21   P2     x     y        Nucleated                   NaN
# 5171 2017-04-28   P2     x     y  Partial-Nucleus                   NaN
# 5224 2017-05-02   P2     x     y  Partial-Nucleus                   NaN
# 5336 2017-05-05   P2     x     y  Partial-Nucleus                   NaN
# 5491 2017-05-17   P2     x     y  Partial-Nucleus                   NaN
# 5742 2017-06-05   P2     x     y  Partial-Nucleus                   NaN
# 6144 2017-06-29   P2     x     y  Partial-Nucleus                   NaN
# 6492 2017-07-19   P1     x     y  Partial-Nucleus                   NaN
# 6530 2017-07-20   P1     x     y  Partial-Nucleus                   NaN
# 6540 2017-07-20   P2     x     y  Partial-Nucleus                   NaN
# 6610 2017-07-24   P8     x     y  Partial-Nucleus                   NaN
# 6702 2017-07-27   P8     x     y  Partial-Nucleus                   NaN
# 6797 2017-08-01   P8     x     y  Partial-Nucleus                   NaN
# 6913 2017-08-08   P8     x     y  Partial-Nucleus                   NaN
# 7162 2017-09-13   P8     x     y  Partial-Nucleus                   NaN
# 4969 2017-04-19   P2     x     y      Outside-Out                   NaN
# 5193 2017-05-01   P2     x     y      Outside-Out                   NaN
# 5466 2017-05-16   P2     x     y      Outside-Out                   NaN
# 6652 2017-07-26   P1     x     y      Outside-Out                   NaN
# 6729 2017-07-28   P2     x     y      Outside-Out                   NaN
# 5264 2017-05-03   P2     x     y          No-Seal                   NaN
# 5715 2017-06-02   P2     x     y          No-Seal                   NaN
# 6152 2017-06-29   P8     x     y          No-Seal                   NaN
# 6916 2017-08-08   P8     x     y          No-Seal                   NaN
# 7078 2017-08-25   P8     x     y          No-Seal                   NaN
# 7153 2017-09-12   P2     x     y          No-Seal                   NaN
#
#      Nucleus sucked in?                                              Notes  \
# 5027                NaN                            Fluorescence in Pipette
# 5051                NaN      Fluorescence in Pipette   a few small bubbles
# 5215                NaN   Cell Dimmed,Cell Shrunk   a couple small bubbles
# 5225                NaN  Fluorescence in Pipette sucked up nucleus duri...
# 5226                NaN  Fluorescence in Pipette sucked nucleus up into...
# 5234                NaN  Fluorescence in Pipette very few small bubbles...
# 5250                NaN  Fluorescence in Pipette,Cell Dimmed   lots of ...
# 5251                NaN  Fluorescence in Pipette,Cell Dimmed   lots of ...
# 5261                NaN         few small bubbles formed during expulsion.
# 5262                NaN  lots of little bubbles formed during expulsion...
# 5295                NaN  Fluorescence in Pipette no bubbles formed duri...
# 5298                NaN  Fluorescence in Pipette No bubbles formed duri...
# 5309                NaN                                       tiny bubbles
# 5319                NaN  Fluorescence in Pipette,Cell Dimmed   a few sm...
# 5320                NaN  Fluorescence in Pipette,Cell Dimmed   a few sm...
# 5333                NaN                                                NaN
# 5334                NaN  Fluorescence in Pipette very few small bubbles...
# 5363                NaN  Fluorescence in Pipette very few tiny bubbles ...
# 5417                NaN  Fluorescence in Pipette few small bubbles form...
# 5479                NaN                       Small Bubbles,Medium Bubbles
# 5481                NaN                                      Small Bubbles
# 5485                NaN                                      Small Bubbles
# 5486                NaN                                      Large Bubbles
# 5487                NaN                       Small Bubbles,Medium Bubbles
# 5716                NaN              Fluorescence in Pipette Small Bubbles
# 5719                NaN                 Fluorescence in Pipette No Bubbles
# 5737                NaN  Fluorescence in Pipette,Cell Dimmed   Small Bu...
# 6083                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 6102                NaN                                      Small Bubbles
# 6117                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# ...                 ...                                                ...
# 7219                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7220                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7221                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7238                NaN  Fluorescence in Pipette Small Bubbles 1.33 min...
# 7239                NaN  Fluorescence in Pipette No Bubbles 3 min retra...
# 5171                NaN                       no bubbles during expulsion.
# 5224                NaN  Fluorescence in Pipette a few small bubbles fo...
# 5336                NaN  Fluorescence in Pipette got gigaohm seal durin...
# 5491                NaN  No Bubbles got nucleus and gigaohm seal but th...
# 5742                NaN                                         No Bubbles
# 6144                NaN  Small Bubbles max seal of about 150 MOhms on p...
# 6492                NaN  Fluorescence in Pipette,Cell Dimmed   No Bubbl...
# 6530                NaN  Cell Dimmed   No Bubbles  final seal got up to...
# 6540                NaN  Medium Bubbles max seal about 700 MOhms; nucle...
# 6610                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Swell...
# 6702                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 6797                NaN  Cell Disappeared Small Bubbles Partial nucleus...
# 6913                NaN  Cell Disappeared No Bubbles partial nucleus en...
# 7162                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 4969                NaN                                                NaN
# 5193                NaN  Fluorescence in Pipette lost seal on cell duri...
# 5466                NaN                                      Small Bubbles
# 6652                NaN  Fluorescence in Pipette,Cell Dimmed   No Bubbl...
# 6729                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 5264                NaN                            Fluorescence in Pipette
# 5715                NaN              Fluorescence in Pipette Small Bubbles
# 6152                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 6916                NaN  Cell Disappeared No Bubbles 0.1 units of press...
# 7078                NaN  Fluorescence in Pipette,Cell Dimmed No Bubbles...
# 7153                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
#
#          Internal version  PCR cycles SM_QC_PF  Resolution index  \
# 5027                 AiV2        21.0     pass          0.877682
# 5051                 AiV2        21.0     pass          1.000000
# 5215                 AiV2        21.0     pass          1.000000
# 5225                 AiV2        21.0     pass          1.000000
# 5226                 AiV2        21.0     pass          1.000000
# 5234                 AiV2        21.0     pass          1.000000
# 5250                 AiV2        21.0     pass          1.000000
# 5251                 AiV2        21.0     pass          1.000000
# 5261                 AiV2        21.0     pass          1.000000
# 5262                 AiV2        21.0     pass          1.000000
# 5295                 AiV2        21.0     pass          1.000000
# 5298                 AiV2        21.0     pass          1.000000
# 5309                 AiV2        21.0     pass          1.000000
# 5319                 AiV2        21.0     pass          1.000000
# 5320                 AiV2        21.0     pass          1.000000
# 5333                 AiV2        21.0     pass          1.000000
# 5334                 AiV2        21.0     pass          1.000000
# 5363                 AiV2        21.0     pass          1.000000
# 5417                 AiV2        21.0     pass          1.000000
# 5479                 AiV2        21.0     pass          1.000000
# 5481                 AiV2        21.0     pass          1.000000
# 5485                 AiV2        21.0     pass          0.884634
# 5486                 AiV2        21.0     pass          0.923406
# 5487                 AiV2        21.0     pass          1.000000
# 5716                 AiV2        21.0     pass          0.831825
# 5719                 AiV2        21.0     pass          1.000000
# 5737                 AiV2        21.0     pass          1.000000
# 6083                 AiV2        21.0     pass          1.000000
# 6102                 AiV2        21.0     pass          1.000000
# 6117                 AiV2        21.0     pass          1.000000
# ...                   ...         ...      ...               ...
# 7219  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7220  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7221  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7238  AiV2-50uM alexa 488        21.0     pass          0.877682
# 7239  AiV2-50uM alexa 488        21.0     pass          0.831825
# 5171                 AiV2        21.0     pass          1.000000
# 5224                 AiV2        21.0     pass          1.000000
# 5336                 AiV2        21.0     pass          1.000000
# 5491                 AiV2        21.0     pass          1.000000
# 5742                 AiV2        21.0     pass          1.000000
# 6144                 AiV2        21.0     pass          1.000000
# 6492                 AiV2        21.0     pass          1.000000
# 6530                 AiV2        21.0     pass          1.000000
# 6540                 AiV2        21.0     pass          1.000000
# 6610                 AiV2        21.0     pass          1.000000
# 6702                 AiV2        21.0     pass          1.000000
# 6797                 AiV2        21.0     pass          1.000000
# 6913                 AiV2        21.0     pass          1.000000
# 7162  AiV2-50uM alexa 488        21.0     pass          1.000000
# 4969                 AiV2        21.0     pass          0.923406
# 5193                 AiV2        21.0     pass          1.000000
# 5466                 AiV2        21.0     pass          1.000000
# 6652                 AiV2        21.0     pass          1.000000
# 6729                 AiV2        21.0     pass          0.831825
# 5264                 AiV2        21.0     pass          1.000000
# 5715                 AiV2        21.0     pass          1.000000
# 6152                 AiV2        21.0     pass          1.000000
# 6916                 AiV2        21.0     pass          1.000000
# 7078                 AiV2        21.0     pass          1.000000
# 7153  AiV2-50uM alexa 488        21.0     pass          1.000000
#
#       Res index pctl.   post patch class
# 5027             64.0          Nucleated
# 5051            100.0          Nucleated
# 5215            100.0          Nucleated
# 5225            100.0          Nucleated
# 5226            100.0          Nucleated
# 5234            100.0          Nucleated
# 5250            100.0          Nucleated
# 5251            100.0          Nucleated
# 5261            100.0          Nucleated
# 5262            100.0          Nucleated
# 5295            100.0          Nucleated
# 5298            100.0          Nucleated
# 5309            100.0          Nucleated
# 5319            100.0          Nucleated
# 5320            100.0          Nucleated
# 5333            100.0          Nucleated
# 5334            100.0          Nucleated
# 5363            100.0          Nucleated
# 5417            100.0          Nucleated
# 5479            100.0          Nucleated
# 5481            100.0          Nucleated
# 5485             65.0          Nucleated
# 5486             65.0          Nucleated
# 5487            100.0          Nucleated
# 5716             58.0          Nucleated
# 5719            100.0          Nucleated
# 5737            100.0          Nucleated
# 6083            100.0          Nucleated
# 6102            100.0          Nucleated
# 6117            100.0          Nucleated
# ...               ...                ...
# 7219            100.0          Nucleated
# 7220            100.0          Nucleated
# 7221            100.0          Nucleated
# 7238             64.0          Nucleated
# 7239             58.0          Nucleated
# 5171            100.0  Partial nucleated
# 5224            100.0  Partial nucleated
# 5336            100.0  Partial nucleated
# 5491            100.0  Partial nucleated
# 5742            100.0  Partial nucleated
# 6144            100.0  Partial nucleated
# 6492            100.0  Partial nucleated
# 6530            100.0  Partial nucleated
# 6540            100.0  Partial nucleated
# 6610            100.0  Partial nucleated
# 6702            100.0  Partial nucleated
# 6797              NaN  Partial nucleated
# 6913              NaN  Partial nucleated
# 7162            100.0  Partial nucleated
# 4969             65.0        Outside out
# 5193            100.0        Outside out
# 5466            100.0        Outside out
# 6652            100.0        Outside out
# 6729             58.0        Outside out
# 5264            100.0            No seal
# 5715            100.0            No seal
# 6152            100.0            No seal
# 6916              NaN            No seal
# 7078            100.0            No seal
# 7153            100.0            No seal
#
# [138 rows x 14 columns]

# %%
calc_pct(Triple_mod, ps2)
# Out:
# 0.11794871794871795

# %% [markdown]
# # Plots

# %%
hi_res_data = hi_res(ps2)
hi_res_data
# Out:
#            Date User Ephys Morph  Post patch?  Post patch pipette R  \
# 5026 2017-04-21   P2     x     n    Nucleated                   NaN
# 5027 2017-04-21   P2     x     y    Nucleated                   NaN
# 5051 2017-04-24   P1     x     y    Nucleated                   NaN
# 5084 2017-04-25   P2     x     n    Nucleated                   NaN
# 5085 2017-04-25   P2     x     n    Nucleated                   NaN
# 5089 2017-04-25   P2     x     q    Nucleated                   NaN
# 5117 2017-04-26   P2     x     q    Nucleated                   NaN
# 5164 2017-04-28   P2     x     q    Nucleated                   NaN
# 5192 2017-05-01   P2     x     q    Nucleated                   NaN
# 5199 2017-05-01   P6     x     q    Nucleated                   NaN
# 5215 2017-05-02   P1     x     y    Nucleated                   NaN
# 5225 2017-05-02   P2     x     y    Nucleated                   NaN
# 5226 2017-05-02   P2     x     y    Nucleated                   NaN
# 5229 2017-05-02   P2     x     q    Nucleated                   NaN
# 5233 2017-05-02   P2     x     q    Nucleated                   NaN
# 5234 2017-05-02   P2     x     y    Nucleated                   NaN
# 5250 2017-05-03   P1     x     y    Nucleated                   NaN
# 5251 2017-05-03   P1     x     y    Nucleated                   NaN
# 5261 2017-05-03   P2     x     y    Nucleated                   NaN
# 5262 2017-05-03   P2     x     y    Nucleated                   NaN
# 5263 2017-05-03   P2     x     n    Nucleated                   NaN
# 5277 2017-05-03   P6     x     q    Nucleated                   NaN
# 5291 2017-05-04   P1     x     n    Nucleated                   NaN
# 5295 2017-05-04   P2     x     y    Nucleated                   NaN
# 5296 2017-05-04   P2     x     q    Nucleated                   NaN
# 5298 2017-05-04   P2     x     y    Nucleated                   NaN
# 5309 2017-05-04   P5     x     y    Nucleated                   NaN
# 5319 2017-05-05   P1     x     y    Nucleated                   NaN
# 5320 2017-05-05   P1     x     y    Nucleated                   NaN
# 5331 2017-05-05   P2     x     q    Nucleated                   NaN
# ...         ...  ...   ...   ...          ...                   ...
# 6730 2017-07-28   P2     x     n      No-Seal                   NaN
# 6750 2017-07-31   P1     x     n      No-Seal                   NaN
# 6756 2017-07-31   P2     x     n      No-Seal                   NaN
# 6757 2017-07-31   P2     x     n      No-Seal                   NaN
# 6764 2017-07-31   P8     x     n      No-Seal                   NaN
# 6798 2017-08-01   P8     x     n      No-Seal                   NaN
# 6830 2017-08-03   P8     x     n      No-Seal                   NaN
# 6867 2017-08-07   P2     x     n      No-Seal                   NaN
# 6868 2017-08-07   P2     x    na      No-Seal                   NaN
# 6869 2017-08-07   P2     ?     n      No-Seal                   NaN
# 6915 2017-08-08   P8     x     n      No-Seal                   NaN
# 6916 2017-08-08   P8     x     y      No-Seal                   NaN
# 6918 2017-08-08   P8     x     n      No-Seal                   NaN
# 6927 2017-08-08   P6     x     n      No-Seal                   NaN
# 7037 2017-08-21   P8     x     n      No-Seal                   NaN
# 7040 2017-08-23   P8     x     n      No-Seal                   NaN
# 7041 2017-08-23   P8     x     q      No-Seal                   NaN
# 7054 2017-08-24   P2     x     n      No-Seal                   NaN
# 7057 2017-08-24   P2     x     q      No-Seal                   NaN
# 7078 2017-08-25   P8     x     y      No-Seal                   NaN
# 7151 2017-09-11   P2     x     n      No-Seal                   NaN
# 7153 2017-09-12   P2     x     y      No-Seal                   NaN
# 7237 2017-09-21   P2     x     n      No-Seal                   NaN
# 5088 2017-04-25   P2     x     n  Entire-Cell                   NaN
# 5369 2017-05-10   P6     x     n  Entire-Cell                   NaN
# 5532 2017-05-18   P6     x   NaN  Entire-Cell                   NaN
# 5687 2017-06-01   P1     x     q  Entire-Cell                   NaN
# 5847 2017-06-13   P1     x     q  Entire-Cell                   NaN
# 6814 2017-08-02   P8     x     n  Entire-Cell                   NaN
# 6963 2017-08-09   P8     x     n  Entire-Cell                   NaN
#
#      Nucleus sucked in?                                              Notes  \
# 5026                NaN                            Fluorescence in Pipette
# 5027                NaN                            Fluorescence in Pipette
# 5051                NaN      Fluorescence in Pipette   a few small bubbles
# 5084                NaN                                                NaN
# 5085                NaN                            Fluorescence in Pipette
# 5089                NaN                       no bubbles during expulsion.
# 5117                NaN  Fluorescence in Pipette large bubble formed du...
# 5164                NaN          one small bubble formed during expulsion.
# 5192                NaN  Fluorescence in Pipette one big bubble formed ...
# 5199                NaN                                                NaN
# 5215                NaN   Cell Dimmed,Cell Shrunk   a couple small bubbles
# 5225                NaN  Fluorescence in Pipette sucked up nucleus duri...
# 5226                NaN  Fluorescence in Pipette sucked nucleus up into...
# 5229                NaN  Fluorescence in Pipette some small bubbles for...
# 5233                NaN  Fluorescence in Pipette a few small bubbles an...
# 5234                NaN  Fluorescence in Pipette very few small bubbles...
# 5250                NaN  Fluorescence in Pipette,Cell Dimmed   lots of ...
# 5251                NaN  Fluorescence in Pipette,Cell Dimmed   lots of ...
# 5261                NaN         few small bubbles formed during expulsion.
# 5262                NaN  lots of little bubbles formed during expulsion...
# 5263                NaN  Fluorescence in Pipette a big bubble formed du...
# 5277                NaN                            Fluorescence in Pipette
# 5291                NaN                  Cell Dimmed   a few small bubbles
# 5295                NaN  Fluorescence in Pipette no bubbles formed duri...
# 5296                NaN  Fluorescence in Pipette only a couple tiny bub...
# 5298                NaN  Fluorescence in Pipette No bubbles formed duri...
# 5309                NaN                                       tiny bubbles
# 5319                NaN  Fluorescence in Pipette,Cell Dimmed   a few sm...
# 5320                NaN  Fluorescence in Pipette,Cell Dimmed   a few sm...
# 5331                NaN  Fluorescence in Pipette some small bubbles for...
# ...                 ...                                                ...
# 6730                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 6750                NaN    No Bubbles  0.15 units of pressure on expulsion
# 6756                NaN      No Bubbles 0.1 units of pressure on expulsion
# 6757                NaN      No Bubbles 0.1 units of pressure on expulsion
# 6764                NaN  Cell Dimmed,Cell Shrunk No Bubbles 0.1 units o...
# 6798                NaN  Cell Disappeared No Bubbles 0.1 units of press...
# 6830                NaN  Fluorescence in Pipette,Cell Shrunk No Bubbles...
# 6867                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 6868                NaN                                         No Bubbles
# 6869                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 6915                NaN  Cell Disappeared No Bubbles 0.1 units of press...
# 6916                NaN  Cell Disappeared No Bubbles 0.1 units of press...
# 6918                NaN  Cell Disappeared Small Bubbles 0.1 units of pr...
# 6927                NaN                                         No Bubbles
# 7037                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Swell...
# 7040                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7041                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7054                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 7057                NaN  Fluorescence in Pipette No Bubbles 0.1 units o...
# 7078                NaN  Fluorescence in Pipette,Cell Dimmed No Bubbles...
# 7151                NaN      No Bubbles 0.1 units of pressure on expulsion
# 7153                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
# 7237                NaN  Fluorescence in Pipette Small Bubbles 0.1 unit...
# 5088                NaN                    small bubbles during expulsion.
# 5369                NaN                                                NaN
# 5532                NaN                                         No Bubbles
# 5687                NaN  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 5847                NaN                        Cell Dimmed   Small Bubbles
# 6814                NaN  Fluorescence in Pipette,Cell Swelled No Bubble...
# 6963                NaN  Fluorescence in Pipette,Cell Disappeared No Bu...
#
#          Internal version  PCR cycles SM_QC_PF  Resolution index  \
# 5026                 AiV2        21.0     pass          1.000000
# 5027                 AiV2        21.0     pass          0.877682
# 5051                 AiV2        21.0     pass          1.000000
# 5084                 AiV2        21.0     pass          1.000000
# 5085                 AiV2        21.0     pass          1.000000
# 5089                 AiV2        21.0     pass          1.000000
# 5117                 AiV2        21.0     pass          1.000000
# 5164                 AiV2        21.0     pass          1.000000
# 5192                 AiV2        21.0     pass          1.000000
# 5199                 AiV2        21.0     pass          0.805486
# 5215                 AiV2        21.0     pass          1.000000
# 5225                 AiV2        21.0     pass          1.000000
# 5226                 AiV2        21.0     pass          1.000000
# 5229                 AiV2        21.0     pass          1.000000
# 5233                 AiV2        21.0     pass          1.000000
# 5234                 AiV2        21.0     pass          1.000000
# 5250                 AiV2        21.0     pass          1.000000
# 5251                 AiV2        21.0     pass          1.000000
# 5261                 AiV2        21.0     pass          1.000000
# 5262                 AiV2        21.0     pass          1.000000
# 5263                 AiV2        21.0     pass          1.000000
# 5277                 AiV2        21.0     pass          1.000000
# 5291                 AiV2        21.0     pass          1.000000
# 5295                 AiV2        21.0     pass          1.000000
# 5296                 AiV2        21.0     pass          1.000000
# 5298                 AiV2        21.0     pass          1.000000
# 5309                 AiV2        21.0     pass          1.000000
# 5319                 AiV2        21.0     pass          1.000000
# 5320                 AiV2        21.0     pass          1.000000
# 5331                 AiV2        21.0     pass          1.000000
# ...                   ...         ...      ...               ...
# 6730                 AiV2        21.0     pass          1.000000
# 6750                 AiV2        21.0     pass          1.000000
# 6756                 AiV2        21.0     pass          1.000000
# 6757                 AiV2        21.0     pass          1.000000
# 6764                 AiV2        21.0     pass          1.000000
# 6798                 AiV2        21.0     pass          1.000000
# 6830                 AiV2        21.0     pass          1.000000
# 6867                 AiV2        21.0     pass          1.000000
# 6868                 AiV2        21.0     pass          1.000000
# 6869                 AiV2        21.0     pass          1.000000
# 6915                 AiV2        21.0     pass          1.000000
# 6916                 AiV2        21.0     pass          1.000000
# 6918                 AiV2        21.0     pass          1.000000
# 6927                 AiV2        21.0     pass          1.000000
# 7037                 AiV2        21.0     pass          1.000000
# 7040                 AiV2        21.0     pass          1.000000
# 7041                 AiV2        21.0     pass          1.000000
# 7054                 AiV2        21.0     pass          1.000000
# 7057                 AiV2        21.0     pass          1.000000
# 7078                 AiV2        21.0     pass          1.000000
# 7151  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7153  AiV2-50uM alexa 488        21.0     pass          1.000000
# 7237  AiV2-50uM alexa 488        21.0     pass          1.000000
# 5088                 AiV2        21.0     pass          1.000000
# 5369                 AiV2        21.0     pass          1.000000
# 5532                 AiV2        21.0     pass          1.000000
# 5687                 AiV2        21.0     pass          1.000000
# 5847                 AiV2        21.0     pass          1.000000
# 6814                 AiV2        21.0     pass          1.000000
# 6963                 AiV2        21.0     pass          1.000000
#
#       Res index pctl. post patch class
# 5026            100.0        Nucleated
# 5027             64.0        Nucleated
# 5051            100.0        Nucleated
# 5084            100.0        Nucleated
# 5085            100.0        Nucleated
# 5089            100.0        Nucleated
# 5117            100.0        Nucleated
# 5164            100.0        Nucleated
# 5192            100.0        Nucleated
# 5199             56.0        Nucleated
# 5215            100.0        Nucleated
# 5225            100.0        Nucleated
# 5226            100.0        Nucleated
# 5229            100.0        Nucleated
# 5233            100.0        Nucleated
# 5234            100.0        Nucleated
# 5250            100.0        Nucleated
# 5251            100.0        Nucleated
# 5261            100.0        Nucleated
# 5262            100.0        Nucleated
# 5263            100.0        Nucleated
# 5277            100.0        Nucleated
# 5291            100.0        Nucleated
# 5295            100.0        Nucleated
# 5296            100.0        Nucleated
# 5298            100.0        Nucleated
# 5309            100.0        Nucleated
# 5319            100.0        Nucleated
# 5320            100.0        Nucleated
# 5331            100.0        Nucleated
# ...               ...              ...
# 6730            100.0          No seal
# 6750              NaN          No seal
# 6756              NaN          No seal
# 6757              NaN          No seal
# 6764              NaN          No seal
# 6798              NaN          No seal
# 6830            100.0          No seal
# 6867            100.0          No seal
# 6868            100.0          No seal
# 6869            100.0          No seal
# 6915              NaN          No seal
# 6916              NaN          No seal
# 6918              NaN          No seal
# 6927            100.0          No seal
# 7037            100.0          No seal
# 7040            100.0          No seal
# 7041            100.0          No seal
# 7054            100.0          No seal
# 7057            100.0          No seal
# 7078            100.0          No seal
# 7151            100.0          No seal
# 7153            100.0          No seal
# 7237            100.0          No seal
# 5088            100.0      Entire cell
# 5369            100.0      Entire cell
# 5532            100.0      Entire cell
# 5687            100.0      Entire cell
# 5847            100.0      Entire cell
# 6814            100.0      Entire cell
# 6963            100.0      Entire cell
#
# [573 rows x 14 columns]

# %% [markdown]
# #### Resolution index vs post patch outcome

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 4)
sns.violinplot(x="post patch class", y="Resolution index", data=ps2, inner=None, cut =0, scale='count',ax=ax)
#sns.swarmplot(x="post patch class", y="Resolution index", data=ps2, color="w", alpha=.5);
#sns.swarmplot(x="post patch class", y="Resolution index", data=hi_res_data, color="w", alpha=.5);
#sns.set_context("poster")
plt.title("Resolution Index vs. Post Patch Outcome")
plt.xlabel("Post Patch Outcome")
#plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("RI plot",dpi=200)

# %% [markdown]
# #### Resolution index vs post patch outcome: scale = area

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 4)
sns.violinplot(x="post patch class", y="Resolution index", data=ps2, inner=None, cut =0, scale='area', ax=ax)
plt.title("Resolution Index vs. Post Patch Outcome")
plt.xlabel("Post Patch Outcome")
#plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("RI plot-area",dpi=200)

# %%
ps["Date"].head()
# Out:
# 4969   2017-04-19
# 4971   2017-04-19
# 4972   2017-04-19
# 4973   2017-04-19
# 4974   2017-04-19
# Name: Date, dtype: datetime64[ns]

# %%
ps["Date"].tail()
# Out:
# 7244   2017-09-21
# 7245   2017-09-21
# 7246   2017-09-21
# 7247   2017-09-21
# 7252   2017-09-21
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# #### Plot for Brian - Nucleated patch Reolution Index only

# %%
ps3= gen_filter(ps2, "post patch class", "Nucleated")
sns.violinplot(x="post patch class", y="Resolution index", data=ps3, inner=None, cut =0, scale='area', width=0.5)
plt.title("Resolution Index vs. Post Patch Outcome")
plt.xlabel("Post Patch Outcome")
#plt.xticks(rotation=30)
#plt.tight_layout()
plt.savefig("RI plot-nucleated",dpi=200)

# %% [markdown]
# #### Resolution index percentile vs post patch outcome

# %%
sns.violinplot(x="post patch class", y="Res index pctl.", data=ps2, inner=None, cut =0, scale='area')
plt.title("Resolution Index Percentile vs. Post Patch Outcome")
plt.xlabel("Post Patch Outcome")
#plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("RI percentile plot-area",dpi=200)

# %% [markdown]
# #### Resolution index vs post patch outcome: scale = area PRE ALEXA

# %%
sns.violinplot(x="post patch class", y="Resolution index", data=pre_alexa, inner=None, cut =0, scale='area')
plt.title("Standard Internal")
plt.xlabel("Post Patch Outcome")
#plt.figure(figsize=(8, 6))
#plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("RI plot-pre_alexa",dpi=200)

# %% [markdown]
# #### Resolution index vs post patch outcome: scale = area POST ALEXA

# %%
sns.violinplot(x="post patch class", y="Resolution index", data=post_alexa, inner=None, cut =0, scale='area')
plt.title("Alexa Internal")
plt.xlabel("Post Patch Outcome")
#plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("RI plot-post_alexa",dpi=200)

# %% [markdown]
# #### Comparing RI standard internal vs alexa

# %%
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(12,4))
#f, (ax1, ax2) = plt.subplots(2, figsize=(7,7))
sns.violinplot(x="post patch class", y="Resolution index", data=pre_alexa, inner="box", cut =0, scale='area', ax=ax1)
ax1.set_title("Standard Internal")
ax1.set_xlabel('')
sns.violinplot(x="post patch class", y="Resolution index", data=post_alexa, inner="box", cut =0, scale='area', ax=ax2)
ax2.set_title("Alexa Internal")
ax2.set_xlabel('')
plt.tight_layout()
plt.savefig("RI plot-alexa vs standard", dpi=100)

# %%
ps["Resolution index"].mean()
# Out:
# 0.716690839795049

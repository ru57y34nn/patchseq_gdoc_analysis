# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
import math
import seaborn as sns
# %matplotlib inline

# %%
ps = pd.read_csv('patch_seq_log_mouse.csv')

# %%
ps = ps[["Date", "User", "Post patch?", "Post patch pipette R", "Nucleus sucked in?", "Notes", "Internal version", "Picogreen", "Ratio", "PCR cycles", "SM_QC_PF"]]
ps.dropna(subset = ["Post patch?", "Picogreen"], inplace = True)
ps["User"] = ps["User"].astype("category")
ps["Post patch?"] = ps["Post patch?"].astype("category")
ps["SM_QC_PF"] = ps["SM_QC_PF"].astype("category")
ps = ps[ps["SM_QC_PF"] != "cnt"]
ps = ps[ps["PCR cycles"] == 21]
ps["Date"] = pd.to_datetime(ps["Date"], format = '%y%m%d')
ps
#ps['Post patch?'].value_counts()
# Out:
#            Date User      Post patch?  Post patch pipette R  \
# 4968 2017-04-19   P2      Outside-Out                   NaN
# 4969 2017-04-19   P2      Outside-Out                   NaN
# 4970 2017-04-19   P2          No-Seal                   NaN
# 4971 2017-04-19   P2        Nucleated                   NaN
# 4972 2017-04-19   P2      Outside-Out                   NaN
# 4973 2017-04-19   P2        Nucleated                   NaN
# 4974 2017-04-19   P2          No-Seal                   NaN
# 4975 2017-04-19   P2        Nucleated                   NaN
# 4978 2017-04-19   P6          No-Seal                   NaN
# 4979 2017-04-19   P6          No-Seal                   NaN
# 4980 2017-04-19   P6          No-Seal                   NaN
# 4981 2017-04-19   P6          No-Seal                   NaN
# 4988 2017-04-20   P1        Nucleated                   NaN
# 4989 2017-04-20   P1          No-Seal                   NaN
# 4990 2017-04-20   P1          No-Seal                   NaN
# 4991 2017-04-20   P1          No-Seal                   NaN
# 4992 2017-04-20   P1          No-Seal                   NaN
# 4993 2017-04-20   P1          No-Seal                   NaN
# 4994 2017-04-20   P1          No-Seal                   NaN
# 4995 2017-04-20   P1          No-Seal                   NaN
# 4996 2017-04-20   P1  Partial-Nucleus                   NaN
# 4997 2017-04-20   P1        Nucleated                   NaN
# 5000 2017-04-20   P2          No-Seal                   NaN
# 5001 2017-04-20   P2      Outside-Out                   NaN
# 5002 2017-04-20   P2      Entire-Cell                   NaN
# 5003 2017-04-20   P2          No-Seal                   NaN
# 5004 2017-04-20   P2          No-Seal                   NaN
# 5005 2017-04-20   P2          No-Seal                   NaN
# 5006 2017-04-20   P2          No-Seal                   NaN
# 5007 2017-04-20   P2          No-Seal                   NaN
# ...         ...  ...              ...                   ...
# 7567 2017-10-16   P9   nucleus_absent                 300.0
# 7568 2017-10-16   PA  nucleus_present                   3.0
# 7569 2017-10-16   PA  nucleus_present                   3.6
# 7570 2017-10-16   PA   nucleus_absent                   3.5
# 7571 2017-10-16   PA  nucleus_present                   6.0
# 7572 2017-10-16   PA  nucleus_present                1000.0
# 7573 2017-10-16   PB  nucleus_present                2000.0
# 7574 2017-10-16   PB  nucleus_present                2000.0
# 7575 2017-10-16   PB  nucleus_present                2000.0
# 7576 2017-10-16   PB  nucleus_present                2000.0
# 7577 2017-10-16   PB  nucleus_present                1000.0
# 7578 2017-10-17   P2   nucleus_absent                  10.0
# 7579 2017-10-17   P2   nucleus_absent                  15.0
# 7580 2017-10-17   P8  nucleus_present                1500.0
# 7581 2017-10-17   P8   nucleus_absent                  50.0
# 7582 2017-10-17   P8  nucleus_present                1000.0
# 7583 2017-10-17   P8   nucleus_absent                  10.0
# 7584 2017-10-18   P2  nucleus_present                  10.0
# 7585 2017-10-18   P2   nucleus_absent                   4.0
# 7586 2017-10-18   P2  nucleus_present                1000.0
# 7587 2017-10-18   P2      entire_cell                   7.0
# 7588 2017-10-18   P2      entire_cell                  10.0
# 7589 2017-10-18   P2   nucleus_absent                  10.0
# 7590 2017-10-18   P2   nucleus_absent                  10.0
# 7591 2017-10-18   P2   nucleus_absent                   5.0
# 7592 2017-10-18   P8  nucleus_present                 100.0
# 7593 2017-10-18   P8  nucleus_present                  20.0
# 7594 2017-10-18   P8   nucleus_absent                  10.0
# 7595 2017-10-18   P8  nucleus_present                1000.0
# 7596 2017-10-18   P8  nucleus_present                1000.0
#
#      Nucleus sucked in?                                              Notes  \
# 4968                NaN                                                NaN
# 4969                NaN                                                NaN
# 4970                NaN                                                NaN
# 4971                NaN                                                NaN
# 4972                NaN                                                NaN
# 4973                NaN                                                NaN
# 4974                NaN                                                NaN
# 4975                NaN                                                NaN
# 4978                NaN                                                NaN
# 4979                NaN                                                NaN
# 4980                NaN                                                NaN
# 4981                NaN                                                NaN
# 4988                NaN                                                NaN
# 4989                NaN                                                NaN
# 4990                NaN                                                NaN
# 4991                NaN                                                NaN
# 4992                NaN                                                NaN
# 4993                NaN                                                NaN
# 4994                NaN                                                NaN
# 4995                NaN                                                NaN
# 4996                NaN                                                NaN
# 4997                NaN                                                NaN
# 5000                NaN                                                NaN
# 5001                NaN                                                NaN
# 5002                NaN                                                NaN
# 5003                NaN                                                NaN
# 5004                NaN                                                NaN
# 5005                NaN              approached angle same as tissue angle
# 5006                NaN                 approach angle same as slice angle
# 5007                NaN                                                NaN
# ...                 ...                                                ...
# 7567                 no  Fluorescence in Pipette No Bubbles Alexa fill ...
# 7568  not_intentionally  Cell Dimmed Medium Bubbles Partial-nucleated. ...
# 7569  not_intentionally  Cell Dimmed No Bubbles,Small Bubbles Partial-n...
# 7570                 no  Cell Dimmed,Cell Swelled,Cell Disappeared Smal...
# 7571  not_intentionally  Cell Dimmed,Cell Shrunk Small Bubbles Partial ...
# 7572                 no  Cell Dimmed,Cell Shrunk Small Bubbles When tra...
# 7573                 no                                            perfect
# 7574                 no                                            perfect
# 7575                 no                                            perfect
# 7576                 no                                            perfect
# 7577                 no                                            perfect
# 7578                 no     No Bubbles alexa fill visible post experiment.
# 7579                 no   Small Bubbles alexa fill visible post experiment
# 7580                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7581                 no  Cell Shrunk No Bubbles Alexa fill visible, but...
# 7582                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7583                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7584  not_intentionally  Fluorescence in Pipette Small Bubbles alexa fi...
# 7585                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7586                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7587                 no  No Bubbles alexa fill not visible post experim...
# 7588                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7589                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7590                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7591                 no  Fluorescence in Pipette No Bubbles alexa fill ...
# 7592      intentionally  Fluorescence in Pipette,Cell Dimmed No Bubbles...
# 7593  not_intentionally  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7594                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7595      intentionally  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
# 7596                 no  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...
#
#          Internal version Picogreen Ratio  PCR cycles SM_QC_PF
# 4968                 AiV2        71  0.41        21.0     fail
# 4969                 AiV2       608  0.54        21.0     pass
# 4970                 AiV2         6     1        21.0     fail
# 4971                 AiV2      1536  0.71        21.0     pass
# 4972                 AiV2       582  0.55        21.0     pass
# 4973                 AiV2      1154  0.81        21.0     pass
# 4974                 AiV2      1504  0.59        21.0     pass
# 4975                 AiV2      1330  0.71        21.0     pass
# 4978                 AiV2       839  0.33        21.0     fail
# 4979                 AiV2      1292  0.51        21.0     pass
# 4980                 AiV2       787  0.75        21.0     pass
# 4981                 AiV2       679  0.43        21.0     pass
# 4988                 AiV2       890  0.66        21.0     pass
# 4989                 AiV2       468  0.64        21.0     pass
# 4990                 AiV2       426   0.6        21.0     pass
# 4991                 AiV2       514   0.6        21.0     pass
# 4992                 AiV2       567  0.56        21.0     pass
# 4993                 AiV2       452  0.66        21.0     pass
# 4994                 AiV2       509   0.7        21.0     pass
# 4995                 AiV2       472  0.58        21.0     pass
# 4996                 AiV2       810  0.62        21.0     pass
# 4997                 AiV2      1023  0.65        21.0     pass
# 5000                 AiV2      4952  0.41        21.0     pass
# 5001                 AiV2       790  0.46        21.0     pass
# 5002                 AiV2      1190  0.64        21.0     pass
# 5003                 AiV2      2965  0.43        21.0     pass
# 5004                 AiV2       820  0.45        21.0     pass
# 5005                 AiV2      1012  0.57        21.0     pass
# 5006                 AiV2       940  0.43        21.0     pass
# 5007                 AiV2      1303   0.4        21.0     pass
# ...                   ...       ...   ...         ...      ...
# 7567  AiV2-50uM alexa 488       655   30%        21.0     fail
# 7568  AiV2-50uM alexa 488       364   36%        21.0     fail
# 7569  AiV2-50uM alexa 488      1098   33%        21.0     pass
# 7570  AiV2-50uM alexa 488       690   33%        21.0     fail
# 7571  AiV2-50uM alexa 488       901   64%        21.0     pass
# 7572  AiV2-50uM alexa 488       405   36%        21.0     fail
# 7573  AiV2-50uM alexa 488      2605   48%        21.0     pass
# 7574  AiV2-50uM alexa 488      1376   49%        21.0     pass
# 7575  AiV2-50uM alexa 488      1699   30%        21.0     pass
# 7576  AiV2-50uM alexa 488      2541   51%        21.0     pass
# 7577  AiV2-50uM alexa 488      1899   67%        21.0     pass
# 7578  AiV2-50uM alexa 488       634   32%        21.0     fail
# 7579  AiV2-50uM alexa 488       931   37%        21.0     pass
# 7580  AiV2-50uM alexa 488       825   31%        21.0     pass
# 7581  AiV2-50uM alexa 488       966   26%        21.0     fail
# 7582  AiV2-50uM alexa 488      1018   51%        21.0     pass
# 7583  AiV2-50uM alexa 488      2262   48%        21.0     pass
# 7584  AiV2-50uM alexa 488       532   34%        21.0     fail
# 7585  AiV2-50uM alexa 488       385   31%        21.0     fail
# 7586  AiV2-50uM alexa 488       951   44%        21.0     pass
# 7587  AiV2-50uM alexa 488       722   21%        21.0     fail
# 7588  AiV2-50uM alexa 488      1420   28%        21.0     pass
# 7589  AiV2-50uM alexa 488      1110   22%        21.0     fail
# 7590  AiV2-50uM alexa 488      1339   42%        21.0     pass
# 7591  AiV2-50uM alexa 488       654   35%        21.0     fail
# 7592  AiV2-50uM alexa 488     16641   65%        21.0     fail
# 7593  AiV2-50uM alexa 488      1668   31%        21.0     pass
# 7594  AiV2-50uM alexa 488      4448   55%        21.0     pass
# 7595  AiV2-50uM alexa 488      1822   31%        21.0     pass
# 7596  AiV2-50uM alexa 488      2808   28%        21.0     pass
#
# [1847 rows x 11 columns]

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1847 entries, 4968 to 7596
# Data columns (total 11 columns):
# Date                    1847 non-null datetime64[ns]
# User                    1847 non-null category
# Post patch?             1847 non-null category
# Post patch pipette R    240 non-null float64
# Nucleus sucked in?      240 non-null object
# Notes                   1728 non-null object
# Internal version        1841 non-null object
# Picogreen               1847 non-null object
# Ratio                   1846 non-null object
# PCR cycles              1847 non-null float64
# SM_QC_PF                1847 non-null category
# dtypes: category(3), datetime64[ns](1), float64(2), object(5)
# memory usage: 136.2+ KB

# %%
def get_count(x):    
    count = x["Post patch?"].count()
    return count

def calc_pct(part,total):
    pct = float(get_count(part)) / get_count(total)
    return pct

# %%
def nucleated(x):
    nucleus = x[(x["Post patch?"] == "Nucleated") | (((x["Post patch?"] == "nucleus_visible") | (x["Post patch?"] == "nucleus_present")) & (x["Post patch pipette R"] >= 501))]
    return nucleus

def partial_nucleated(y):
    partial = y[(y["Post patch?"] == 'Partial-Nucleus') | (((y['Post patch?'] == 'nucleus_present') | (y['Post patch?'] == 'nucleus_visible')) & (y["Post patch pipette R"] <= 500))]
    return partial

def outside_out(z):
    outside = z[(z["Post patch?"] == 'Outside-Out') | (((z['Post patch?'] == 'nucleus_absent') | (z['Post patch?'] == 'no_nuclues_visible')) & (z['Post patch pipette R'] >= 501))]
    return outside

def no_seal(w): 
    no = w[(w["Post patch?"] == 'No-Seal') | (((w['Post patch?'] == 'nucleus_absent') | (w['Post patch?'] == 'no_nucleus_visible')) & (w['Post patch pipette R'] <= 500))]
    return no
    
def entire_cell(v):
    entire = v[(v["Post patch?"] == 'Entire-Cell') | (v['Post patch?'] == 'entire_cell')]
    return entire
    
def pass_only(df):
    pas = df[df["SM_QC_PF"] == "pass"]
    return pas

def gen_filter(df, col, cond):
    filtr = df[df[col] == cond]
    return filtr

# %%
nuc = nucleated(ps)
nuc["post patch class"] = "Nucleated"

part_nuc = partial_nucleated(ps)
part_nuc["post patch class"] = "Partial nucleated"

out_out = outside_out(ps)
out_out["post patch class"] = "Outisde out"

noSeal = no_seal(ps)
noSeal["post patch class"] = "No seal"

entirecell = entire_cell(ps)
entirecell["post patch class"] = "Entire Cell"

frames = [nuc, part_nuc, out_out, noSeal, entirecell]
ps2 = pd.concat(frames)
ps2
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Date User     Post patch?  Post patch pipette R Nucleus sucked in?  \
# 4971 2017-04-19   P2       Nucleated                   NaN                NaN
# 4973 2017-04-19   P2       Nucleated                   NaN                NaN
# 4975 2017-04-19   P2       Nucleated                   NaN                NaN
# 4988 2017-04-20   P1       Nucleated                   NaN                NaN
# 4997 2017-04-20   P1       Nucleated                   NaN                NaN
# 5009 2017-04-20   P2       Nucleated                   NaN                NaN
# 5022 2017-04-21   P1       Nucleated                   NaN                NaN
# 5026 2017-04-21   P2       Nucleated                   NaN                NaN
# 5027 2017-04-21   P2       Nucleated                   NaN                NaN
# 5035 2017-04-21   P2       Nucleated                   NaN                NaN
# 5045 2017-04-24   P1       Nucleated                   NaN                NaN
# 5051 2017-04-24   P1       Nucleated                   NaN                NaN
# 5058 2017-04-24   P2       Nucleated                   NaN                NaN
# 5063 2017-04-24   P2       Nucleated                   NaN                NaN
# 5073 2017-04-25   P1       Nucleated                   NaN                NaN
# 5084 2017-04-25   P2       Nucleated                   NaN                NaN
# 5085 2017-04-25   P2       Nucleated                   NaN                NaN
# 5089 2017-04-25   P2       Nucleated                   NaN                NaN
# 5111 2017-04-26   P2       Nucleated                   NaN                NaN
# 5114 2017-04-26   P2       Nucleated                   NaN                NaN
# 5117 2017-04-26   P2       Nucleated                   NaN                NaN
# 5134 2017-04-27   P1       Nucleated                   NaN                NaN
# 5146 2017-04-27   P2       Nucleated                   NaN                NaN
# 5154 2017-04-28   P1       Nucleated                   NaN                NaN
# 5164 2017-04-28   P2       Nucleated                   NaN                NaN
# 5166 2017-04-28   P2       Nucleated                   NaN                NaN
# 5184 2017-05-01   P2       Nucleated                   NaN                NaN
# 5185 2017-05-01   P2       Nucleated                   NaN                NaN
# 5186 2017-05-01   P2       Nucleated                   NaN                NaN
# 5189 2017-05-01   P2       Nucleated                   NaN                NaN
# ...         ...  ...             ...                   ...                ...
# 7579 2017-10-17   P2  nucleus_absent                  15.0                 no
# 7581 2017-10-17   P8  nucleus_absent                  50.0                 no
# 7583 2017-10-17   P8  nucleus_absent                  10.0                 no
# 7585 2017-10-18   P2  nucleus_absent                   4.0                 no
# 7589 2017-10-18   P2  nucleus_absent                  10.0                 no
# 7590 2017-10-18   P2  nucleus_absent                  10.0                 no
# 7591 2017-10-18   P2  nucleus_absent                   5.0                 no
# 7594 2017-10-18   P8  nucleus_absent                  10.0                 no
# 5002 2017-04-20   P2     Entire-Cell                   NaN                NaN
# 5088 2017-04-25   P2     Entire-Cell                   NaN                NaN
# 5242 2017-05-02   P6     Entire-Cell                   NaN                NaN
# 5269 2017-05-03   P2     Entire-Cell                   NaN                NaN
# 5273 2017-05-03   P5     Entire-Cell                   NaN                NaN
# 5274 2017-05-03   P5     Entire-Cell                   NaN                NaN
# 5369 2017-05-10   P6     Entire-Cell                   NaN                NaN
# 5532 2017-05-18   P6     Entire-Cell                   NaN                NaN
# 5623 2017-05-24   P6     Entire-Cell                   NaN                NaN
# 5687 2017-06-01   P1     Entire-Cell                   NaN                NaN
# 5847 2017-06-13   P1     Entire-Cell                   NaN                NaN
# 6814 2017-08-02   P8     Entire-Cell                   NaN                NaN
# 6963 2017-08-09   P8     Entire-Cell                   NaN                NaN
# 7076 2017-08-25   P8     Entire-Cell                   NaN                NaN
# 7094 2017-08-29   P8     Entire-Cell                   NaN                NaN
# 7272 2017-09-22   PA     Entire-Cell                   NaN                NaN
# 7308 2017-09-26   PB     Entire-Cell                   NaN                NaN
# 7410 2017-10-04   P2     entire_cell                  10.0                 no
# 7447 2017-10-05   P2     entire_cell                 100.0                 no
# 7455 2017-10-05   P9     entire_cell                   5.0  not_intentionally
# 7587 2017-10-18   P2     entire_cell                   7.0                 no
# 7588 2017-10-18   P2     entire_cell                  10.0                 no
#
#                                                   Notes     Internal version  \
# 4971                                                NaN                 AiV2
# 4973                                                NaN                 AiV2
# 4975                                                NaN                 AiV2
# 4988                                                NaN                 AiV2
# 4997                                                NaN                 AiV2
# 5009                                                NaN                 AiV2
# 5022                Fluorescence in Pipette,Cell Dimmed                 AiV2
# 5026                            Fluorescence in Pipette                 AiV2
# 5027                            Fluorescence in Pipette                 AiV2
# 5035                                                NaN                 AiV2
# 5045                            Fluorescence in Pipette                 AiV2
# 5051      Fluorescence in Pipette   a few small bubbles                 AiV2
# 5058                                                NaN                 AiV2
# 5063  Fluorescence in Pipette One big bubble formed ...                 AiV2
# 5073                              lots of small bubbles                 AiV2
# 5084                                                NaN                 AiV2
# 5085                            Fluorescence in Pipette                 AiV2
# 5089                       no bubbles during expulsion.                 AiV2
# 5111                                                NaN                 AiV2
# 5114  Fluorescence in Pipette a few small bubbles fo...                 AiV2
# 5117  Fluorescence in Pipette large bubble formed du...                 AiV2
# 5134                              lots of small bubbles                 AiV2
# 5146                few small bubbles during expulsion.                 AiV2
# 5154               Fluorescence in Pipette   no bubbles                 AiV2
# 5164          one small bubble formed during expulsion.                 AiV2
# 5166  One medium bubble formed during expulsion, sol...                 AiV2
# 5184    a couple small bubbles formed during expulsion.                 AiV2
# 5185  Fluorescence in Pipette a few small bubbles an...                 AiV2
# 5186  Fluorescence in Pipette few small bubbles form...                 AiV2
# 5189  Fluorescence in Pipette a layer of small bubbl...                 AiV2
# ...                                                 ...                  ...
# 7579   Small Bubbles alexa fill visible post experiment  AiV2-50uM alexa 488
# 7581  Cell Shrunk No Bubbles Alexa fill visible, but...  AiV2-50uM alexa 488
# 7583  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7585  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7589  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7590  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7591  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7594  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 5002                                                NaN                 AiV2
# 5088                    small bubbles during expulsion.                 AiV2
# 5242                                                NaN                 AiV2
# 5269                            Fluorescence in Pipette                 AiV2
# 5273  cuoldnt get gigaseal but pulled Entire-Cell ou...                  NaN
# 5274  cuoldnt get gigaseal but pulled Entire-Cell ou...                  NaN
# 5369                                                NaN                 AiV2
# 5532                                         No Bubbles                 AiV2
# 5623                                     Medium Bubbles                 AiV2
# 5687  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...                 AiV2
# 5847                        Cell Dimmed   Small Bubbles                 AiV2
# 6814  Fluorescence in Pipette,Cell Swelled No Bubble...                 AiV2
# 6963  Fluorescence in Pipette,Cell Disappeared No Bu...                 AiV2
# 7076     Fluorescence in Pipette,Cell Shrunk No Bubbles                 AiV2
# 7094  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7272  No Bubbles Sucked in entire cell while retract...  AiV2-50uM alexa 488
# 7308                            Fluorescence in Pipette  AiV2-50uM alexa 488
# 7410  Fluorescence in Pipette Medium Bubbles cell de...  AiV2-50uM alexa 488
# 7447  Fluorescence in Pipette Small Bubbles alexa fi...  AiV2-50uM alexa 488
# 7455  Fluorescence in Pipette,Cell Dimmed No Bubbles...  AiV2-50uM alexa 488
# 7587  No Bubbles alexa fill not visible post experim...  AiV2-50uM alexa 488
# 7588  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
#
#      Picogreen Ratio  PCR cycles SM_QC_PF post patch class
# 4971      1536  0.71        21.0     pass        Nucleated
# 4973      1154  0.81        21.0     pass        Nucleated
# 4975      1330  0.71        21.0     pass        Nucleated
# 4988       890  0.66        21.0     pass        Nucleated
# 4997      1023  0.65        21.0     pass        Nucleated
# 5009      1701  0.74        21.0     pass        Nucleated
# 5022      1211  0.81        21.0     pass        Nucleated
# 5026      1272  0.61        21.0     pass        Nucleated
# 5027       775  0.75        21.0     pass        Nucleated
# 5035      1134  0.78        21.0     pass        Nucleated
# 5045      1419  0.67        21.0     pass        Nucleated
# 5051       942  0.66        21.0     pass        Nucleated
# 5058       655  0.91        21.0     pass        Nucleated
# 5063       751  0.63        21.0     pass        Nucleated
# 5073       838  0.67        21.0     pass        Nucleated
# 5084       840  0.77        21.0     pass        Nucleated
# 5085      1085   0.7        21.0     pass        Nucleated
# 5089       641  0.76        21.0     pass        Nucleated
# 5111      1207  0.55        21.0     pass        Nucleated
# 5114       903  0.62        21.0     pass        Nucleated
# 5117      1195  0.83        21.0     pass        Nucleated
# 5134       659  0.64        21.0     pass        Nucleated
# 5146      1241  0.62        21.0     pass        Nucleated
# 5154       524  0.59        21.0     pass        Nucleated
# 5164      1236  0.81        21.0     pass        Nucleated
# 5166      1356  0.55        21.0     pass        Nucleated
# 5184      1269  0.67        21.0     pass        Nucleated
# 5185      1169  0.75        21.0     pass        Nucleated
# 5186      2156  0.77        21.0     pass        Nucleated
# 5189      1287  0.78        21.0     pass        Nucleated
# ...        ...   ...         ...      ...              ...
# 7579       931   37%        21.0     pass          No seal
# 7581       966   26%        21.0     fail          No seal
# 7583      2262   48%        21.0     pass          No seal
# 7585       385   31%        21.0     fail          No seal
# 7589      1110   22%        21.0     fail          No seal
# 7590      1339   42%        21.0     pass          No seal
# 7591       654   35%        21.0     fail          No seal
# 7594      4448   55%        21.0     pass          No seal
# 5002      1190  0.64        21.0     pass      Entire Cell
# 5088      1155  0.48        21.0     pass      Entire Cell
# 5242       957  0.66        21.0     pass      Entire Cell
# 5269      2698  0.47        21.0     fail      Entire Cell
# 5273      1885  0.69        21.0     pass      Entire Cell
# 5274      2089  0.64        21.0     pass      Entire Cell
# 5369      1850  0.63        21.0     pass      Entire Cell
# 5532      1034  0.75        21.0     pass      Entire Cell
# 5623       663  0.22        21.0     fail      Entire Cell
# 5687       983  0.66        21.0     pass      Entire Cell
# 5847       922  0.72        21.0     pass      Entire Cell
# 6814      2391  0.86        21.0     pass      Entire Cell
# 6963      5631   0.9        21.0     pass      Entire Cell
# 7076       698  0.59        21.0     pass      Entire Cell
# 7094       300   172        21.0     pass      Entire Cell
# 7272       722   42%        21.0     pass      Entire Cell
# 7308     517.5   45%        21.0     pass      Entire Cell
# 7410      1967   21%        21.0     fail      Entire Cell
# 7447      1674   46%        21.0     pass      Entire Cell
# 7455       760   46%        21.0     pass      Entire Cell
# 7587       722   21%        21.0     fail      Entire Cell
# 7588      1420   28%        21.0     pass      Entire Cell
#
# [1845 rows x 12 columns]

# %%
ps2["Picogreen"] = pd.to_numeric(ps2["Picogreen"].str.replace(' ',''), errors ='force')
ps2["post patch class"] = ps2["post patch class"].astype("category")
ps2['Internal version'] = ps2['Internal version'].astype('category')
ps2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1845 entries, 4971 to 7588
# Data columns (total 12 columns):
# Date                    1845 non-null datetime64[ns]
# User                    1845 non-null category
# Post patch?             1845 non-null category
# Post patch pipette R    239 non-null float64
# Nucleus sucked in?      239 non-null object
# Notes                   1726 non-null object
# Internal version        1839 non-null category
# Picogreen               1845 non-null float64
# Ratio                   1844 non-null object
# PCR cycles              1845 non-null float64
# SM_QC_PF                1845 non-null category
# post patch class        1845 non-null category
# dtypes: category(5), datetime64[ns](1), float64(3), object(3)
# memory usage: 125.6+ KB

# %%
ps2 = ps2[ps2["Picogreen"] < 10000]
ps2 = ps2[ps2['Internal version'] != 'AiV2-50uM alexa 489']
ps2['Internal version'].value_counts()
# Out:
# AiV2                   1368
# AiV2-50uM alexa 488     469
# Name: Internal version, dtype: int64

# %%
#Internal = ps2.groupby(['Internal version'])
#standard = ps2[ps2['Internal version'] == 'AiV2']
#standard
sns.swarmplot(x='Internal version', y='Picogreen', data=ps2)
#sns.violinplot(x='post patch class', y='Picogreen', data=ps2)

# %%
sns.violinplot(x='Internal version', y='Picogreen', data=ps2, scale='area')
plt.title("Picogreen Concentration vs Internal Version")
plt.savefig("Picogreen Concentration vs Internal Version", dpi=300)

# %%
#scatterplot data includes both standard and Alexa internal
sns.swarmplot(x='post patch class', y='Picogreen', data=ps2)

# %%
#violinplot data includes both standard and Alexa internal
sns.violinplot(x='post patch class', y='Picogreen', data=ps2)

# %%
standard_internal = gen_filter(ps2,"Internal version", "AiV2")
standard_internal
# Out:
#            Date User  Post patch?  Post patch pipette R Nucleus sucked in?  \
# 4971 2017-04-19   P2    Nucleated                   NaN                NaN
# 4973 2017-04-19   P2    Nucleated                   NaN                NaN
# 4975 2017-04-19   P2    Nucleated                   NaN                NaN
# 4988 2017-04-20   P1    Nucleated                   NaN                NaN
# 4997 2017-04-20   P1    Nucleated                   NaN                NaN
# 5009 2017-04-20   P2    Nucleated                   NaN                NaN
# 5022 2017-04-21   P1    Nucleated                   NaN                NaN
# 5026 2017-04-21   P2    Nucleated                   NaN                NaN
# 5027 2017-04-21   P2    Nucleated                   NaN                NaN
# 5035 2017-04-21   P2    Nucleated                   NaN                NaN
# 5045 2017-04-24   P1    Nucleated                   NaN                NaN
# 5051 2017-04-24   P1    Nucleated                   NaN                NaN
# 5058 2017-04-24   P2    Nucleated                   NaN                NaN
# 5063 2017-04-24   P2    Nucleated                   NaN                NaN
# 5073 2017-04-25   P1    Nucleated                   NaN                NaN
# 5084 2017-04-25   P2    Nucleated                   NaN                NaN
# 5085 2017-04-25   P2    Nucleated                   NaN                NaN
# 5089 2017-04-25   P2    Nucleated                   NaN                NaN
# 5111 2017-04-26   P2    Nucleated                   NaN                NaN
# 5114 2017-04-26   P2    Nucleated                   NaN                NaN
# 5117 2017-04-26   P2    Nucleated                   NaN                NaN
# 5134 2017-04-27   P1    Nucleated                   NaN                NaN
# 5146 2017-04-27   P2    Nucleated                   NaN                NaN
# 5154 2017-04-28   P1    Nucleated                   NaN                NaN
# 5164 2017-04-28   P2    Nucleated                   NaN                NaN
# 5166 2017-04-28   P2    Nucleated                   NaN                NaN
# 5184 2017-05-01   P2    Nucleated                   NaN                NaN
# 5185 2017-05-01   P2    Nucleated                   NaN                NaN
# 5186 2017-05-01   P2    Nucleated                   NaN                NaN
# 5189 2017-05-01   P2    Nucleated                   NaN                NaN
# ...         ...  ...          ...                   ...                ...
# 6985 2017-08-10   P2      No-Seal                   NaN                NaN
# 6986 2017-08-10   P2      No-Seal                   NaN                NaN
# 6994 2017-08-11   P1      No-Seal                   NaN                NaN
# 7003 2017-08-16   P8      No-Seal                   NaN                NaN
# 7005 2017-08-16   P8      No-Seal                   NaN                NaN
# 7024 2017-08-18   P8      No-Seal                   NaN                NaN
# 7025 2017-08-18   P8      No-Seal                   NaN                NaN
# 7037 2017-08-21   P8      No-Seal                   NaN                NaN
# 7038 2017-08-21   P8      No-Seal                   NaN                NaN
# 7040 2017-08-23   P8      No-Seal                   NaN                NaN
# 7041 2017-08-23   P8      No-Seal                   NaN                NaN
# 7047 2017-08-23   P8      No-Seal                   NaN                NaN
# 7054 2017-08-24   P2      No-Seal                   NaN                NaN
# 7057 2017-08-24   P2      No-Seal                   NaN                NaN
# 7074 2017-08-25   P8      No-Seal                   NaN                NaN
# 7078 2017-08-25   P8      No-Seal                   NaN                NaN
# 7086 2017-08-28   P8      No-Seal                   NaN                NaN
# 7135 2017-09-01   P8      No-Seal                   NaN                NaN
# 5002 2017-04-20   P2  Entire-Cell                   NaN                NaN
# 5088 2017-04-25   P2  Entire-Cell                   NaN                NaN
# 5242 2017-05-02   P6  Entire-Cell                   NaN                NaN
# 5269 2017-05-03   P2  Entire-Cell                   NaN                NaN
# 5369 2017-05-10   P6  Entire-Cell                   NaN                NaN
# 5532 2017-05-18   P6  Entire-Cell                   NaN                NaN
# 5623 2017-05-24   P6  Entire-Cell                   NaN                NaN
# 5687 2017-06-01   P1  Entire-Cell                   NaN                NaN
# 5847 2017-06-13   P1  Entire-Cell                   NaN                NaN
# 6814 2017-08-02   P8  Entire-Cell                   NaN                NaN
# 6963 2017-08-09   P8  Entire-Cell                   NaN                NaN
# 7076 2017-08-25   P8  Entire-Cell                   NaN                NaN
#
#                                                   Notes Internal version  \
# 4971                                                NaN             AiV2
# 4973                                                NaN             AiV2
# 4975                                                NaN             AiV2
# 4988                                                NaN             AiV2
# 4997                                                NaN             AiV2
# 5009                                                NaN             AiV2
# 5022                Fluorescence in Pipette,Cell Dimmed             AiV2
# 5026                            Fluorescence in Pipette             AiV2
# 5027                            Fluorescence in Pipette             AiV2
# 5035                                                NaN             AiV2
# 5045                            Fluorescence in Pipette             AiV2
# 5051      Fluorescence in Pipette   a few small bubbles             AiV2
# 5058                                                NaN             AiV2
# 5063  Fluorescence in Pipette One big bubble formed ...             AiV2
# 5073                              lots of small bubbles             AiV2
# 5084                                                NaN             AiV2
# 5085                            Fluorescence in Pipette             AiV2
# 5089                       no bubbles during expulsion.             AiV2
# 5111                                                NaN             AiV2
# 5114  Fluorescence in Pipette a few small bubbles fo...             AiV2
# 5117  Fluorescence in Pipette large bubble formed du...             AiV2
# 5134                              lots of small bubbles             AiV2
# 5146                few small bubbles during expulsion.             AiV2
# 5154               Fluorescence in Pipette   no bubbles             AiV2
# 5164          one small bubble formed during expulsion.             AiV2
# 5166  One medium bubble formed during expulsion, sol...             AiV2
# 5184    a couple small bubbles formed during expulsion.             AiV2
# 5185  Fluorescence in Pipette a few small bubbles an...             AiV2
# 5186  Fluorescence in Pipette few small bubbles form...             AiV2
# 5189  Fluorescence in Pipette a layer of small bubbl...             AiV2
# ...                                                 ...              ...
# 6985  Cell Disappeared Small Bubbles 0.1 units of pr...             AiV2
# 6986  Cell Disappeared Small Bubbles 0.1 units of pr...             AiV2
# 6994  Too Deep   No Bubbles  0.15 units of pressure ...             AiV2
# 7003  Fluorescence in Pipette,Cell Shrunk No Bubbles...             AiV2
# 7005                 Fluorescence in Pipette No Bubbles             AiV2
# 7024     Fluorescence in Pipette,Cell Shrunk No Bubbles             AiV2
# 7025                 Fluorescence in Pipette No Bubbles             AiV2
# 7037  Fluorescence in Pipette,Cell Dimmed,Cell Swell...             AiV2
# 7038  Fluorescence in Pipette,Cell Shrunk No Bubbles...             AiV2
# 7040  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...             AiV2
# 7041  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...             AiV2
# 7047  Fluorescence in Pipette,Cell Shrunk No Bubbles...             AiV2
# 7054  Fluorescence in Pipette No Bubbles 0.1 units o...             AiV2
# 7057  Fluorescence in Pipette No Bubbles 0.1 units o...             AiV2
# 7074  Fluorescence in Pipette,Cell Disappeared No Bu...             AiV2
# 7078  Fluorescence in Pipette,Cell Dimmed No Bubbles...             AiV2
# 7086  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...             AiV2
# 7135      Cell Disappeared No Bubbles standard internal             AiV2
# 5002                                                NaN             AiV2
# 5088                    small bubbles during expulsion.             AiV2
# 5242                                                NaN             AiV2
# 5269                            Fluorescence in Pipette             AiV2
# 5369                                                NaN             AiV2
# 5532                                         No Bubbles             AiV2
# 5623                                     Medium Bubbles             AiV2
# 5687  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...             AiV2
# 5847                        Cell Dimmed   Small Bubbles             AiV2
# 6814  Fluorescence in Pipette,Cell Swelled No Bubble...             AiV2
# 6963  Fluorescence in Pipette,Cell Disappeared No Bu...             AiV2
# 7076     Fluorescence in Pipette,Cell Shrunk No Bubbles             AiV2
#
#       Picogreen Ratio  PCR cycles SM_QC_PF post patch class
# 4971     1536.0  0.71        21.0     pass        Nucleated
# 4973     1154.0  0.81        21.0     pass        Nucleated
# 4975     1330.0  0.71        21.0     pass        Nucleated
# 4988      890.0  0.66        21.0     pass        Nucleated
# 4997     1023.0  0.65        21.0     pass        Nucleated
# 5009     1701.0  0.74        21.0     pass        Nucleated
# 5022     1211.0  0.81        21.0     pass        Nucleated
# 5026     1272.0  0.61        21.0     pass        Nucleated
# 5027      775.0  0.75        21.0     pass        Nucleated
# 5035     1134.0  0.78        21.0     pass        Nucleated
# 5045     1419.0  0.67        21.0     pass        Nucleated
# 5051      942.0  0.66        21.0     pass        Nucleated
# 5058      655.0  0.91        21.0     pass        Nucleated
# 5063      751.0  0.63        21.0     pass        Nucleated
# 5073      838.0  0.67        21.0     pass        Nucleated
# 5084      840.0  0.77        21.0     pass        Nucleated
# 5085     1085.0   0.7        21.0     pass        Nucleated
# 5089      641.0  0.76        21.0     pass        Nucleated
# 5111     1207.0  0.55        21.0     pass        Nucleated
# 5114      903.0  0.62        21.0     pass        Nucleated
# 5117     1195.0  0.83        21.0     pass        Nucleated
# 5134      659.0  0.64        21.0     pass        Nucleated
# 5146     1241.0  0.62        21.0     pass        Nucleated
# 5154      524.0  0.59        21.0     pass        Nucleated
# 5164     1236.0  0.81        21.0     pass        Nucleated
# 5166     1356.0  0.55        21.0     pass        Nucleated
# 5184     1269.0  0.67        21.0     pass        Nucleated
# 5185     1169.0  0.75        21.0     pass        Nucleated
# 5186     2156.0  0.77        21.0     pass        Nucleated
# 5189     1287.0  0.78        21.0     pass        Nucleated
# ...         ...   ...         ...      ...              ...
# 6985     1916.0  0.57        21.0     pass          No seal
# 6986     1814.0  0.45        21.0     fail          No seal
# 6994     1072.0  0.56        21.0     pass          No seal
# 7003     1609.0  0.77        21.0     pass          No seal
# 7005      804.0  0.67        21.0     pass          No seal
# 7024      543.0  0.57        21.0     fail          No seal
# 7025      734.0  0.62        21.0     fail          No seal
# 7037      923.0  0.82        21.0     pass          No seal
# 7038      353.0  0.59        21.0     pass          No seal
# 7040     1234.0  0.42        21.0     pass          No seal
# 7041     1320.0   0.6        21.0     pass          No seal
# 7047      492.0  0.55        21.0     pass          No seal
# 7054     1686.0  0.57        21.0     pass          No seal
# 7057      630.0   0.6        21.0     pass          No seal
# 7074      487.0  0.39        21.0     pass          No seal
# 7078      858.0  0.75        21.0     pass          No seal
# 7086      446.0  0.62        21.0     pass          No seal
# 7135      453.0  0.37        21.0     pass          No seal
# 5002     1190.0  0.64        21.0     pass      Entire Cell
# 5088     1155.0  0.48        21.0     pass      Entire Cell
# 5242      957.0  0.66        21.0     pass      Entire Cell
# 5269     2698.0  0.47        21.0     fail      Entire Cell
# 5369     1850.0  0.63        21.0     pass      Entire Cell
# 5532     1034.0  0.75        21.0     pass      Entire Cell
# 5623      663.0  0.22        21.0     fail      Entire Cell
# 5687      983.0  0.66        21.0     pass      Entire Cell
# 5847      922.0  0.72        21.0     pass      Entire Cell
# 6814     2391.0  0.86        21.0     pass      Entire Cell
# 6963     5631.0   0.9        21.0     pass      Entire Cell
# 7076      698.0  0.59        21.0     pass      Entire Cell
#
# [1368 rows x 12 columns]

# %%
standard_internal['post patch class'].value_counts()
# Out:
# Nucleated            596
# No seal              495
# Partial nucleated    177
# Outisde out           88
# Entire Cell           12
# Name: post patch class, dtype: int64

# %%
standard_nucleated = gen_filter(standard_internal,"post patch class", "Nucleated")
standard_nucleated.mean()
# Out:
# Post patch pipette R            NaN
# Picogreen               1092.446309
# PCR cycles                21.000000
# dtype: float64

# %%
standard_partial = gen_filter(standard_internal,"post patch class", "Partial nucleated")
standard_partial.mean()
# Out:
# Post patch pipette R           NaN
# Picogreen               1046.19209
# PCR cycles                21.00000
# dtype: float64

# %%
standard_noseal = gen_filter(standard_internal,"post patch class", "No seal")
standard_noseal.mean()
# Out:
# Post patch pipette R           NaN
# Picogreen               882.553535
# PCR cycles               21.000000
# dtype: float64

# %%
standard_out = gen_filter(standard_internal,"post patch class", "Outisde out")
standard_out.mean()
# Out:
# Post patch pipette R           NaN
# Picogreen               637.590909
# PCR cycles               21.000000
# dtype: float64

# %%
standard_entire = gen_filter(standard_internal,"post patch class", "Entire Cell")
standard_entire.mean()
# Out:
# Post patch pipette R       NaN
# Picogreen               1681.0
# PCR cycles                21.0
# dtype: float64

# %%
alexa_internal = gen_filter(ps2,"Internal version", "AiV2-50uM alexa 488")
alexa_internal
# Out:
#            Date User     Post patch?  Post patch pipette R Nucleus sucked in?  \
# 7108 2017-08-31   P2       Nucleated                   NaN                NaN
# 7109 2017-08-31   P2       Nucleated                   NaN                NaN
# 7110 2017-08-31   P2       Nucleated                   NaN                NaN
# 7113 2017-08-31   P8       Nucleated                   NaN                NaN
# 7116 2017-08-31   P8       Nucleated                   NaN                NaN
# 7118 2017-08-31   P8       Nucleated                   NaN                NaN
# 7119 2017-08-31   P8       Nucleated                   NaN                NaN
# 7126 2017-09-01   P2       Nucleated                   NaN                NaN
# 7128 2017-09-01   P2       Nucleated                   NaN                NaN
# 7133 2017-09-01   P8       Nucleated                   NaN                NaN
# 7143 2017-09-06   P2       Nucleated                   NaN                NaN
# 7144 2017-09-06   P2       Nucleated                   NaN                NaN
# 7145 2017-09-08   P2       Nucleated                   NaN                NaN
# 7146 2017-09-08   P2       Nucleated                   NaN                NaN
# 7148 2017-09-11   P2       Nucleated                   NaN                NaN
# 7150 2017-09-11   P2       Nucleated                   NaN                NaN
# 7154 2017-09-12   P2       Nucleated                   NaN                NaN
# 7155 2017-09-12   P2       Nucleated                   NaN                NaN
# 7156 2017-09-13   P8       Nucleated                   NaN                NaN
# 7159 2017-09-13   P8       Nucleated                   NaN                NaN
# 7161 2017-09-13   P8       Nucleated                   NaN                NaN
# 7166 2017-09-14   P8       Nucleated                   NaN                NaN
# 7168 2017-09-14   P8       Nucleated                   NaN                NaN
# 7169 2017-09-14   P8       Nucleated                   NaN                NaN
# 7170 2017-09-14   P8       Nucleated                   NaN                NaN
# 7172 2017-09-15   P2       Nucleated                   NaN                NaN
# 7173 2017-09-15   P2       Nucleated                   NaN                NaN
# 7175 2017-09-15   P2       Nucleated                   NaN                NaN
# 7176 2017-09-15   P2       Nucleated                   NaN                NaN
# 7179 2017-09-15   P8       Nucleated                   NaN                NaN
# ...         ...  ...             ...                   ...                ...
# 7536 2017-10-11   PB  nucleus_absent                 500.0  not_intentionally
# 7539 2017-10-12   P2  nucleus_absent                  10.0                 no
# 7542 2017-10-12   PB  nucleus_absent                   0.0  not_intentionally
# 7543 2017-10-12   PA  nucleus_absent                   6.6                 no
# 7544 2017-10-13   P8  nucleus_absent                   8.0                 no
# 7548 2017-10-13   PA  nucleus_absent                  15.0                 no
# 7549 2017-10-13   PB  nucleus_absent                   0.0                 no
# 7558 2017-10-16   P8  nucleus_absent                  10.0                 no
# 7562 2017-10-16   P9  nucleus_absent                   5.3                 no
# 7563 2017-10-16   P9  nucleus_absent                  13.3                 no
# 7565 2017-10-16   P9  nucleus_absent                 200.0                 no
# 7567 2017-10-16   P9  nucleus_absent                 300.0                 no
# 7570 2017-10-16   PA  nucleus_absent                   3.5                 no
# 7578 2017-10-17   P2  nucleus_absent                  10.0                 no
# 7579 2017-10-17   P2  nucleus_absent                  15.0                 no
# 7581 2017-10-17   P8  nucleus_absent                  50.0                 no
# 7583 2017-10-17   P8  nucleus_absent                  10.0                 no
# 7585 2017-10-18   P2  nucleus_absent                   4.0                 no
# 7589 2017-10-18   P2  nucleus_absent                  10.0                 no
# 7590 2017-10-18   P2  nucleus_absent                  10.0                 no
# 7591 2017-10-18   P2  nucleus_absent                   5.0                 no
# 7594 2017-10-18   P8  nucleus_absent                  10.0                 no
# 7094 2017-08-29   P8     Entire-Cell                   NaN                NaN
# 7272 2017-09-22   PA     Entire-Cell                   NaN                NaN
# 7308 2017-09-26   PB     Entire-Cell                   NaN                NaN
# 7410 2017-10-04   P2     entire_cell                  10.0                 no
# 7447 2017-10-05   P2     entire_cell                 100.0                 no
# 7455 2017-10-05   P9     entire_cell                   5.0  not_intentionally
# 7587 2017-10-18   P2     entire_cell                   7.0                 no
# 7588 2017-10-18   P2     entire_cell                  10.0                 no
#
#                                                   Notes     Internal version  \
# 7108      No Bubbles 0.1 units of pressure on expulsion  AiV2-50uM alexa 488
# 7109  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7110  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7113  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7116  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7118  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7119  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7126  Fluorescence in Pipette Small Bubbles 0.1 unit...  AiV2-50uM alexa 488
# 7128  Fluorescence in Pipette No Bubbles alexa inter...  AiV2-50uM alexa 488
# 7133  Fluorescence in Pipette No Bubbles nucleus may...  AiV2-50uM alexa 488
# 7143  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7144  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7145  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7146  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7148      No Bubbles 0.1 units of pressure on expulsion  AiV2-50uM alexa 488
# 7150      No Bubbles 0.1 units of pressure on expulsion  AiV2-50uM alexa 488
# 7154  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7155  Fluorescence in Pipette No Bubbles 0.1 units o...  AiV2-50uM alexa 488
# 7156     Fluorescence in Pipette,Cell Dimmed No Bubbles  AiV2-50uM alexa 488
# 7159  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7161  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7166  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7168  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7169     Fluorescence in Pipette,Cell Dimmed No Bubbles  AiV2-50uM alexa 488
# 7170  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7172  Fluorescence in Pipette No Bubbles 2 min 26 se...  AiV2-50uM alexa 488
# 7173  No Bubbles 2 min 47 seconds retraction period....  AiV2-50uM alexa 488
# 7175  Fluorescence in Pipette No Bubbles 2 min 25 se...  AiV2-50uM alexa 488
# 7176  Fluorescence in Pipette No Bubbles 2 min 42 se...  AiV2-50uM alexa 488
# 7179  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# ...                                                 ...                  ...
# 7536                            Fluorescence in Pipette  AiV2-50uM alexa 488
# 7539  Fluorescence in Pipette Large Bubbles alexa fi...  AiV2-50uM alexa 488
# 7542                                                NaN  AiV2-50uM alexa 488
# 7543  Cell Swelled No Bubbles No seal, in wave of de...  AiV2-50uM alexa 488
# 7544                               Tissue touch control  AiV2-50uM alexa 488
# 7548                    No Bubbles Tissue Touch Control  AiV2-50uM alexa 488
# 7549                                       tissue touch  AiV2-50uM alexa 488
# 7558      Cell Dimmed No Bubbles Alexa fill not visible  AiV2-50uM alexa 488
# 7562  Cell Dimmed No Bubbles,Solution in Pipette Sha...  AiV2-50uM alexa 488
# 7563  Cell Dimmed Small Bubbles,Solution in Pipette ...  AiV2-50uM alexa 488
# 7565  Fluorescence in Pipette No Bubbles Alexa fill ...  AiV2-50uM alexa 488
# 7567  Fluorescence in Pipette No Bubbles Alexa fill ...  AiV2-50uM alexa 488
# 7570  Cell Dimmed,Cell Swelled,Cell Disappeared Smal...  AiV2-50uM alexa 488
# 7578     No Bubbles alexa fill visible post experiment.  AiV2-50uM alexa 488
# 7579   Small Bubbles alexa fill visible post experiment  AiV2-50uM alexa 488
# 7581  Cell Shrunk No Bubbles Alexa fill visible, but...  AiV2-50uM alexa 488
# 7583  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7585  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7589  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7590  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7591  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
# 7594  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7094  Fluorescence in Pipette,Cell Dimmed,Cell Shrun...  AiV2-50uM alexa 488
# 7272  No Bubbles Sucked in entire cell while retract...  AiV2-50uM alexa 488
# 7308                            Fluorescence in Pipette  AiV2-50uM alexa 488
# 7410  Fluorescence in Pipette Medium Bubbles cell de...  AiV2-50uM alexa 488
# 7447  Fluorescence in Pipette Small Bubbles alexa fi...  AiV2-50uM alexa 488
# 7455  Fluorescence in Pipette,Cell Dimmed No Bubbles...  AiV2-50uM alexa 488
# 7587  No Bubbles alexa fill not visible post experim...  AiV2-50uM alexa 488
# 7588  Fluorescence in Pipette No Bubbles alexa fill ...  AiV2-50uM alexa 488
#
#       Picogreen Ratio  PCR cycles SM_QC_PF post patch class
# 7108      927.0  0.75        21.0     pass        Nucleated
# 7109      844.0  0.74        21.0     pass        Nucleated
# 7110      637.0  0.69        21.0     pass        Nucleated
# 7113     1187.0  0.71        21.0     pass        Nucleated
# 7116      989.0  0.83        21.0     pass        Nucleated
# 7118      946.0  0.71        21.0     pass        Nucleated
# 7119      936.0  0.65        21.0     pass        Nucleated
# 7126      659.0   0.7        21.0     pass        Nucleated
# 7128     1415.0  0.63        21.0     pass        Nucleated
# 7133      859.0  0.71        21.0     pass        Nucleated
# 7143      963.0   63%        21.0     pass        Nucleated
# 7144     1123.0   73%        21.0     pass        Nucleated
# 7145     1072.0   71%        21.0     pass        Nucleated
# 7146     1213.0   62%        21.0     pass        Nucleated
# 7148     1150.0   65%        21.0     pass        Nucleated
# 7150     1324.0   55%        21.0     pass        Nucleated
# 7154      904.0   72%        21.0     pass        Nucleated
# 7155      620.0   73%        21.0     pass        Nucleated
# 7156     1345.0   45%        21.0     pass        Nucleated
# 7159      833.0   73%        21.0     pass        Nucleated
# 7161     1016.0   73%        21.0     pass        Nucleated
# 7166     1335.0   57%        21.0     pass        Nucleated
# 7168     2837.0   70%        21.0     pass        Nucleated
# 7169     1818.0   51%        21.0     pass        Nucleated
# 7170      527.0   33%        21.0     fail        Nucleated
# 7172     1240.0   59%        21.0     pass        Nucleated
# 7173     2389.0   56%        21.0     pass        Nucleated
# 7175     1367.0   75%        21.0     pass        Nucleated
# 7176     1437.0   71%        21.0     pass        Nucleated
# 7179      800.0   42%        21.0     pass        Nucleated
# ...         ...   ...         ...      ...              ...
# 7536      430.0   36%        21.0     fail          No seal
# 7539     6400.0   15%        21.0     fail          No seal
# 7542     1761.0   85%        21.0     pass          No seal
# 7543     1144.0   41%        21.0     pass          No seal
# 7544     2562.0   25%        21.0     pass          No seal
# 7548      782.0   32%        21.0     pass          No seal
# 7549      462.0   48%        21.0     pass          No seal
# 7558     1740.0   26%        21.0     pass          No seal
# 7562      467.0   40%        21.0     fail          No seal
# 7563      972.0   24%        21.0     fail          No seal
# 7565      896.0   30%        21.0     pass          No seal
# 7567      655.0   30%        21.0     fail          No seal
# 7570      690.0   33%        21.0     fail          No seal
# 7578      634.0   32%        21.0     fail          No seal
# 7579      931.0   37%        21.0     pass          No seal
# 7581      966.0   26%        21.0     fail          No seal
# 7583     2262.0   48%        21.0     pass          No seal
# 7585      385.0   31%        21.0     fail          No seal
# 7589     1110.0   22%        21.0     fail          No seal
# 7590     1339.0   42%        21.0     pass          No seal
# 7591      654.0   35%        21.0     fail          No seal
# 7594     4448.0   55%        21.0     pass          No seal
# 7094      300.0   172        21.0     pass      Entire Cell
# 7272      722.0   42%        21.0     pass      Entire Cell
# 7308      517.5   45%        21.0     pass      Entire Cell
# 7410     1967.0   21%        21.0     fail      Entire Cell
# 7447     1674.0   46%        21.0     pass      Entire Cell
# 7455      760.0   46%        21.0     pass      Entire Cell
# 7587      722.0   21%        21.0     fail      Entire Cell
# 7588     1420.0   28%        21.0     pass      Entire Cell
#
# [469 rows x 12 columns]

# %%
alexa_internal['post patch class'].value_counts()
# Out:
# Nucleated            243
# No seal              143
# Partial nucleated     53
# Outisde out           22
# Entire Cell            8
# Name: post patch class, dtype: int64

# %%
alexa_nucleated = gen_filter(alexa_internal,"post patch class", "Nucleated")
alexa_nucleated.mean()
# Out:
# Post patch pipette R    1471.755102
# Picogreen               1299.827160
# PCR cycles                21.000000
# dtype: float64

# %%
alexa_partial = gen_filter(alexa_internal,"post patch class", "Partial nucleated")
alexa_partial.mean()
# Out:
# Post patch pipette R     137.886667
# Picogreen               1333.769811
# PCR cycles                21.000000
# dtype: float64

# %%
alexa_noseal = gen_filter(alexa_internal,"post patch class", "No seal")
alexa_noseal.mean()
# Out:
# Post patch pipette R     72.210345
# Picogreen               973.888112
# PCR cycles               21.000000
# dtype: float64

# %%
alexa_out = gen_filter(alexa_internal,"post patch class", "Outisde out")
alexa_out.mean()
# Out:
# Post patch pipette R    1194.444444
# Picogreen               1090.090909
# PCR cycles                21.000000
# dtype: float64

# %%
alexa_entire = gen_filter(alexa_internal,"post patch class", "Entire Cell")
alexa_entire.mean()
# Out:
# Post patch pipette R      26.4000
# Picogreen               1010.3125
# PCR cycles                21.0000
# dtype: float64

# %%
n_groups = 5

standard = [1092.446309, 1046.19209, 882.553535, 637.590909, 1681.0]
alexa = [1301.132780, 1333.769811, 973.888112, 1090.090909, 1010.3125]
index = np.arange(n_groups)
#index = [1,2,3,4,5]
bar_width = 0.25

rects1 = plt.bar(index, standard, bar_width, color='b', label='AiV2')

rects2 = plt.bar(index+bar_width, alexa, bar_width, color='g', label='AiV2-50uM alexa 488')

plt.xticks(index + bar_width, ('Nucleated', 'Partial Nucleated', 'No Seal', 'Outside Out', 'Entire Cell'), rotation=20)
plt.title("Average Picogreen Concentration vs. Post Patch Outcome")
plt.xlabel("Post Patch Outcome")
plt.ylabel("Average Picogreen Conc.")
axes = plt.gca()
axes.set_xlim([-.25,5])
plt.legend(loc='upper center')
plt.tight_layout()

plt.savefig("Picogreen Conc vs Post Patch Outcome", dpi=300)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = [go.Bar(x=[Nucleated, Partial Nucleated, No Seal, Outside Out, Entire Cell], y=[1092.446309, 1046.19209, 882.553535, 637.590909, 1681.0])]

trace2 = [go.Bar(x=[Nucleated, Partial Nucleated, No Seal, Outside Out, Entire Cell], y=[1301.132780, 1333.769811, 973.888112, 1090.090909, 1010.3125])]

data = [trace1, trace2]
layout = go.Layout(barmode = 'group')

fig = go.Figure(data=data, layout=layout)
py.iplot (fig, filename='grouped-bar')
# Out:
#   File "<ipython-input-29-770e1e5c2232>", line 4
#     trace1 = [go.Bar(x=[Nucleated, Partial Nucleated, No Seal, Outside Out, Entire Cell], y=[1092.446309, 1046.19209, 882.553535, 637.590909, 1681.0])]
#                                                    ^
# SyntaxError: invalid syntax
